# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDS0321ENSkillsNetwork26802033-2022-01-01" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Space X  Falcon 9 First Stage Landing Prediction**

# %% [markdown]
# ## Web scraping Falcon 9 and Falcon Heavy Launches Records from Wikipedia

# %% [markdown]
# Estimated time needed: **40** minutes

# %% [markdown]
# In this lab, you will be performing web scraping to collect Falcon 9 historical launch records from a Wikipedia page titled `List of Falcon 9 and Falcon Heavy launches`
#
# [https://en.wikipedia.org/wiki/List_of_Falcon\_9\_and_Falcon_Heavy_launches](https://en.wikipedia.org/wiki/List_of_Falcon\_9\_and_Falcon_Heavy_launches?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDS0321ENSkillsNetwork26802033-2022-01-01)

# %% [markdown]
# ![](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module\_1\_L2/images/Falcon9\_rocket_family.svg)

# %% [markdown]
# Falcon 9 first stage will land successfully

# %% [markdown]
# Several examples of an unsuccessful landing are shown here:

# %% [markdown]
# More specifically, the launch records are stored in a HTML table shown below:

# %% [markdown]
# ![](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module\_1\_L2/images/falcon9-launches-wiki.png)

# %% [markdown]
# ## Objectives
#
# Web scrap Falcon 9 launch records with `BeautifulSoup`:
#
# *   Extract a Falcon 9 launch records HTML table from Wikipedia
# *   Parse the table and convert it into a Pandas data frame

# %% [markdown]
# First let's import required packages for this lab

# %%
# !pip3 install beautifulsoup4
# !pip3 install requests
# Out:
# Requirement already satisfied: beautifulsoup4 in c:\users\ktpra\appdata\local\programs\python\python311\lib\site-packages (4.11.2)
# Requirement already satisfied: soupsieve>1.2 in c:\users\ktpra\appdata\local\programs\python\python311\lib\site-packages (from beautifulsoup4) (2.4)

# %%
import sys

import requests
from bs4 import BeautifulSoup
import re
import unicodedata
import pandas as pd

# %% [markdown]
# and we will provide some helper functions for you to process web scraped HTML table

# %%
def date_time(table_cells):
    """
    This function returns the data and time from the HTML  table cell
    Input: the  element of a table data cell extracts extra row
    """
    return [data_time.strip() for data_time in list(table_cells.strings)][0:2]

def booster_version(table_cells):
    """
    This function returns the booster version from the HTML  table cell 
    Input: the  element of a table data cell extracts extra row
    """
    out=''.join([booster_version for i,booster_version in enumerate( table_cells.strings) if i%2==0][0:-1])
    return out

def landing_status(table_cells):
    """
    This function returns the landing status from the HTML table cell 
    Input: the  element of a table data cell extracts extra row
    """
    out=[i for i in table_cells.strings][0]
    return out


def get_mass(table_cells):
    mass=unicodedata.normalize("NFKD", table_cells.text).strip()
    if mass:
        mass.find("kg")
        new_mass=mass[0:mass.find("kg")+2]
    else:
        new_mass=0
    return new_mass


def extract_column_from_header(row):
    """
    This function returns the landing status from the HTML table cell 
    Input: the  element of a table data cell extracts extra row
    """
    if (row.br):
        row.br.extract()
    if row.a:
        row.a.extract()
    if row.sup:
        row.sup.extract()
        
    colunm_name = ' '.join(row.contents)
    
    # Filter the digit and empty names
    if not(colunm_name.strip().isdigit()):
        colunm_name = colunm_name.strip()
        return colunm_name

# %% [markdown]
# To keep the lab tasks consistent, you will be asked to scrape the data from a snapshot of the  `List of Falcon 9 and Falcon Heavy launches` Wikipage updated on
# `9th June 2021`

# %%
static_url = "https://en.wikipedia.org/w/index.php?title=List_of_Falcon_9_and_Falcon_Heavy_launches&oldid=1027686922"

# %% [markdown]
# Next, request the HTML page from the above URL and get a `response` object

# %% [markdown]
# ### TASK 1: Request the Falcon9 Launch Wiki page from its URL

# %% [markdown]
# First, let's perform an HTTP GET method to request the Falcon9 Launch HTML page, as an HTTP response.

# %%
# use requests.get() method with the provided static_url
# assign the response to a object
response = requests.get(static_url)

# %% [markdown]
# Create a `BeautifulSoup` object from the HTML `response`

# %%
# Use BeautifulSoup() to create a BeautifulSoup object from a response text content
soup = BeautifulSoup(response.text, 'html.parser')

# %% [markdown]
# Print the page title to verify if the `BeautifulSoup` object was created properly

# %%
# Use soup.title attribute
print(soup.title)
# Out:
# <title>List of Falcon 9 and Falcon Heavy launches - Wikipedia</title>

# %% [markdown]
# ### TASK 2: Extract all column/variable names from the HTML table header

# %% [markdown]
# Next, we want to collect all relevant column names from the HTML table header

# %% [markdown]
# Let's try to find all tables on the wiki page first. If you need to refresh your memory about `BeautifulSoup`, please check the external reference link towards the end of this lab

# %%
# Use the find_all function in the BeautifulSoup object, with element type `table`
# Assign the result to a list called `html_tables`
html_tables = soup.find_all('table')

# %% [markdown]
# Starting from the third table is our target table contains the actual launch records.

# %%
# Let's print the third table and check its content
first_launch_table = html_tables[2]
print(first_launch_table)
# Out:
# <table class="wikitable plainrowheaders collapsible" style="width: 100%;">
# <tbody><tr>
# <th scope="col">Flight No.
# </th>
# <th scope="col">Date and<br/>time (<a href="/wiki/Coordinated_Universal_Time" title="Coordinated Universal Time">UTC</a>)
# </th>
# <th scope="col"><a href="/wiki/List_of_Falcon_9_first-stage_boosters" title="List of Falcon 9 first-stage boosters">Version,<br/>Booster</a> <sup class="reference" id="cite_ref-booster_11-0"><a href="#cite_note-booster-11">[b]</a></sup>
# </th>
# <th scope="col">Launch site
# </th>
# <th scope="col">Payload<sup class="reference" id="cite_ref-Dragon_12-0"><a href="#cite_note-Dragon-12">[c]</a></sup>
# </th>
# <th scope="col">Payload mass
# </th>
# <th scope="col">Orbit
# </th>
# <th scope="col">Customer
# </th>
# <th scope="col">Launch<br/>outcome
# </th>
# <th scope="col"><a href="/wiki/Falcon_9_first-stage_landing_tests" title="Falcon 9 first-stage landing tests">Booster<br/>landing</a>
# </th></tr>
# <tr>
# <th rowspan="2" scope="row" style="text-align:center;">1
# </th>
# <td>4 June 2010,<br/>18:45
# </td>
# <td><a href="/wiki/Falcon_9_v1.0" title="Falcon 9 v1.0">F9 v1.0</a><sup class="reference" id="cite_ref-MuskMay2012_13-0"><a href="#cite_note-MuskMay2012-13">[7]</a></sup><br/>B0003.1<sup class="reference" id="cite_ref-block_numbers_14-0"><a href="#cite_note-block_numbers-14">[8]</a></sup>
# </td>
# <td><a href="/wiki/Cape_Canaveral_Space_Force_Station" title="Cape Canaveral Space Force Station">CCAFS</a>,<br/><a href="/wiki/Cape_Canaveral_Space_Launch_Complex_40" title="Cape Canaveral Space Launch Complex 40">SLC-40</a>
# </td>
# <td><a href="/wiki/Dragon_Spacecraft_Qualification_Unit" title="Dragon Spacecraft Qualification Unit">Dragon Spacecraft Qualification Unit</a>
# </td>
# <td>
# </td>
# <td><a href="/wiki/Low_Earth_orbit" title="Low Earth orbit">LEO</a>
# </td>
# <td><a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# </td>
# <td class="table-success" style="background: #9EFF9E; vertical-align: middle; text-align: center;">Success
# </td>
# <td class="table-failure" style="background: #FFC7C7; vertical-align: middle; text-align: center;">Failure<sup class="reference" id="cite_ref-ns20110930_15-0"><a href="#cite_note-ns20110930-15">[9]</a></sup><sup class="reference" id="cite_ref-16"><a href="#cite_note-16">[10]</a></sup><br/><small>(parachute)</small>
# </td></tr>
# <tr>
# <td colspan="9">First flight of Falcon 9 v1.0.<sup class="reference" id="cite_ref-sfn20100604_17-0"><a href="#cite_note-sfn20100604-17">[11]</a></sup> Used a boilerplate version of Dragon capsule which was not designed to separate from the second stage.<small>(<a href="#First_flight_of_Falcon_9">more details below</a>)</small> Attempted to recover the first stage by parachuting it into the ocean, but it burned up on reentry, before the parachutes even deployed.<sup class="reference" id="cite_ref-parachute_18-0"><a href="#cite_note-parachute-18">[12]</a></sup>
# </td></tr>
# <tr>
# <th rowspan="2" scope="row" style="text-align:center;">2
# </th>
# <td>8 December 2010,<br/>15:43<sup class="reference" id="cite_ref-spaceflightnow_Clark_Launch_Report_19-0"><a href="#cite_note-spaceflightnow_Clark_Launch_Report-19">[13]</a></sup>
# </td>
# <td><a href="/wiki/Falcon_9_v1.0" title="Falcon 9 v1.0">F9 v1.0</a><sup class="reference" id="cite_ref-MuskMay2012_13-1"><a href="#cite_note-MuskMay2012-13">[7]</a></sup><br/>B0004.1<sup class="reference" id="cite_ref-block_numbers_14-1"><a href="#cite_note-block_numbers-14">[8]</a></sup>
# </td>
# <td><a href="/wiki/Cape_Canaveral_Space_Force_Station" title="Cape Canaveral Space Force Station">CCAFS</a>,<br/><a href="/wiki/Cape_Canaveral_Space_Launch_Complex_40" title="Cape Canaveral Space Launch Complex 40">SLC-40</a>
# </td>
# <td><a href="/wiki/SpaceX_Dragon" title="SpaceX Dragon">Dragon</a> <a class="mw-redirect" href="/wiki/COTS_Demo_Flight_1" title="COTS Demo Flight 1">demo flight C1</a><br/>(Dragon C101)
# </td>
# <td>
# </td>
# <td><a href="/wiki/Low_Earth_orbit" title="Low Earth orbit">LEO</a> (<a href="/wiki/International_Space_Station" title="International Space Station">ISS</a>)
# </td>
# <td><style data-mw-deduplicate="TemplateStyles:r1126788409">.mw-parser-output .plainlist ol,.mw-parser-output .plainlist ul{line-height:inherit;list-style:none;margin:0;padding:0}.mw-parser-output .plainlist ol li,.mw-parser-output .plainlist ul li{margin-bottom:0}</style><div class="plainlist">
# <ul><li><a href="/wiki/NASA" title="NASA">NASA</a> (<a href="/wiki/Commercial_Orbital_Transportation_Services" title="Commercial Orbital Transportation Services">COTS</a>)</li>
# <li><a href="/wiki/National_Reconnaissance_Office" title="National Reconnaissance Office">NRO</a></li></ul>
# </div>
# </td>
# <td class="table-success" style="background: #9EFF9E; vertical-align: middle; text-align: center;">Success<sup class="reference" id="cite_ref-ns20110930_15-1"><a href="#cite_note-ns20110930-15">[9]</a></sup>
# </td>
# <td class="table-failure" style="background: #FFC7C7; vertical-align: middle; text-align: center;">Failure<sup class="reference" id="cite_ref-ns20110930_15-2"><a href="#cite_note-ns20110930-15">[9]</a></sup><sup class="reference" id="cite_ref-20"><a href="#cite_note-20">[14]</a></sup><br/><small>(parachute)</small>
# </td></tr>
# <tr>
# <td colspan="9">Maiden flight of <a class="mw-redirect" href="/wiki/Dragon_capsule" title="Dragon capsule">Dragon capsule</a>, consisting of over 3 hours of testing thruster maneuvering and reentry.<sup class="reference" id="cite_ref-spaceflightnow_Clark_unleashing_Dragon_21-0"><a href="#cite_note-spaceflightnow_Clark_unleashing_Dragon-21">[15]</a></sup> Attempted to recover the first stage by parachuting it into the ocean, but it disintegrated upon reentry, before the parachutes were deployed.<sup class="reference" id="cite_ref-parachute_18-1"><a href="#cite_note-parachute-18">[12]</a></sup> <small>(<a href="#COTS_demo_missions">more details below</a>)</small> It also included two <a href="/wiki/CubeSat" title="CubeSat">CubeSats</a>,<sup class="reference" id="cite_ref-NRO_Taps_Boeing_for_Next_Batch_of_CubeSats_22-0"><a href="#cite_note-NRO_Taps_Boeing_for_Next_Batch_of_CubeSats-22">[16]</a></sup> and a wheel of <a href="/wiki/Brou%C3%A8re" title="Brouère">Brouère</a> cheese.
# </td></tr>
# <tr>
# <th rowspan="2" scope="row" style="text-align:center;">3
# </th>
# <td>22 May 2012,<br/>07:44<sup class="reference" id="cite_ref-BBC_new_era_23-0"><a href="#cite_note-BBC_new_era-23">[17]</a></sup>
# </td>
# <td><a href="/wiki/Falcon_9_v1.0" title="Falcon 9 v1.0">F9 v1.0</a><sup class="reference" id="cite_ref-MuskMay2012_13-2"><a href="#cite_note-MuskMay2012-13">[7]</a></sup><br/>B0005.1<sup class="reference" id="cite_ref-block_numbers_14-2"><a href="#cite_note-block_numbers-14">[8]</a></sup>
# </td>
# <td><a href="/wiki/Cape_Canaveral_Space_Force_Station" title="Cape Canaveral Space Force Station">CCAFS</a>,<br/><a href="/wiki/Cape_Canaveral_Space_Launch_Complex_40" title="Cape Canaveral Space Launch Complex 40">SLC-40</a>
# </td>
# <td><a href="/wiki/SpaceX_Dragon" title="SpaceX Dragon">Dragon</a> <a class="mw-redirect" href="/wiki/Dragon_C2%2B" title="Dragon C2+">demo flight C2+</a><sup class="reference" id="cite_ref-C2_24-0"><a href="#cite_note-C2-24">[18]</a></sup><br/>(Dragon C102)
# </td>
# <td>525 kg (1,157 lb)<sup class="reference" id="cite_ref-25"><a href="#cite_note-25">[19]</a></sup>
# </td>
# <td><a href="/wiki/Low_Earth_orbit" title="Low Earth orbit">LEO</a> (<a href="/wiki/International_Space_Station" title="International Space Station">ISS</a>)
# </td>
# <td><a href="/wiki/NASA" title="NASA">NASA</a> (<a href="/wiki/Commercial_Orbital_Transportation_Services" title="Commercial Orbital Transportation Services">COTS</a>)
# </td>
# <td class="table-success" style="background: #9EFF9E; vertical-align: middle; text-align: center;">Success<sup class="reference" id="cite_ref-26"><a href="#cite_note-26">[20]</a></sup>
# </td>
# <td class="table-noAttempt" style="background: #EEE; vertical-align: middle; white-space: nowrap; text-align: center;">No attempt
# </td></tr>
# <tr>
# <td colspan="9">Dragon spacecraft demonstrated a series of tests before it was allowed to approach the <a href="/wiki/International_Space_Station" title="International Space Station">International Space Station</a>. Two days later, it became the first commercial spacecraft to board the ISS.<sup class="reference" id="cite_ref-BBC_new_era_23-1"><a href="#cite_note-BBC_new_era-23">[17]</a></sup> <small>(<a href="#COTS_demo_missions">more details below</a>)</small>
# </td></tr>
# <tr>
# <th rowspan="3" scope="row" style="text-align:center;">4
# </th>
# <td rowspan="2">8 October 2012,<br/>00:35<sup class="reference" id="cite_ref-SFN_LLog_27-0"><a href="#cite_note-SFN_LLog-27">[21]</a></sup>
# </td>
# <td rowspan="2"><a href="/wiki/Falcon_9_v1.0" title="Falcon 9 v1.0">F9 v1.0</a><sup class="reference" id="cite_ref-MuskMay2012_13-3"><a href="#cite_note-MuskMay2012-13">[7]</a></sup><br/>B0006.1<sup class="reference" id="cite_ref-block_numbers_14-3"><a href="#cite_note-block_numbers-14">[8]</a></sup>
# </td>
# <td rowspan="2"><a href="/wiki/Cape_Canaveral_Space_Force_Station" title="Cape Canaveral Space Force Station">CCAFS</a>,<br/><a href="/wiki/Cape_Canaveral_Space_Launch_Complex_40" title="Cape Canaveral Space Launch Complex 40">SLC-40</a>
# </td>
# <td><a href="/wiki/SpaceX_CRS-1" title="SpaceX CRS-1">SpaceX CRS-1</a><sup class="reference" id="cite_ref-sxManifest20120925_28-0"><a href="#cite_note-sxManifest20120925-28">[22]</a></sup><br/>(Dragon C103)
# </td>
# <td>4,700 kg (10,400 lb)
# </td>
# <td><a href="/wiki/Low_Earth_orbit" title="Low Earth orbit">LEO</a> (<a href="/wiki/International_Space_Station" title="International Space Station">ISS</a>)
# </td>
# <td><a href="/wiki/NASA" title="NASA">NASA</a> (<a href="/wiki/Commercial_Resupply_Services" title="Commercial Resupply Services">CRS</a>)
# </td>
# <td class="table-success" style="background: #9EFF9E; vertical-align: middle; text-align: center;">Success
# </td>
# <td rowspan="2" style="background:#ececec; text-align:center;"><span class="nowrap">No attempt</span>
# </td></tr>
# <tr>
# <td><a href="/wiki/Orbcomm_(satellite)" title="Orbcomm (satellite)">Orbcomm-OG2</a><sup class="reference" id="cite_ref-Orbcomm_29-0"><a href="#cite_note-Orbcomm-29">[23]</a></sup>
# </td>
# <td>172 kg (379 lb)<sup class="reference" id="cite_ref-gunter-og2_30-0"><a href="#cite_note-gunter-og2-30">[24]</a></sup>
# </td>
# <td><a href="/wiki/Low_Earth_orbit" title="Low Earth orbit">LEO</a>
# </td>
# <td><a href="/wiki/Orbcomm" title="Orbcomm">Orbcomm</a>
# </td>
# <td class="table-partial" style="background: #FE9; vertical-align: middle; text-align: center;">Partial failure<sup class="reference" id="cite_ref-nyt-20121030_31-0"><a href="#cite_note-nyt-20121030-31">[25]</a></sup>
# </td></tr>
# <tr>
# <td colspan="9">CRS-1 was successful, but the <a href="/wiki/Secondary_payload" title="Secondary payload">secondary payload</a> was inserted into an abnormally low orbit and subsequently lost. This was due to one of the nine <a href="/wiki/SpaceX_Merlin" title="SpaceX Merlin">Merlin engines</a> shutting down during the launch, and NASA declining a second reignition, as per <a href="/wiki/International_Space_Station" title="International Space Station">ISS</a> visiting vehicle safety rules, the primary payload owner is contractually allowed to decline a second reignition. NASA stated that this was because SpaceX could not guarantee a high enough likelihood of the second stage completing the second burn successfully which was required to avoid any risk of secondary payload's collision with the ISS.<sup class="reference" id="cite_ref-OrbcommTotalLoss_32-0"><a href="#cite_note-OrbcommTotalLoss-32">[26]</a></sup><sup class="reference" id="cite_ref-sn20121011_33-0"><a href="#cite_note-sn20121011-33">[27]</a></sup><sup class="reference" id="cite_ref-34"><a href="#cite_note-34">[28]</a></sup>
# </td></tr>
# <tr>
# <th rowspan="2" scope="row" style="text-align:center;">5
# </th>
# <td>1 March 2013,<br/>15:10
# </td>
# <td><a href="/wiki/Falcon_9_v1.0" title="Falcon 9 v1.0">F9 v1.0</a><sup class="reference" id="cite_ref-MuskMay2012_13-4"><a href="#cite_note-MuskMay2012-13">[7]</a></sup><br/>B0007.1<sup class="reference" id="cite_ref-block_numbers_14-4"><a href="#cite_note-block_numbers-14">[8]</a></sup>
# </td>
# <td><a href="/wiki/Cape_Canaveral_Space_Force_Station" title="Cape Canaveral Space Force Station">CCAFS</a>,<br/><a href="/wiki/Cape_Canaveral_Space_Launch_Complex_40" title="Cape Canaveral Space Launch Complex 40">SLC-40</a>
# </td>
# <td><a href="/wiki/SpaceX_CRS-2" title="SpaceX CRS-2">SpaceX CRS-2</a><sup class="reference" id="cite_ref-sxManifest20120925_28-1"><a href="#cite_note-sxManifest20120925-28">[22]</a></sup><br/>(Dragon C104)
# </td>
# <td>4,877 kg (10,752 lb)
# </td>
# <td><a href="/wiki/Low_Earth_orbit" title="Low Earth orbit">LEO</a> (<a class="mw-redirect" href="/wiki/ISS" title="ISS">ISS</a>)
# </td>
# <td><a href="/wiki/NASA" title="NASA">NASA</a> (<a href="/wiki/Commercial_Resupply_Services" title="Commercial Resupply Services">CRS</a>)
# </td>
# <td class="table-success" style="background: #9EFF9E; vertical-align: middle; text-align: center;">Success
# </td>
# <td class="table-noAttempt" style="background: #EEE; vertical-align: middle; white-space: nowrap; text-align: center;">No attempt
# </td></tr>
# <tr>
# <td colspan="9">Last launch of the original Falcon 9 v1.0 <a href="/wiki/Launch_vehicle" title="Launch vehicle">launch vehicle</a>, first use of the unpressurized trunk section of Dragon.<sup class="reference" id="cite_ref-sxf9_20110321_35-0"><a href="#cite_note-sxf9_20110321-35">[29]</a></sup>
# </td></tr>
# <tr>
# <th rowspan="2" scope="row" style="text-align:center;">6
# </th>
# <td>29 September 2013,<br/>16:00<sup class="reference" id="cite_ref-pa20130930_36-0"><a href="#cite_note-pa20130930-36">[30]</a></sup>
# </td>
# <td><a href="/wiki/Falcon_9_v1.1" title="Falcon 9 v1.1">F9 v1.1</a><sup class="reference" id="cite_ref-MuskMay2012_13-5"><a href="#cite_note-MuskMay2012-13">[7]</a></sup><br/>B1003<sup class="reference" id="cite_ref-block_numbers_14-5"><a href="#cite_note-block_numbers-14">[8]</a></sup>
# </td>
# <td><a class="mw-redirect" href="/wiki/Vandenberg_Air_Force_Base" title="Vandenberg Air Force Base">VAFB</a>,<br/><a href="/wiki/Vandenberg_Space_Launch_Complex_4" title="Vandenberg Space Launch Complex 4">SLC-4E</a>
# </td>
# <td><a href="/wiki/CASSIOPE" title="CASSIOPE">CASSIOPE</a><sup class="reference" id="cite_ref-sxManifest20120925_28-2"><a href="#cite_note-sxManifest20120925-28">[22]</a></sup><sup class="reference" id="cite_ref-CASSIOPE_MDA_37-0"><a href="#cite_note-CASSIOPE_MDA-37">[31]</a></sup>
# </td>
# <td>500 kg (1,100 lb)
# </td>
# <td><a href="/wiki/Polar_orbit" title="Polar orbit">Polar orbit</a> <a href="/wiki/Low_Earth_orbit" title="Low Earth orbit">LEO</a>
# </td>
# <td><a href="/wiki/Maxar_Technologies" title="Maxar Technologies">MDA</a>
# </td>
# <td class="table-success" style="background: #9EFF9E; vertical-align: middle; text-align: center;">Success<sup class="reference" id="cite_ref-pa20130930_36-1"><a href="#cite_note-pa20130930-36">[30]</a></sup>
# </td>
# <td class="table-no2" style="background: #FFE3E3; color: black; vertical-align: middle; text-align: center;">Uncontrolled<br/><small>(ocean)</small><sup class="reference" id="cite_ref-ocean_landing_38-0"><a href="#cite_note-ocean_landing-38">[d]</a></sup>
# </td></tr>
# <tr>
# <td colspan="9">First commercial mission with a private customer, first launch from Vandenberg, and demonstration flight of Falcon 9 v1.1 with an improved 13-tonne to LEO capacity.<sup class="reference" id="cite_ref-sxf9_20110321_35-1"><a href="#cite_note-sxf9_20110321-35">[29]</a></sup> After separation from the second stage carrying Canadian commercial and scientific satellites, the first stage booster performed a controlled reentry,<sup class="reference" id="cite_ref-39"><a href="#cite_note-39">[32]</a></sup> and an <a href="/wiki/Falcon_9_first-stage_landing_tests" title="Falcon 9 first-stage landing tests">ocean touchdown test</a> for the first time. This provided good test data, even though the booster started rolling as it neared the ocean, leading to the shutdown of the central engine as the roll depleted it of fuel, resulting in a hard impact with the ocean.<sup class="reference" id="cite_ref-pa20130930_36-2"><a href="#cite_note-pa20130930-36">[30]</a></sup> This was the first known attempt of a rocket engine being lit to perform a supersonic retro propulsion, and allowed SpaceX to enter a public-private partnership with <a href="/wiki/NASA" title="NASA">NASA</a> and its Mars entry, descent, and landing technologies research projects.<sup class="reference" id="cite_ref-40"><a href="#cite_note-40">[33]</a></sup> <small>(<a href="#Maiden_flight_of_v1.1">more details below</a>)</small>
# </td></tr>
# <tr>
# <th rowspan="2" scope="row" style="text-align:center;">7
# </th>
# <td>3 December 2013,<br/>22:41<sup class="reference" id="cite_ref-sfn_wwls20130624_41-0"><a href="#cite_note-sfn_wwls20130624-41">[34]</a></sup>
# </td>
# <td><a href="/wiki/Falcon_9_v1.1" title="Falcon 9 v1.1">F9 v1.1</a><br/>B1004
# </td>
# <td><a href="/wiki/Cape_Canaveral_Space_Force_Station" title="Cape Canaveral Space Force Station">CCAFS</a>,<br/><a href="/wiki/Cape_Canaveral_Space_Launch_Complex_40" title="Cape Canaveral Space Launch Complex 40">SLC-40</a>
# </td>
# <td><a href="/wiki/SES-8" title="SES-8">SES-8</a><sup class="reference" id="cite_ref-sxManifest20120925_28-3"><a href="#cite_note-sxManifest20120925-28">[22]</a></sup><sup class="reference" id="cite_ref-spx-pr_42-0"><a href="#cite_note-spx-pr-42">[35]</a></sup><sup class="reference" id="cite_ref-aw20110323_43-0"><a href="#cite_note-aw20110323-43">[36]</a></sup>
# </td>
# <td>3,170 kg (6,990 lb)
# </td>
# <td><a href="/wiki/Geostationary_transfer_orbit" title="Geostationary transfer orbit">GTO</a>
# </td>
# <td><a href="/wiki/SES_S.A." title="SES S.A.">SES</a>
# </td>
# <td class="table-success" style="background: #9EFF9E; vertical-align: middle; text-align: center;">Success<sup class="reference" id="cite_ref-SNMissionStatus7_44-0"><a href="#cite_note-SNMissionStatus7-44">[37]</a></sup>
# </td>
# <td class="table-noAttempt" style="background: #EEE; vertical-align: middle; white-space: nowrap; text-align: center;">No attempt<br/><sup class="reference" id="cite_ref-sf10120131203_45-0"><a href="#cite_note-sf10120131203-45">[38]</a></sup>
# </td></tr>
# <tr>
# <td colspan="9">First <a href="/wiki/Geostationary_transfer_orbit" title="Geostationary transfer orbit">Geostationary transfer orbit</a> (GTO) launch for Falcon 9,<sup class="reference" id="cite_ref-spx-pr_42-1"><a href="#cite_note-spx-pr-42">[35]</a></sup> and first successful reignition of the second stage.<sup class="reference" id="cite_ref-46"><a href="#cite_note-46">[39]</a></sup> SES-8 was inserted into a <a href="/wiki/Geostationary_transfer_orbit" title="Geostationary transfer orbit">Super-Synchronous Transfer Orbit</a> of 79,341 km (49,300 mi) in apogee with an <a href="/wiki/Orbital_inclination" title="Orbital inclination">inclination</a> of 20.55° to the <a href="/wiki/Equator" title="Equator">equator</a>.
# </td></tr></tbody></table>

# %% [markdown]
# You should able to see the columns names embedded in the table header elements `<th>` as follows:

# %% [markdown]
# ```
# <tr>
# <th scope="col">Flight No.
# </th>
# <th scope="col">Date and<br/>time (<a href="/wiki/Coordinated_Universal_Time" title="Coordinated Universal Time">UTC</a>)
# </th>
# <th scope="col"><a href="/wiki/List_of_Falcon_9_first-stage_boosters" title="List of Falcon 9 first-stage boosters">Version,<br/>Booster</a> <sup class="reference" id="cite_ref-booster_11-0"><a href="#cite_note-booster-11">[b]</a></sup>
# </th>
# <th scope="col">Launch site
# </th>
# <th scope="col">Payload<sup class="reference" id="cite_ref-Dragon_12-0"><a href="#cite_note-Dragon-12">[c]</a></sup>
# </th>
# <th scope="col">Payload mass
# </th>
# <th scope="col">Orbit
# </th>
# <th scope="col">Customer
# </th>
# <th scope="col">Launch<br/>outcome
# </th>
# <th scope="col"><a href="/wiki/Falcon_9_first-stage_landing_tests" title="Falcon 9 first-stage landing tests">Booster<br/>landing</a>
# </th></tr>
# ```

# %% [markdown]
# Next, we just need to iterate through the `<th>` elements and apply the provided `extract_column_from_header()` to extract column name one by one

# %%
column_names = []

# Apply find_all() function with `th` element on first_launch_table
# Iterate each th element and apply the provided extract_column_from_header() to get a column name
# Append the Non-empty column name (`if name is not None and len(name) > 0`) into a list called column_names
for th in first_launch_table.find_all('th'):
    name = extract_column_from_header(th)
    if name is not None and len(name) > 0:
        column_names.append(name)

# %% [markdown]
# Check the extracted column names

# %%
print(column_names)
# Out:
# ['Flight No.', 'Date and time ( )', 'Launch site', 'Payload', 'Payload mass', 'Orbit', 'Customer', 'Launch outcome']

# %% [markdown]
# ## TASK 3: Create a data frame by parsing the launch HTML tables

# %% [markdown]
# We will create an empty dictionary with keys from the extracted column names in the previous task. Later, this dictionary will be converted into a Pandas dataframe

# %%
launch_dict= dict.fromkeys(column_names)

# Remove an irrelvant column
del launch_dict['Date and time ( )']

# Let's initial the launch_dict with each value to be an empty list
launch_dict['Flight No.'] = []
launch_dict['Date']=[]
launch_dict['Time']=[]
launch_dict['Launch site'] = []
launch_dict['Payload'] = []
launch_dict['Payload mass'] = []
launch_dict['Orbit'] = []
launch_dict['Customer'] = []
launch_dict['Launch outcome'] = []
# Added some new columns
launch_dict['Version Booster']=[]
launch_dict['Booster landing']=[]


print(launch_dict)
# Out:
# {'Flight No.': [], 'Launch site': [], 'Payload': [], 'Payload mass': [], 'Orbit': [], 'Customer': [], 'Launch outcome': [], 'Date': [], 'Time': [], 'Version Booster': [], 'Booster landing': []}

# %% [markdown]
# Next, we just need to fill up the `launch_dict` with launch records extracted from table rows.

# %% [markdown]
# Usually, HTML tables in Wiki pages are likely to contain unexpected annotations and other types of noises, such as reference links `B0004.1[8]`, missing values `N/A [e]`, inconsistent formatting, etc.

# %% [markdown]
# To simplify the parsing process, we have provided an incomplete code snippet below to help you to fill up the `launch_dict`. Please complete the following code snippet with TODOs or you can choose to write your own logic to parse all launch tables:

# %%
extracted_row = 0
#Extract each table and enumerate over each table use the soup object ot find all tables with class wikitable plainrowheaders collapsible
for table_number,table in enumerate(soup.find_all('table',class_="wikitable plainrowheaders collapsible")):

   # get table row 
    for rows in table.find_all('tr'):
        #check to see if first table heading is as number corresponding to launch a number 
        if rows.th:
            if rows.th.string:
                flight_number=rows.th.string.strip()
                flag=flight_number.isdigit()
        else:
            flag=False
        #get table element 
        row=rows.find_all('td')
        #if it is number save cells in a dictonary 
        if flag:
            extracted_row += 1
            # Flight Number value
            # TODO: Append the flight_number into launch_dict with key `Flight No.`
            launch_dict['Flight No.'].append(flight_number)
            print(f"Flight No.: {flight_number}")

            datatimelist=date_time(row[0])

            
            # Date value
            # TODO: Append the date into launch_dict with key `Date
            date = datatimelist[0].strip(',')
            launch_dict['Date'].append(date)
            print(f"Date: {date}")
            
            # Time value
            # TODO: Append the time into launch_dict with key `Time`
            time = datatimelist[1].strip(',')
            launch_dict['Time'].append(time)
            print(f"Time: {time}")
              
            # Booster version
            # TODO: Append the bv into launch_dict with key `Version Booster` using booster_version function, strip trailing and leading spaces
            bv=booster_version(row[1])
            launch_dict['Version Booster'].append(bv)
            if not(bv):
                bv=row[1]
            print(f"Version Booster: {bv}")
            
            # Launch Site
            # TODO: Append the bv into launch_dict with key `Launch Site`
            launch_site = booster_version(row[2])
            launch_dict['Launch site'].append(launch_site.strip(','))
            if not (launch_site):
                launch_site = row[2]
            print(f"Launch site: {launch_site}")
            
            # Payload
            # TODO: Append the payload into launch_dict with key `Payload`
            payload = row[3].a.string
            launch_dict['Payload'].append(payload)
            print(f"Payload: {payload}")
            
            # Payload Mass
            # TODO: Append the payload_mass into launch_dict with key `Payload mass`
            payload_mass = get_mass(row[4])
            launch_dict['Payload mass'].append(payload_mass)
            print(f"Payload mass: {payload_mass}")
            
            # Orbit
            # TODO: Append the orbit into launch_dict with key `Orbit`
            orbit = row[5].a.string
            launch_dict['Orbit'].append(orbit)
            print(f"Orbit: {orbit}")
            
            # Customer
            # TODO: Append the customer into launch_dict with key `Customer`
            launch_dict['Customer'].append(customer)
            customer = row[6]
            print(f"Customer: {customer}")
            
            # Launch outcome
            # TODO: Append the launch_outcome into launch_dict with key `Launch outcome`
            launch_outcome = list(row[7].strings)[0]
            launch_dict['Launch outcome'].append(launch_outcome)
            print(f"Launch outcome: {launch_outcome}")
            
            # Booster landing
            # TODO: Append the launch_outcome into launch_dict with key `Booster landing`
            booster_landing = landing_status(row[8])
            launch_dict['Booster landing'].append(launch_outcome)
            print(f"Booster landing: {booster_landing}")
            
             # Debugging
            print(f"Extracted row: {extracted_row}")
            print(f"Length of Flight No. array: {len(launch_dict['Flight No.'])}")
            print(f"Length of Date array: {len(launch_dict['Date'])}")
            print(f"Length of Time array: {len(launch_dict['Time'])}")
            print(f"Length of Version Booster array: {len(launch_dict['Version Booster'])}")
            print(f"Length of Launch site array: {len(launch_dict['Launch site'])}")
            print(f"Length of Payload array: {len(launch_dict['Payload'])}")
            print(f"Length of Payload mass array: {len(launch_dict['Payload mass'])}")
            print(f"Length of Orbit array: {len(launch_dict['Orbit'])}")
            print(f"Length of Customer array: {len(launch_dict['Customer'])}")
            print(f"Length of Launch outcome array: {len(launch_dict['Launch outcome'])}")
            print(f"Length of Booster landing array: {len(launch_dict['Booster landing'])}")
# Out:
# Flight No.: 1
# Date: 4 June 2010
# Time: 18:45
# Version Booster: F9 v1.0B0003.1
# Launch site: CCAFS
# Payload: Dragon Spacecraft Qualification Unit
# Payload mass: 0
# Orbit: LEO
# Customer: <td><a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# </td>
# Launch outcome: Success
#
# Booster landing: Failure
# Extracted row: 1
# Length of Flight No. array: 2956
# Length of Date array: 2849
# Length of Time array: 2742
# Length of Version Booster array: 2523
# Length of Launch site array: 2099
# Length of Payload array: 1992
# Length of Payload mass array: 1037
# Length of Orbit array: 1037
# Length of Customer array: 1029
# Length of Launch outcome array: 1027
# Length of Booster landing array: 1027
# Flight No.: 2
# Date: 8 December 2010
# Time: 15:43
# Version Booster: F9 v1.0B0004.1
# Launch site: CCAFS
# Payload: Dragon
# Payload mass: 0
# Orbit: LEO
# Customer: <td><style data-mw-deduplicate="TemplateStyles:r1126788409">.mw-parser-output .plainlist ol,.mw-parser-output .plainlist ul{line-height:inherit;list-style:none;margin:0;padding:0}.mw-parser-output .plainlist ol li,.mw-parser-output .plainlist ul li{margin-bottom:0}</style><div class="plainlist">
# <ul><li><a href="/wiki/NASA" title="NASA">NASA</a> (<a href="/wiki/Commercial_Orbital_Transportation_Services" title="Commercial Orbital Transportation Services">COTS</a>)</li>
# <li><a href="/wiki/National_Reconnaissance_Office" title="National Reconnaissance Office">NRO</a></li></ul>
# </div>
# </td>
# Launch outcome: Success
# Booster landing: Failure
# Extracted row: 2
# Length of Flight No. array: 2957
# Length of Date array: 2850
# Length of Time array: 2743
# Length of Version Booster array: 2524
# Length of Launch site array: 2100
# Length of Payload array: 1993
# Length of Payload mass array: 1038
# Length of Orbit array: 1038
# Length of Customer array: 1030
# Length of Launch outcome array: 1028
# Length of Booster landing array: 1028
# Flight No.: 3
# Date: 22 May 2012
# Time: 07:44
# Version Booster: F9 v1.0B0005.1
# Launch site: CCAFS
# Payload: Dragon
# Payload mass: 525 kg
# Orbit: LEO
# Customer: <td><a href="/wiki/NASA" title="NASA">NASA</a> (<a href="/wiki/Commercial_Orbital_Transportation_Services" title="Commercial Orbital Transportation Services">COTS</a>)
# </td>
# Launch outcome: Success
# Booster landing: No attempt
#
# Extracted row: 3
# Length of Flight No. array: 2958
# Length of Date array: 2851
# Length of Time array: 2744
# Length of Version Booster array: 2525
# Length of Launch site array: 2101
# Length of Payload array: 1994
# Length of Payload mass array: 1039
# Length of Orbit array: 1039
# Length of Customer array: 1031
# Length of Launch outcome array: 1029
# Length of Booster landing array: 1029
# Flight No.: 4
# Date: 8 October 2012
# Time: 00:35
# Version Booster: F9 v1.0B0006.1
# Launch site: CCAFS
# Payload: SpaceX CRS-1
# Payload mass: 4,700 kg
# Orbit: LEO
# Customer: <td><a href="/wiki/NASA" title="NASA">NASA</a> (<a href="/wiki/Commercial_Resupply_Services" title="Commercial Resupply Services">CRS</a>)
# </td>
# Launch outcome: Success
#
# Booster landing: No attempt
# Extracted row: 4
# Length of Flight No. array: 2959
# Length of Date array: 2852
# Length of Time array: 2745
# Length of Version Booster array: 2526
# Length of Launch site array: 2102
# Length of Payload array: 1995
# Length of Payload mass array: 1040
# Length of Orbit array: 1040
# Length of Customer array: 1032
# Length of Launch outcome array: 1030
# Length of Booster landing array: 1030
# Flight No.: 5
# Date: 1 March 2013
# Time: 15:10
# Version Booster: F9 v1.0B0007.1
# Launch site: CCAFS
# Payload: SpaceX CRS-2
# Payload mass: 4,877 kg
# Orbit: LEO
# Customer: <td><a href="/wiki/NASA" title="NASA">NASA</a> (<a href="/wiki/Commercial_Resupply_Services" title="Commercial Resupply Services">CRS</a>)
# </td>
# Launch outcome: Success
#
# Booster landing: No attempt
#
# Extracted row: 5
# Length of Flight No. array: 2960
# Length of Date array: 2853
# Length of Time array: 2746
# Length of Version Booster array: 2527
# Length of Launch site array: 2103
# Length of Payload array: 1996
# Length of Payload mass array: 1041
# Length of Orbit array: 1041
# Length of Customer array: 1033
# Length of Launch outcome array: 1031
# Length of Booster landing array: 1031
# Flight No.: 6
# Date: 29 September 2013
# Time: 16:00
# Version Booster: F9 v1.1B1003
# Launch site: VAFB
# Payload: CASSIOPE
# Payload mass: 500 kg
# Orbit: Polar orbit
# Customer: <td><a href="/wiki/Maxar_Technologies" title="Maxar Technologies">MDA</a>
# </td>
# Launch outcome: Success
# Booster landing: Uncontrolled
# Extracted row: 6
# Length of Flight No. array: 2961
# Length of Date array: 2854
# Length of Time array: 2747
# Length of Version Booster array: 2528
# Length of Launch site array: 2104
# Length of Payload array: 1997
# Length of Payload mass array: 1042
# Length of Orbit array: 1042
# Length of Customer array: 1034
# Length of Launch outcome array: 1032
# Length of Booster landing array: 1032
# Flight No.: 7
# Date: 3 December 2013
# Time: 22:41
# Version Booster: <td><a href="/wiki/Falcon_9_v1.1" title="Falcon 9 v1.1">F9 v1.1</a><br/>B1004
# </td>
# Launch site: CCAFS
# Payload: SES-8
# Payload mass: 3,170 kg
# Orbit: GTO
# Customer: <td><a href="/wiki/SES_S.A." title="SES S.A.">SES</a>
# </td>
# Launch outcome: Success
# Booster landing: No attempt
# Extracted row: 7
# Length of Flight No. array: 2962
# Length of Date array: 2855
# Length of Time array: 2748
# Length of Version Booster array: 2529
# Length of Launch site array: 2105
# Length of Payload array: 1998
# Length of Payload mass array: 1043
# Length of Orbit array: 1043
# Length of Customer array: 1035
# Length of Launch outcome array: 1033
# Length of Booster landing array: 1033
# Flight No.: 8
# Date: 6 January 2014
# Time: 22:06
# Version Booster: <td><a href="/wiki/Falcon_9_v1.1" title="Falcon 9 v1.1">F9 v1.1</a>
# </td>
# Launch site: CCAFS
# Payload: Thaicom 6
# Payload mass: 3,325 kg
# Orbit: GTO
# Customer: <td><a href="/wiki/Thaicom" title="Thaicom">Thaicom</a>
# </td>
# Launch outcome: Success
# Booster landing: No attempt
# Extracted row: 8
# Length of Flight No. array: 2963
# Length of Date array: 2856
# Length of Time array: 2749
# Length of Version Booster array: 2530
# Length of Launch site array: 2106
# Length of Payload array: 1999
# Length of Payload mass array: 1044
# Length of Orbit array: 1044
# Length of Customer array: 1036
# Length of Launch outcome array: 1034
# Length of Booster landing array: 1034
# Flight No.: 9
# Date: 18 April 2014
# Time: 19:25
# Version Booster: <td><a href="/wiki/Falcon_9_v1.1" title="Falcon 9 v1.1">F9 v1.1</a>
# </td>
# Launch site: Cape Canaveral
# Payload: SpaceX CRS-3
# Payload mass: 2,296 kg
# Orbit: LEO
# Customer: <td><a href="/wiki/NASA" title="NASA">NASA</a> (<a href="/wiki/Commercial_Resupply_Services" title="Commercial Resupply Services">CRS</a>)
# </td>
# Launch outcome: Success
#
# Booster landing: Controlled
# Extracted row: 9
# Length of Flight No. array: 2964
# Length of Date array: 2857
# Length of Time array: 2750
# Length of Version Booster array: 2531
# Length of Launch site array: 2107
# Length of Payload array: 2000
# Length of Payload mass array: 1045
# Length of Orbit array: 1045
# Length of Customer array: 1037
# Length of Launch outcome array: 1035
# Length of Booster landing array: 1035
# Flight No.: 10
# Date: 14 July 2014
# Time: 15:15
# Version Booster: <td><a href="/wiki/Falcon_9_v1.1" title="Falcon 9 v1.1">F9 v1.1</a>
# </td>
# Launch site: Cape Canaveral
# Payload: Orbcomm-OG2
# Payload mass: 1,316 kg
# Orbit: LEO
# Customer: <td><a href="/wiki/Orbcomm" title="Orbcomm">Orbcomm</a>
# </td>
# Launch outcome: Success
# Booster landing: Controlled
# Extracted row: 10
# Length of Flight No. array: 2965
# Length of Date array: 2858
# Length of Time array: 2751
# Length of Version Booster array: 2532
# Length of Launch site array: 2108
# Length of Payload array: 2001
# Length of Payload mass array: 1046
# Length of Orbit array: 1046
# Length of Customer array: 1038
# Length of Launch outcome array: 1036
# Length of Booster landing array: 1036
# Flight No.: 11
# Date: 5 August 2014
# Time: 08:00
# Version Booster: <td><a href="/wiki/Falcon_9_v1.1" title="Falcon 9 v1.1">F9 v1.1</a>
# </td>
# Launch site: Cape Canaveral
# Payload: AsiaSat 8
# Payload mass: 4,535 kg
# Orbit: GTO
# Customer: <td><a href="/wiki/AsiaSat" title="AsiaSat">AsiaSat</a>
# </td>
# Launch outcome: Success
# Booster landing: No attempt
# Extracted row: 11
# Length of Flight No. array: 2966
# Length of Date array: 2859
# Length of Time array: 2752
# Length of Version Booster array: 2533
# Length of Launch site array: 2109
# Length of Payload array: 2002
# Length of Payload mass array: 1047
# Length of Orbit array: 1047
# Length of Customer array: 1039
# Length of Launch outcome array: 1037
# Length of Booster landing array: 1037
# Flight No.: 12
# Date: 7 September 2014
# Time: 05:00
# Version Booster: F9 v1.1
# Launch site: Cape Canaveral
# Payload: AsiaSat 6
# Payload mass: 4,428 kg
# Orbit: GTO
# Customer: <td><a href="/wiki/AsiaSat" title="AsiaSat">AsiaSat</a>
# </td>
# Launch outcome: Success
# Booster landing: No attempt
#
# Extracted row: 12
# Length of Flight No. array: 2967
# Length of Date array: 2860
# Length of Time array: 2753
# Length of Version Booster array: 2534
# Length of Launch site array: 2110
# Length of Payload array: 2003
# Length of Payload mass array: 1048
# Length of Orbit array: 1048
# Length of Customer array: 1040
# Length of Launch outcome array: 1038
# Length of Booster landing array: 1038
# Flight No.: 13
# Date: 21 September 2014
# Time: 05:52
# Version Booster: F9 v1.1
# Launch site: Cape Canaveral
# Payload: SpaceX CRS-4
# Payload mass: 2,216 kg
# Orbit: LEO
# Customer: <td><a href="/wiki/NASA" title="NASA">NASA</a> (<a href="/wiki/Commercial_Resupply_Services" title="Commercial Resupply Services">CRS</a>)
# </td>
# Launch outcome: Success
# Booster landing: Uncontrolled
# Extracted row: 13
# Length of Flight No. array: 2968
# Length of Date array: 2861
# Length of Time array: 2754
# Length of Version Booster array: 2535
# Length of Launch site array: 2111
# Length of Payload array: 2004
# Length of Payload mass array: 1049
# Length of Orbit array: 1049
# Length of Customer array: 1041
# Length of Launch outcome array: 1039
# Length of Booster landing array: 1039
# Flight No.: 14
# Date: 10 January 2015
# Time: 09:47
# Version Booster: F9 v1.1
# Launch site: Cape Canaveral
# Payload: SpaceX CRS-5
# Payload mass: 2,395 kg
# Orbit: LEO
# Customer: <td><a href="/wiki/NASA" title="NASA">NASA</a> (<a href="/wiki/Commercial_Resupply_Services" title="Commercial Resupply Services">CRS</a>)
# </td>
# Launch outcome: Success
# Booster landing: Failure
# Extracted row: 14
# Length of Flight No. array: 2969
# Length of Date array: 2862
# Length of Time array: 2755
# Length of Version Booster array: 2536
# Length of Launch site array: 2112
# Length of Payload array: 2005
# Length of Payload mass array: 1050
# Length of Orbit array: 1050
# Length of Customer array: 1042
# Length of Launch outcome array: 1040
# Length of Booster landing array: 1040
# Flight No.: 15
# Date: 11 February 2015
# Time: 23:03
# Version Booster: F9 v1.1
# Launch site: Cape Canaveral
# Payload: DSCOVR
# Payload mass: 570 kg
# Orbit: HEO
# Customer: <td><link href="mw-data:TemplateStyles:r1126788409" rel="mw-deduplicated-inline-style"/><div class="plainlist">
# <ul><li><a href="/wiki/United_States_Air_Force" title="United States Air Force">USAF</a></li>
# <li><a href="/wiki/NASA" title="NASA">NASA</a></li>
# <li><a class="mw-redirect" href="/wiki/NOAA" title="NOAA">NOAA</a></li></ul>
# </div>
# </td>
# Launch outcome: Success
#
# Booster landing: Controlled
# Extracted row: 15
# Length of Flight No. array: 2970
# Length of Date array: 2863
# Length of Time array: 2756
# Length of Version Booster array: 2537
# Length of Launch site array: 2113
# Length of Payload array: 2006
# Length of Payload mass array: 1051
# Length of Orbit array: 1051
# Length of Customer array: 1043
# Length of Launch outcome array: 1041
# Length of Booster landing array: 1041
# Flight No.: 16
# Date: 2 March 2015
# Time: 03:50
# Version Booster: F9 v1.1
# Launch site: Cape Canaveral
# Payload: ABS-3A
# Payload mass: 4,159 kg
# Orbit: GTO
# Customer: <td><link href="mw-data:TemplateStyles:r1126788409" rel="mw-deduplicated-inline-style"/><div class="plainlist">
# <ul><li><a class="mw-redirect" href="/wiki/Asia_Broadcast_Satellite" title="Asia Broadcast Satellite">ABS</a></li>
# <li><a href="/wiki/Eutelsat" title="Eutelsat">Eutelsat</a></li></ul>
# </div>
# </td>
# Launch outcome: Success
#
# Booster landing: No attempt
# Extracted row: 16
# Length of Flight No. array: 2971
# Length of Date array: 2864
# Length of Time array: 2757
# Length of Version Booster array: 2538
# Length of Launch site array: 2114
# Length of Payload array: 2007
# Length of Payload mass array: 1052
# Length of Orbit array: 1052
# Length of Customer array: 1044
# Length of Launch outcome array: 1042
# Length of Booster landing array: 1042
# Flight No.: 17
# Date: 14 April 2015
# Time: 20:10
# Version Booster: F9 v1.1
# Launch site: Cape Canaveral
# Payload: SpaceX CRS-6
# Payload mass: 1,898 kg
# Orbit: LEO
# Customer: <td><a href="/wiki/NASA" title="NASA">NASA</a> (<a href="/wiki/Commercial_Resupply_Services" title="Commercial Resupply Services">CRS</a>)
# </td>
# Launch outcome: Success
#
# Booster landing: Failure
# Extracted row: 17
# Length of Flight No. array: 2972
# Length of Date array: 2865
# Length of Time array: 2758
# Length of Version Booster array: 2539
# Length of Launch site array: 2115
# Length of Payload array: 2008
# Length of Payload mass array: 1053
# Length of Orbit array: 1053
# Length of Customer array: 1045
# Length of Launch outcome array: 1043
# Length of Booster landing array: 1043
# Flight No.: 18
# Date: 27 April 2015
# Time: 23:03
# Version Booster: F9 v1.1
# Launch site: Cape Canaveral
# Payload: TürkmenÄlem 52°E / MonacoSAT
# Payload mass: 4,707 kg
# Orbit: GTO
# Customer: <td><a href="/wiki/Turkmenistan_National_Space_Agency" title="Turkmenistan National Space Agency">Turkmenistan National<br/>Space Agency</a><sup class="reference" id="cite_ref-95"><a href="#cite_note-95">[88]</a></sup>
# </td>
# Launch outcome: Success
#
# Booster landing: No attempt
# Extracted row: 18
# Length of Flight No. array: 2973
# Length of Date array: 2866
# Length of Time array: 2759
# Length of Version Booster array: 2540
# Length of Launch site array: 2116
# Length of Payload array: 2009
# Length of Payload mass array: 1054
# Length of Orbit array: 1054
# Length of Customer array: 1046
# Length of Launch outcome array: 1044
# Length of Booster landing array: 1044
# Flight No.: 19
# Date: 28 June 2015
# Time: 14:21
# Version Booster: F9 v1.1
# Launch site: Cape Canaveral
# Payload: SpaceX CRS-7
# Payload mass: 1,952 kg
# Orbit: LEO
# Customer: <td><a href="/wiki/NASA" title="NASA">NASA</a> (<a href="/wiki/Commercial_Resupply_Services" title="Commercial Resupply Services">CRS</a>)
# </td>
# Launch outcome: Failure
# Booster landing: Precluded
# Extracted row: 19
# Length of Flight No. array: 2974
# Length of Date array: 2867
# Length of Time array: 2760
# Length of Version Booster array: 2541
# Length of Launch site array: 2117
# Length of Payload array: 2010
# Length of Payload mass array: 1055
# Length of Orbit array: 1055
# Length of Customer array: 1047
# Length of Launch outcome array: 1045
# Length of Booster landing array: 1045
# Flight No.: 20
# Date: 22 December 2015
# Time: 01:29
# Version Booster: F9 FT
# Launch site: Cape Canaveral
# Payload: Orbcomm-OG2
# Payload mass: 2,034 kg
# Orbit: LEO
# Customer: <td><a href="/wiki/Orbcomm" title="Orbcomm">Orbcomm</a>
# </td>
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 20
# Length of Flight No. array: 2975
# Length of Date array: 2868
# Length of Time array: 2761
# Length of Version Booster array: 2542
# Length of Launch site array: 2118
# Length of Payload array: 2011
# Length of Payload mass array: 1056
# Length of Orbit array: 1056
# Length of Customer array: 1048
# Length of Launch outcome array: 1046
# Length of Booster landing array: 1046
# Flight No.: 21
# Date: 17 January 2016
# Time: 18:42
# Version Booster: F9 v1.1
# Launch site: VAFB
# Payload: Jason-3
# Payload mass: 553 kg
# Orbit: LEO
# Customer: <td><link href="mw-data:TemplateStyles:r1126788409" rel="mw-deduplicated-inline-style"/><div class="plainlist">
# <ul><li><a href="/wiki/NASA" title="NASA">NASA</a> (<a class="mw-redirect" href="/wiki/Launch_Services_Program" title="Launch Services Program">LSP</a>)</li>
# <li><a class="mw-redirect" href="/wiki/NOAA" title="NOAA">NOAA</a></li>
# <li><a href="/wiki/CNES" title="CNES">CNES</a></li></ul>
# </div>
# </td>
# Launch outcome: Success
#
# Booster landing: Failure
# Extracted row: 21
# Length of Flight No. array: 2976
# Length of Date array: 2869
# Length of Time array: 2762
# Length of Version Booster array: 2543
# Length of Launch site array: 2119
# Length of Payload array: 2012
# Length of Payload mass array: 1057
# Length of Orbit array: 1057
# Length of Customer array: 1049
# Length of Launch outcome array: 1047
# Length of Booster landing array: 1047
# Flight No.: 22
# Date: 4 March 2016
# Time: 23:35
# Version Booster: F9 FT
# Launch site: Cape Canaveral
# Payload: SES-9
# Payload mass: 5,271 kg
# Orbit: GTO
# Customer: <td><a href="/wiki/SES_S.A." title="SES S.A.">SES</a>
# </td>
# Launch outcome: Success
#
# Booster landing: Failure
# Extracted row: 22
# Length of Flight No. array: 2977
# Length of Date array: 2870
# Length of Time array: 2763
# Length of Version Booster array: 2544
# Length of Launch site array: 2120
# Length of Payload array: 2013
# Length of Payload mass array: 1058
# Length of Orbit array: 1058
# Length of Customer array: 1050
# Length of Launch outcome array: 1048
# Length of Booster landing array: 1048
# Flight No.: 23
# Date: 8 April 2016
# Time: 20:43
# Version Booster: F9 FT
# Launch site: Cape Canaveral
# Payload: SpaceX CRS-8
# Payload mass: 3,136 kg
# Orbit: LEO
# Customer: <td><a href="/wiki/NASA" title="NASA">NASA</a> (<a href="/wiki/Commercial_Resupply_Services" title="Commercial Resupply Services">CRS</a>)
# </td>
# Launch outcome: Success
# Booster landing: Success
# Extracted row: 23
# Length of Flight No. array: 2978
# Length of Date array: 2871
# Length of Time array: 2764
# Length of Version Booster array: 2545
# Length of Launch site array: 2121
# Length of Payload array: 2014
# Length of Payload mass array: 1059
# Length of Orbit array: 1059
# Length of Customer array: 1051
# Length of Launch outcome array: 1049
# Length of Booster landing array: 1049
# Flight No.: 24
# Date: 6 May 2016
# Time: 05:21
# Version Booster: F9 FT
# Launch site: Cape Canaveral
# Payload: JCSAT-14
# Payload mass: 4,696 kg
# Orbit: GTO
# Customer: <td><a href="/wiki/SKY_Perfect_JSAT" title="SKY Perfect JSAT">SKY Perfect JSAT Group</a>
# </td>
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 24
# Length of Flight No. array: 2979
# Length of Date array: 2872
# Length of Time array: 2765
# Length of Version Booster array: 2546
# Length of Launch site array: 2122
# Length of Payload array: 2015
# Length of Payload mass array: 1060
# Length of Orbit array: 1060
# Length of Customer array: 1052
# Length of Launch outcome array: 1050
# Length of Booster landing array: 1050
# Flight No.: 25
# Date: 27 May 2016
# Time: 21:39
# Version Booster: F9 FT
# Launch site: Cape Canaveral
# Payload: Thaicom 8
# Payload mass: 3,100 kg
# Orbit: GTO
# Customer: <td><a href="/wiki/Thaicom" title="Thaicom">Thaicom</a>
# </td>
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 25
# Length of Flight No. array: 2980
# Length of Date array: 2873
# Length of Time array: 2766
# Length of Version Booster array: 2547
# Length of Launch site array: 2123
# Length of Payload array: 2016
# Length of Payload mass array: 1061
# Length of Orbit array: 1061
# Length of Customer array: 1053
# Length of Launch outcome array: 1051
# Length of Booster landing array: 1051
# Flight No.: 26
# Date: 15 June 2016
# Time: 14:29
# Version Booster: F9 FT
# Launch site: Cape Canaveral
# Payload: ABS-2A
# Payload mass: 3,600 kg
# Orbit: GTO
# Customer: <td><link href="mw-data:TemplateStyles:r1126788409" rel="mw-deduplicated-inline-style"/><div class="plainlist">
# <ul><li><a class="mw-redirect" href="/wiki/Asia_Broadcast_Satellite" title="Asia Broadcast Satellite">ABS</a></li>
# <li><a href="/wiki/Eutelsat" title="Eutelsat">Eutelsat</a></li></ul>
# </div>
# </td>
# Launch outcome: Success
#
# Booster landing: Failure
# Extracted row: 26
# Length of Flight No. array: 2981
# Length of Date array: 2874
# Length of Time array: 2767
# Length of Version Booster array: 2548
# Length of Launch site array: 2124
# Length of Payload array: 2017
# Length of Payload mass array: 1062
# Length of Orbit array: 1062
# Length of Customer array: 1054
# Length of Launch outcome array: 1052
# Length of Booster landing array: 1052
# Flight No.: 27
# Date: 18 July 2016
# Time: 04:45
# Version Booster: F9 FT
# Launch site: Cape Canaveral
# Payload: SpaceX CRS-9
# Payload mass: 2,257 kg
# Orbit: LEO
# Customer: <td><a href="/wiki/NASA" title="NASA">NASA</a> (<a href="/wiki/Commercial_Resupply_Services" title="Commercial Resupply Services">CRS</a>)
# </td>
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 27
# Length of Flight No. array: 2982
# Length of Date array: 2875
# Length of Time array: 2768
# Length of Version Booster array: 2549
# Length of Launch site array: 2125
# Length of Payload array: 2018
# Length of Payload mass array: 1063
# Length of Orbit array: 1063
# Length of Customer array: 1055
# Length of Launch outcome array: 1053
# Length of Booster landing array: 1053
# Flight No.: 28
# Date: 14 August 2016
# Time: 05:26
# Version Booster: F9 FT
# Launch site: Cape Canaveral
# Payload: JCSAT-16
# Payload mass: 4,600 kg
# Orbit: GTO
# Customer: <td><a class="mw-redirect" href="/wiki/SKY_Perfect_JSAT_Group" title="SKY Perfect JSAT Group">SKY Perfect JSAT Group</a>
# </td>
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 28
# Length of Flight No. array: 2983
# Length of Date array: 2876
# Length of Time array: 2769
# Length of Version Booster array: 2550
# Length of Launch site array: 2126
# Length of Payload array: 2019
# Length of Payload mass array: 1064
# Length of Orbit array: 1064
# Length of Customer array: 1056
# Length of Launch outcome array: 1054
# Length of Booster landing array: 1054
# Flight No.: 29
# Date: 14 January 2017
# Time: 17:54
# Version Booster: F9 FT
# Launch site: VAFB
# Payload: Iridium NEXT
# Payload mass: 9,600 kg
# Orbit: Polar
# Customer: <td><a href="/wiki/Iridium_Communications" title="Iridium Communications">Iridium Communications</a>
# </td>
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 29
# Length of Flight No. array: 2984
# Length of Date array: 2877
# Length of Time array: 2770
# Length of Version Booster array: 2551
# Length of Launch site array: 2127
# Length of Payload array: 2020
# Length of Payload mass array: 1065
# Length of Orbit array: 1065
# Length of Customer array: 1057
# Length of Launch outcome array: 1055
# Length of Booster landing array: 1055
# Flight No.: 30
# Date: 19 February 2017
# Time: 14:39
# Version Booster: F9 FT
# Launch site: KSC
# Payload: SpaceX CRS-10
# Payload mass: 2,490 kg
# Orbit: LEO
# Customer: <td><a href="/wiki/NASA" title="NASA">NASA</a> (<a href="/wiki/Commercial_Resupply_Services" title="Commercial Resupply Services">CRS</a>)
# </td>
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 30
# Length of Flight No. array: 2985
# Length of Date array: 2878
# Length of Time array: 2771
# Length of Version Booster array: 2552
# Length of Launch site array: 2128
# Length of Payload array: 2021
# Length of Payload mass array: 1066
# Length of Orbit array: 1066
# Length of Customer array: 1058
# Length of Launch outcome array: 1056
# Length of Booster landing array: 1056
# Flight No.: 31
# Date: 16 March 2017
# Time: 06:00
# Version Booster: F9 FT
# Launch site: KSC
# Payload: EchoStar 23
# Payload mass: 5,600 kg
# Orbit: GTO
# Customer: <td><a href="/wiki/EchoStar" title="EchoStar">EchoStar</a>
# </td>
# Launch outcome: Success
#
# Booster landing: No attempt
# Extracted row: 31
# Length of Flight No. array: 2986
# Length of Date array: 2879
# Length of Time array: 2772
# Length of Version Booster array: 2553
# Length of Launch site array: 2129
# Length of Payload array: 2022
# Length of Payload mass array: 1067
# Length of Orbit array: 1067
# Length of Customer array: 1059
# Length of Launch outcome array: 1057
# Length of Booster landing array: 1057
# Flight No.: 32
# Date: 30 March 2017
# Time: 22:27
# Version Booster: F9 FT♺
# Launch site: KSC
# Payload: SES-10
# Payload mass: 5,300 kg
# Orbit: GTO
# Customer: <td><a href="/wiki/SES_S.A." title="SES S.A.">SES</a>
# </td>
# Launch outcome: Success
# Booster landing: Success
# Extracted row: 32
# Length of Flight No. array: 2987
# Length of Date array: 2880
# Length of Time array: 2773
# Length of Version Booster array: 2554
# Length of Launch site array: 2130
# Length of Payload array: 2023
# Length of Payload mass array: 1068
# Length of Orbit array: 1068
# Length of Customer array: 1060
# Length of Launch outcome array: 1058
# Length of Booster landing array: 1058
# Flight No.: 33
# Date: 1 May 2017
# Time: 11:15
# Version Booster: F9 FT
# Launch site: KSC
# Payload: NROL-76
# Payload mass: C
# Orbit: LEO
# Customer: <td><a href="/wiki/National_Reconnaissance_Office" title="National Reconnaissance Office">NRO</a>
# </td>
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 33
# Length of Flight No. array: 2988
# Length of Date array: 2881
# Length of Time array: 2774
# Length of Version Booster array: 2555
# Length of Launch site array: 2131
# Length of Payload array: 2024
# Length of Payload mass array: 1069
# Length of Orbit array: 1069
# Length of Customer array: 1061
# Length of Launch outcome array: 1059
# Length of Booster landing array: 1059
# Flight No.: 34
# Date: 15 May 2017
# Time: 23:21
# Version Booster: F9 FT
# Launch site: KSC
# Payload: Inmarsat-5 F4
# Payload mass: 6,070 kg
# Orbit: GTO
# Customer: <td><a href="/wiki/Inmarsat" title="Inmarsat">Inmarsat</a>
# </td>
# Launch outcome: Success
#
# Booster landing: No attempt
# Extracted row: 34
# Length of Flight No. array: 2989
# Length of Date array: 2882
# Length of Time array: 2775
# Length of Version Booster array: 2556
# Length of Launch site array: 2132
# Length of Payload array: 2025
# Length of Payload mass array: 1070
# Length of Orbit array: 1070
# Length of Customer array: 1062
# Length of Launch outcome array: 1060
# Length of Booster landing array: 1060
# Flight No.: 35
# Date: 3 June 2017
# Time: 21:07
# Version Booster: F9 FT
# Launch site: KSC
# Payload: SpaceX CRS-11
# Payload mass: 2,708 kg
# Orbit: LEO
# Customer: <td><a href="/wiki/NASA" title="NASA">NASA</a> (<a href="/wiki/Commercial_Resupply_Services" title="Commercial Resupply Services">CRS</a>)
# </td>
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 35
# Length of Flight No. array: 2990
# Length of Date array: 2883
# Length of Time array: 2776
# Length of Version Booster array: 2557
# Length of Launch site array: 2133
# Length of Payload array: 2026
# Length of Payload mass array: 1071
# Length of Orbit array: 1071
# Length of Customer array: 1063
# Length of Launch outcome array: 1061
# Length of Booster landing array: 1061
# Flight No.: 36
# Date: 23 June 2017
# Time: 19:10
# Version Booster: F9 FTB1029.2
# Launch site: KSC
# Payload: BulgariaSat-1
# Payload mass: 3,669 kg
# Orbit: GTO
# Customer: <td><a href="/wiki/Bulsatcom" title="Bulsatcom">Bulsatcom</a>
# </td>
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 36
# Length of Flight No. array: 2991
# Length of Date array: 2884
# Length of Time array: 2777
# Length of Version Booster array: 2558
# Length of Launch site array: 2134
# Length of Payload array: 2027
# Length of Payload mass array: 1072
# Length of Orbit array: 1072
# Length of Customer array: 1064
# Length of Launch outcome array: 1062
# Length of Booster landing array: 1062
# Flight No.: 37
# Date: 25 June 2017
# Time: 20:25
# Version Booster: F9 FT
# Launch site: VAFB
# Payload: Iridium NEXT
# Payload mass: 9,600 kg
# Orbit: LEO
# Customer: <td><a href="/wiki/Iridium_Communications" title="Iridium Communications">Iridium Communications</a>
# </td>
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 37
# Length of Flight No. array: 2992
# Length of Date array: 2885
# Length of Time array: 2778
# Length of Version Booster array: 2559
# Length of Launch site array: 2135
# Length of Payload array: 2028
# Length of Payload mass array: 1073
# Length of Orbit array: 1073
# Length of Customer array: 1065
# Length of Launch outcome array: 1063
# Length of Booster landing array: 1063
# Flight No.: 38
# Date: 5 July 2017
# Time: 23:38
# Version Booster: F9 FT
# Launch site: KSC
# Payload: Intelsat 35e
# Payload mass: 6,761 kg
# Orbit: GTO
# Customer: <td><a href="/wiki/Intelsat" title="Intelsat">Intelsat</a>
# </td>
# Launch outcome: Success
#
# Booster landing: No attempt
# Extracted row: 38
# Length of Flight No. array: 2993
# Length of Date array: 2886
# Length of Time array: 2779
# Length of Version Booster array: 2560
# Length of Launch site array: 2136
# Length of Payload array: 2029
# Length of Payload mass array: 1074
# Length of Orbit array: 1074
# Length of Customer array: 1066
# Length of Launch outcome array: 1064
# Length of Booster landing array: 1064
# Flight No.: 39
# Date: 14 August 2017
# Time: 16:31
# Version Booster: F9 B4
# Launch site: KSC
# Payload: SpaceX CRS-12
# Payload mass: 3,310 kg
# Orbit: LEO
# Customer: <td><a href="/wiki/NASA" title="NASA">NASA</a> (<a href="/wiki/Commercial_Resupply_Services" title="Commercial Resupply Services">CRS</a>)
# </td>
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 39
# Length of Flight No. array: 2994
# Length of Date array: 2887
# Length of Time array: 2780
# Length of Version Booster array: 2561
# Length of Launch site array: 2137
# Length of Payload array: 2030
# Length of Payload mass array: 1075
# Length of Orbit array: 1075
# Length of Customer array: 1067
# Length of Launch outcome array: 1065
# Length of Booster landing array: 1065
# Flight No.: 40
# Date: 24 August 2017
# Time: 18:51
# Version Booster: F9 FT
# Launch site: VAFB
# Payload: Formosat-5
# Payload mass: 475 kg
# Orbit: SSO
# Customer: <td><a class="mw-redirect" href="/wiki/National_Space_Organization" title="National Space Organization">NSPO</a>
# </td>
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 40
# Length of Flight No. array: 2995
# Length of Date array: 2888
# Length of Time array: 2781
# Length of Version Booster array: 2562
# Length of Launch site array: 2138
# Length of Payload array: 2031
# Length of Payload mass array: 1076
# Length of Orbit array: 1076
# Length of Customer array: 1068
# Length of Launch outcome array: 1066
# Length of Booster landing array: 1066
# Flight No.: 41
# Date: 7 September 2017
# Time: 14:00
# Version Booster: F9 B4
# Launch site: KSC
# Payload: Boeing X-37B
# Payload mass: 4,990 kg
# Orbit: LEO
# Customer: <td><a href="/wiki/United_States_Air_Force" title="United States Air Force">USAF</a>
# </td>
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 41
# Length of Flight No. array: 2996
# Length of Date array: 2889
# Length of Time array: 2782
# Length of Version Booster array: 2563
# Length of Launch site array: 2139
# Length of Payload array: 2032
# Length of Payload mass array: 1077
# Length of Orbit array: 1077
# Length of Customer array: 1069
# Length of Launch outcome array: 1067
# Length of Booster landing array: 1067
# Flight No.: 42
# Date: 9 October 2017
# Time: 12:37
# Version Booster: F9 B4
# Launch site: VAFB
# Payload: Iridium NEXT
# Payload mass: 9,600 kg
# Orbit: Polar
# Customer: <td><a href="/wiki/Iridium_Communications" title="Iridium Communications">Iridium Communications</a>
# </td>
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 42
# Length of Flight No. array: 2997
# Length of Date array: 2890
# Length of Time array: 2783
# Length of Version Booster array: 2564
# Length of Launch site array: 2140
# Length of Payload array: 2033
# Length of Payload mass array: 1078
# Length of Orbit array: 1078
# Length of Customer array: 1070
# Length of Launch outcome array: 1068
# Length of Booster landing array: 1068
# Flight No.: 43
# Date: 11 October 2017
# Time: 22:53:00
# Version Booster: F9 FTB1031.2
# Launch site: KSC
# Payload: SES-11
# Payload mass: 5,200 kg
# Orbit: GTO
# Customer: <td><link href="mw-data:TemplateStyles:r1126788409" rel="mw-deduplicated-inline-style"/><div class="plainlist">
# <ul><li><a href="/wiki/SES_S.A." title="SES S.A.">SES S.A.</a></li>
# <li><a href="/wiki/EchoStar" title="EchoStar">EchoStar</a></li></ul>
# </div>
# </td>
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 43
# Length of Flight No. array: 2998
# Length of Date array: 2891
# Length of Time array: 2784
# Length of Version Booster array: 2565
# Length of Launch site array: 2141
# Length of Payload array: 2034
# Length of Payload mass array: 1079
# Length of Orbit array: 1079
# Length of Customer array: 1071
# Length of Launch outcome array: 1069
# Length of Booster landing array: 1069
# Flight No.: 44
# Date: 30 October 2017
# Time: 19:34
# Version Booster: F9 B4
# Launch site: KSC
# Payload: Koreasat 5A
# Payload mass: 3,500 kg
# Orbit: GTO
# Customer: <td><a href="/wiki/KT_Corporation" title="KT Corporation">KT Corporation</a>
# </td>
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 44
# Length of Flight No. array: 2999
# Length of Date array: 2892
# Length of Time array: 2785
# Length of Version Booster array: 2566
# Length of Launch site array: 2142
# Length of Payload array: 2035
# Length of Payload mass array: 1080
# Length of Orbit array: 1080
# Length of Customer array: 1072
# Length of Launch outcome array: 1070
# Length of Booster landing array: 1070
# Flight No.: 45
# Date: 15 December 2017
# Time: 15:36
# Version Booster: F9 FTB1035.2
# Launch site: Cape Canaveral
# Payload: SpaceX CRS-13
# Payload mass: 2,205 kg
# Orbit: LEO
# Customer: <td><a href="/wiki/NASA" title="NASA">NASA</a> (<a href="/wiki/Commercial_Resupply_Services" title="Commercial Resupply Services">CRS</a>)
# </td>
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 45
# Length of Flight No. array: 3000
# Length of Date array: 2893
# Length of Time array: 2786
# Length of Version Booster array: 2567
# Length of Launch site array: 2143
# Length of Payload array: 2036
# Length of Payload mass array: 1081
# Length of Orbit array: 1081
# Length of Customer array: 1073
# Length of Launch outcome array: 1071
# Length of Booster landing array: 1071
# Flight No.: 46
# Date: 23 December 2017
# Time: 01:27
# Version Booster: F9 FTB1036.2
# Launch site: VAFB
# Payload: Iridium NEXT
# Payload mass: 9,600 kg
# Orbit: Polar
# Customer: <td><a href="/wiki/Iridium_Communications" title="Iridium Communications">Iridium Communications</a>
# </td>
# Launch outcome: Success
# Booster landing: Controlled
# Extracted row: 46
# Length of Flight No. array: 3001
# Length of Date array: 2894
# Length of Time array: 2787
# Length of Version Booster array: 2568
# Length of Launch site array: 2144
# Length of Payload array: 2037
# Length of Payload mass array: 1082
# Length of Orbit array: 1082
# Length of Customer array: 1074
# Length of Launch outcome array: 1072
# Length of Booster landing array: 1072
# Flight No.: 47
# Date: 8 January 2018
# Time: 01:00
# Version Booster: F9 B4
# Launch site: CCAFS
# Payload: Zuma
# Payload mass: C
# Orbit: LEO
# Customer: <td><a href="/wiki/Northrop_Grumman" title="Northrop Grumman">Northrop Grumman</a> <sup class="reference" id="cite_ref-249"><a href="#cite_note-249">[f]</a></sup><sup class="reference" id="cite_ref-zuma_246-2"><a href="#cite_note-zuma-246">[238]</a></sup>
# </td>
# Launch outcome: Success
# Booster landing: Success
# Extracted row: 47
# Length of Flight No. array: 3002
# Length of Date array: 2895
# Length of Time array: 2788
# Length of Version Booster array: 2569
# Length of Launch site array: 2145
# Length of Payload array: 2038
# Length of Payload mass array: 1083
# Length of Orbit array: 1083
# Length of Customer array: 1075
# Length of Launch outcome array: 1073
# Length of Booster landing array: 1073
# Flight No.: 48
# Date: 31 January 2018
# Time: 21:25
# Version Booster: F9 FTB1032.2
# Launch site: CCAFS
# Payload: GovSat-1
# Payload mass: 4,230 kg
# Orbit: GTO
# Customer: <td><a href="/wiki/SES_S.A." title="SES S.A.">SES</a>
# </td>
# Launch outcome: Success
# Booster landing: Controlled
# Extracted row: 48
# Length of Flight No. array: 3003
# Length of Date array: 2896
# Length of Time array: 2789
# Length of Version Booster array: 2570
# Length of Launch site array: 2146
# Length of Payload array: 2039
# Length of Payload mass array: 1084
# Length of Orbit array: 1084
# Length of Customer array: 1076
# Length of Launch outcome array: 1074
# Length of Booster landing array: 1074
# Flight No.: 49
# Date: 22 February 2018
# Time: 14:17
# Version Booster: F9 FTB1038.2
# Launch site: VAFB
# Payload: Paz
# Payload mass: 2,150 kg
# Orbit: SSO
# Customer: <td><link href="mw-data:TemplateStyles:r1126788409" rel="mw-deduplicated-inline-style"/><div class="plainlist">
# <ul><li><a href="/wiki/Hisdesat" title="Hisdesat">Hisdesat</a></li>
# <li><a href="/wiki/ExactEarth" title="ExactEarth">exactEarth</a></li>
# <li><a href="/wiki/SpaceX" title="SpaceX">SpaceX</a></li></ul>
# </div>
# </td>
# Launch outcome: Success
# Booster landing: No attempt
# Extracted row: 49
# Length of Flight No. array: 3004
# Length of Date array: 2897
# Length of Time array: 2790
# Length of Version Booster array: 2571
# Length of Launch site array: 2147
# Length of Payload array: 2040
# Length of Payload mass array: 1085
# Length of Orbit array: 1085
# Length of Customer array: 1077
# Length of Launch outcome array: 1075
# Length of Booster landing array: 1075
# Flight No.: 50
# Date: 6 March 2018
# Time: 05:33
# Version Booster: F9 B4
# Launch site: CCAFS
# Payload: Hispasat 30W-6
# Payload mass: 6,092 kg
# Orbit: GTO
# Customer: <td><link href="mw-data:TemplateStyles:r1126788409" rel="mw-deduplicated-inline-style"/><div class="plainlist">
# <ul><li><a href="/wiki/Hispasat" title="Hispasat">Hispasat</a><sup class="reference" id="cite_ref-spx20150914_286-1"><a href="#cite_note-spx20150914-286">[277]</a></sup></li>
# <li><a href="/wiki/NovaWurks" title="NovaWurks">NovaWurks</a></li></ul>
# </div>
# </td>
# Launch outcome: Success
# Booster landing: No attempt
# Extracted row: 50
# Length of Flight No. array: 3005
# Length of Date array: 2898
# Length of Time array: 2791
# Length of Version Booster array: 2572
# Length of Launch site array: 2148
# Length of Payload array: 2041
# Length of Payload mass array: 1086
# Length of Orbit array: 1086
# Length of Customer array: 1078
# Length of Launch outcome array: 1076
# Length of Booster landing array: 1076
# Flight No.: 51
# Date: 30 March 2018
# Time: 14:14
# Version Booster: F9 B4B1041.2
# Launch site: VAFB
# Payload: Iridium NEXT
# Payload mass: 9,600 kg
# Orbit: Polar
# Customer: <td><a href="/wiki/Iridium_Communications" title="Iridium Communications">Iridium Communications</a>
# </td>
# Launch outcome: Success
# Booster landing: No attempt
# Extracted row: 51
# Length of Flight No. array: 3006
# Length of Date array: 2899
# Length of Time array: 2792
# Length of Version Booster array: 2573
# Length of Launch site array: 2149
# Length of Payload array: 2042
# Length of Payload mass array: 1087
# Length of Orbit array: 1087
# Length of Customer array: 1079
# Length of Launch outcome array: 1077
# Length of Booster landing array: 1077
# Flight No.: 52
# Date: 2 April 2018
# Time: 20:30
# Version Booster: F9 B4B1039.2
# Launch site: CCAFS
# Payload: SpaceX CRS-14
# Payload mass: 2,647 kg
# Orbit: LEO
# Customer: <td><a href="/wiki/NASA" title="NASA">NASA</a> (<a href="/wiki/Commercial_Resupply_Services" title="Commercial Resupply Services">CRS</a>)
# </td>
# Launch outcome: Success
# Booster landing: No attempt
# Extracted row: 52
# Length of Flight No. array: 3007
# Length of Date array: 2900
# Length of Time array: 2793
# Length of Version Booster array: 2574
# Length of Launch site array: 2150
# Length of Payload array: 2043
# Length of Payload mass array: 1088
# Length of Orbit array: 1088
# Length of Customer array: 1080
# Length of Launch outcome array: 1078
# Length of Booster landing array: 1078
# Flight No.: 53
# Date: 18 April 2018
# Time: 22:51
# Version Booster: F9 B4
# Launch site: CCAFS
# Payload: Transiting Exoplanet Survey Satellite
# Payload mass: 362 kg
# Orbit: HEO
# Customer: <td><a href="/wiki/NASA" title="NASA">NASA</a> (<a class="mw-redirect" href="/wiki/Launch_Services_Program" title="Launch Services Program">LSP</a>)
# </td>
# Launch outcome: Success
# Booster landing: Success
# Extracted row: 53
# Length of Flight No. array: 3008
# Length of Date array: 2901
# Length of Time array: 2794
# Length of Version Booster array: 2575
# Length of Launch site array: 2151
# Length of Payload array: 2044
# Length of Payload mass array: 1089
# Length of Orbit array: 1089
# Length of Customer array: 1081
# Length of Launch outcome array: 1079
# Length of Booster landing array: 1079
# Flight No.: 54
# Date: 11 May 2018
# Time: 20:14
# Version Booster: F9 B5B1046.1
# Launch site: KSC
# Payload: Bangabandhu-1
# Payload mass: 3,600 kg
# Orbit: GTO
# Customer: <td><a href="/wiki/Thales_Alenia_Space" title="Thales Alenia Space">Thales-Alenia</a> / <a href="/wiki/Bangladesh_Telecommunication_Regulatory_Commission" title="Bangladesh Telecommunication Regulatory Commission">BTRC</a>
# </td>
# Launch outcome: Success
# Booster landing: Success
# Extracted row: 54
# Length of Flight No. array: 3009
# Length of Date array: 2902
# Length of Time array: 2795
# Length of Version Booster array: 2576
# Length of Launch site array: 2152
# Length of Payload array: 2045
# Length of Payload mass array: 1090
# Length of Orbit array: 1090
# Length of Customer array: 1082
# Length of Launch outcome array: 1080
# Length of Booster landing array: 1080
# Flight No.: 55
# Date: 22 May 2018
# Time: 19:47
# Version Booster: F9 B4B1043.2
# Launch site: VAFB
# Payload: Iridium NEXT
# Payload mass: 6,460 kg
# Orbit: Polar
# Customer: <td><link href="mw-data:TemplateStyles:r1126788409" rel="mw-deduplicated-inline-style"/><div class="plainlist">
# <ul><li><a href="/wiki/Iridium_Communications" title="Iridium Communications">Iridium Communications</a></li>
# <li><a href="/wiki/GFZ_German_Research_Centre_for_Geosciences" title="GFZ German Research Centre for Geosciences">GFZ</a> • <a href="/wiki/NASA" title="NASA">NASA</a></li></ul>
# </div>
# </td>
# Launch outcome: Success
# Booster landing: No attempt
# Extracted row: 55
# Length of Flight No. array: 3010
# Length of Date array: 2903
# Length of Time array: 2796
# Length of Version Booster array: 2577
# Length of Launch site array: 2153
# Length of Payload array: 2046
# Length of Payload mass array: 1091
# Length of Orbit array: 1091
# Length of Customer array: 1083
# Length of Launch outcome array: 1081
# Length of Booster landing array: 1081
# Flight No.: 56
# Date: 4 June 2018
# Time: 04:45
# Version Booster: F9 B4B1040.2
# Launch site: CCAFS
# Payload: SES-12
# Payload mass: 5,384 kg
# Orbit: GTO
# Customer: <td><a href="/wiki/SES_S.A." title="SES S.A.">SES</a>
# </td>
# Launch outcome: Success
# Booster landing: No attempt
# Extracted row: 56
# Length of Flight No. array: 3011
# Length of Date array: 2904
# Length of Time array: 2797
# Length of Version Booster array: 2578
# Length of Launch site array: 2154
# Length of Payload array: 2047
# Length of Payload mass array: 1092
# Length of Orbit array: 1092
# Length of Customer array: 1084
# Length of Launch outcome array: 1082
# Length of Booster landing array: 1082
# Flight No.: 57
# Date: 29 June 2018
# Time: 09:42
# Version Booster: F9 B4B1045.2
# Launch site: CCAFS
# Payload: SpaceX CRS-15
# Payload mass: 2,697 kg
# Orbit: LEO
# Customer: <td><a href="/wiki/NASA" title="NASA">NASA</a> (<a href="/wiki/Commercial_Resupply_Services" title="Commercial Resupply Services">CRS</a>)
# </td>
# Launch outcome: Success
# Booster landing: No attempt
# Extracted row: 57
# Length of Flight No. array: 3012
# Length of Date array: 2905
# Length of Time array: 2798
# Length of Version Booster array: 2579
# Length of Launch site array: 2155
# Length of Payload array: 2048
# Length of Payload mass array: 1093
# Length of Orbit array: 1093
# Length of Customer array: 1085
# Length of Launch outcome array: 1083
# Length of Booster landing array: 1083
# Flight No.: 58
# Date: 22 July 2018
# Time: 05:50
# Version Booster: F9 B5
# Launch site: CCAFS
# Payload: Telstar 19V
# Payload mass: 7,075 kg
# Orbit: GTO
# Customer: <td><a href="/wiki/Telesat" title="Telesat">Telesat</a>
# </td>
# Launch outcome: Success
# Booster landing: Success
# Extracted row: 58
# Length of Flight No. array: 3013
# Length of Date array: 2906
# Length of Time array: 2799
# Length of Version Booster array: 2580
# Length of Launch site array: 2156
# Length of Payload array: 2049
# Length of Payload mass array: 1094
# Length of Orbit array: 1094
# Length of Customer array: 1086
# Length of Launch outcome array: 1084
# Length of Booster landing array: 1084
# Flight No.: 59
# Date: 25 July 2018
# Time: 11:39
# Version Booster: F9 B5B1048
# Launch site: VAFB
# Payload: Iridium NEXT
# Payload mass: 9,600 kg
# Orbit: Polar
# Customer: <td><a href="/wiki/Iridium_Communications" title="Iridium Communications">Iridium Communications</a>
# </td>
# Launch outcome: Success
# Booster landing: Success
# Extracted row: 59
# Length of Flight No. array: 3014
# Length of Date array: 2907
# Length of Time array: 2800
# Length of Version Booster array: 2581
# Length of Launch site array: 2157
# Length of Payload array: 2050
# Length of Payload mass array: 1095
# Length of Orbit array: 1095
# Length of Customer array: 1087
# Length of Launch outcome array: 1085
# Length of Booster landing array: 1085
# Flight No.: 60
# Date: 7 August 2018
# Time: 05:18
# Version Booster: F9 B5B1046.2
# Launch site: CCAFS
# Payload: Merah Putih
# Payload mass: 5,800 kg
# Orbit: GTO
# Customer: <td><a href="/wiki/Telkom_Indonesia" title="Telkom Indonesia">Telkom Indonesia</a>
# </td>
# Launch outcome: Success
# Booster landing: Success
# Extracted row: 60
# Length of Flight No. array: 3015
# Length of Date array: 2908
# Length of Time array: 2801
# Length of Version Booster array: 2582
# Length of Launch site array: 2158
# Length of Payload array: 2051
# Length of Payload mass array: 1096
# Length of Orbit array: 1096
# Length of Customer array: 1088
# Length of Launch outcome array: 1086
# Length of Booster landing array: 1086
# Flight No.: 61
# Date: 10 September 2018
# Time: 04:45
# Version Booster: F9 B5
# Launch site: CCAFS
# Payload: Telstar 18V
# Payload mass: 7,060 kg
# Orbit: GTO
# Customer: <td><a href="/wiki/Telesat" title="Telesat">Telesat</a>
# </td>
# Launch outcome: Success
# Booster landing: Success
# Extracted row: 61
# Length of Flight No. array: 3016
# Length of Date array: 2909
# Length of Time array: 2802
# Length of Version Booster array: 2583
# Length of Launch site array: 2159
# Length of Payload array: 2052
# Length of Payload mass array: 1097
# Length of Orbit array: 1097
# Length of Customer array: 1089
# Length of Launch outcome array: 1087
# Length of Booster landing array: 1087
# Flight No.: 62
# Date: 8 October 2018
# Time: 02:22
# Version Booster: F9 B5B1048.2
# Launch site: VAFB
# Payload: SAOCOM 1A
# Payload mass: 3,000 kg
# Orbit: SSO
# Customer: <td><a href="/wiki/Comisi%C3%B3n_Nacional_de_Actividades_Espaciales" title="Comisión Nacional de Actividades Espaciales">CONAE</a>
# </td>
# Launch outcome: Success
# Booster landing: Success
# Extracted row: 62
# Length of Flight No. array: 3017
# Length of Date array: 2910
# Length of Time array: 2803
# Length of Version Booster array: 2584
# Length of Launch site array: 2160
# Length of Payload array: 2053
# Length of Payload mass array: 1098
# Length of Orbit array: 1098
# Length of Customer array: 1090
# Length of Launch outcome array: 1088
# Length of Booster landing array: 1088
# Flight No.: 63
# Date: 15 November 2018
# Time: 20:46
# Version Booster: F9 B5B1047.2
# Launch site: KSC
# Payload: Es'hail 2
# Payload mass: 5,300 kg
# Orbit: GTO
# Customer: <td><a href="/wiki/Es%27hailSat" title="Es'hailSat">Es'hailSat</a>
# </td>
# Launch outcome: Success
# Booster landing: Success
# Extracted row: 63
# Length of Flight No. array: 3018
# Length of Date array: 2911
# Length of Time array: 2804
# Length of Version Booster array: 2585
# Length of Launch site array: 2161
# Length of Payload array: 2054
# Length of Payload mass array: 1099
# Length of Orbit array: 1099
# Length of Customer array: 1091
# Length of Launch outcome array: 1089
# Length of Booster landing array: 1089
# Flight No.: 64
# Date: 3 December 2018
# Time: 18:34:05
# Version Booster: F9 B5B1046.3
# Launch site: VAFB
# Payload: SSO-A
# Payload mass: ~4,000 kg
# Orbit: SSO
# Customer: <td><a href="/wiki/Spaceflight_Industries" title="Spaceflight Industries">Spaceflight Industries</a>
# </td>
# Launch outcome: Success
# Booster landing: Success
# Extracted row: 64
# Length of Flight No. array: 3019
# Length of Date array: 2912
# Length of Time array: 2805
# Length of Version Booster array: 2586
# Length of Launch site array: 2162
# Length of Payload array: 2055
# Length of Payload mass array: 1100
# Length of Orbit array: 1100
# Length of Customer array: 1092
# Length of Launch outcome array: 1090
# Length of Booster landing array: 1090
# Flight No.: 65
# Date: 5 December 2018
# Time: 18:16
# Version Booster: F9 B5
# Launch site: CCAFS
# Payload: SpaceX CRS-16
# Payload mass: 2,500 kg
# Orbit: LEO
# Customer: <td><a href="/wiki/NASA" title="NASA">NASA</a> (<a href="/wiki/Commercial_Resupply_Services" title="Commercial Resupply Services">CRS</a>)
# </td>
# Launch outcome: Success
#
# Booster landing: Failure
# Extracted row: 65
# Length of Flight No. array: 3020
# Length of Date array: 2913
# Length of Time array: 2806
# Length of Version Booster array: 2587
# Length of Launch site array: 2163
# Length of Payload array: 2056
# Length of Payload mass array: 1101
# Length of Orbit array: 1101
# Length of Customer array: 1093
# Length of Launch outcome array: 1091
# ...
#
# Booster landing: Success
# Extracted row: 98
# Length of Flight No. array: 3053
# Length of Date array: 2946
# Length of Time array: 2839
# Length of Version Booster array: 2620
# Length of Launch site array: 2196
# Length of Payload array: 2089
# Length of Payload mass array: 1134
# Length of Orbit array: 1134
# Length of Customer array: 1126
# Length of Launch outcome array: 1124
# Length of Booster landing array: 1124
# Flight No.: 99
# Date: 21 November 2020
# Time: 17:17:08
# Version Booster: F9 B5
# Launch site: VAFB
# Payload: Sentinel-6 Michael Freilich (Jason-CS A)
# Payload mass: 1,192 kg
# Orbit: LEO
# Customer: <td><a href="/wiki/NASA" title="NASA">NASA</a> / <a class="mw-redirect" href="/wiki/NOAA" title="NOAA">NOAA</a> / <a class="mw-redirect" href="/wiki/ESA" title="ESA">ESA</a> / <a class="mw-redirect" href="/wiki/EUMETSAT" title="EUMETSAT">EUMETSAT</a>
# </td>
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 99
# Length of Flight No. array: 3054
# Length of Date array: 2947
# Length of Time array: 2840
# Length of Version Booster array: 2621
# Length of Launch site array: 2197
# Length of Payload array: 2090
# Length of Payload mass array: 1135
# Length of Orbit array: 1135
# Length of Customer array: 1127
# Length of Launch outcome array: 1125
# Length of Booster landing array: 1125
# Flight No.: 100
# Date: 25 November 2020
# Time: 02:13
# Version Booster: F9 B5 ♺
# Launch site: CCAFS
# Payload: Starlink
# Payload mass: 15,600 kg
# Orbit: LEO
# Customer: <td><a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# </td>
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 100
# Length of Flight No. array: 3055
# Length of Date array: 2948
# Length of Time array: 2841
# Length of Version Booster array: 2622
# Length of Launch site array: 2198
# Length of Payload array: 2091
# Length of Payload mass array: 1136
# Length of Orbit array: 1136
# Length of Customer array: 1128
# Length of Launch outcome array: 1126
# Length of Booster landing array: 1126
# Flight No.: 101
# Date: 6 December 2020
# Time: 16:17:08
# Version Booster: F9 B5 ♺
# Launch site: KSC
# Payload: SpaceX CRS-21
# Payload mass: 2,972 kg
# Orbit: LEO
# Customer: <td><a href="/wiki/NASA" title="NASA">NASA</a> (<a href="/wiki/Commercial_Resupply_Services" title="Commercial Resupply Services">CRS</a>)
# </td>
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 101
# Length of Flight No. array: 3056
# Length of Date array: 2949
# Length of Time array: 2842
# Length of Version Booster array: 2623
# Length of Launch site array: 2199
# Length of Payload array: 2092
# Length of Payload mass array: 1137
# Length of Orbit array: 1137
# Length of Customer array: 1129
# Length of Launch outcome array: 1127
# Length of Booster landing array: 1127
# Flight No.: 102
# Date: 13 December 2020
# Time: 17:30:00
# Version Booster: F9 B5 ♺
# Launch site: CCSFSSLC-40
# Payload: SXM-7
# Payload mass: 7,000 kg
# Orbit: GTO
# Customer: <td><a href="/wiki/Sirius_XM" title="Sirius XM">Sirius XM</a>
# </td>
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 102
# Length of Flight No. array: 3057
# Length of Date array: 2950
# Length of Time array: 2843
# Length of Version Booster array: 2624
# Length of Launch site array: 2200
# Length of Payload array: 2093
# Length of Payload mass array: 1138
# Length of Orbit array: 1138
# Length of Customer array: 1130
# Length of Launch outcome array: 1128
# Length of Booster landing array: 1128
# Flight No.: 103
# Date: 19 December 2020
# Time: 14:00:00
# Version Booster: F9 B5 ♺
# Launch site: KSC
# Payload: NROL-108
# Payload mass: C
# Orbit: LEO
# Customer: <td><a href="/wiki/National_Reconnaissance_Office" title="National Reconnaissance Office">NRO</a>
# </td>
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 103
# Length of Flight No. array: 3058
# Length of Date array: 2951
# Length of Time array: 2844
# Length of Version Booster array: 2625
# Length of Launch site array: 2201
# Length of Payload array: 2094
# Length of Payload mass array: 1139
# Length of Orbit array: 1139
# Length of Customer array: 1131
# Length of Launch outcome array: 1129
# Length of Booster landing array: 1129
# Flight No.: 104
# Date: 8 January 2021
# Time: 02:15
# Version Booster: F9 B5
# Launch site: CCSFS
# Payload: Türksat 5A
# Payload mass: 3,500 kg
# Orbit: GTO
# Customer: <td><a href="/wiki/T%C3%BCrksat_(company)" title="Türksat (company)">Türksat</a>
# </td>
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 104
# Length of Flight No. array: 3059
# Length of Date array: 2952
# Length of Time array: 2845
# Length of Version Booster array: 2626
# Length of Launch site array: 2202
# Length of Payload array: 2095
# Length of Payload mass array: 1140
# Length of Orbit array: 1140
# Length of Customer array: 1132
# Length of Launch outcome array: 1130
# Length of Booster landing array: 1130
# Flight No.: 105
# Date: 20 January 2021
# Time: 13:02
# Version Booster: F9 B5B1051.8
# Launch site: KSC
# Payload: Starlink
# Payload mass: 15,600 kg
# Orbit: LEO
# Customer: <td><a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# </td>
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 105
# Length of Flight No. array: 3060
# Length of Date array: 2953
# Length of Time array: 2846
# Length of Version Booster array: 2627
# Length of Launch site array: 2203
# Length of Payload array: 2096
# Length of Payload mass array: 1141
# Length of Orbit array: 1141
# Length of Customer array: 1133
# Length of Launch outcome array: 1131
# Length of Booster landing array: 1131
# Flight No.: 106
# Date: 24 January 2021
# Time: 15:00
# Version Booster: F9 B5B1058.5
# Launch site: CCSFS
# Payload: Transporter-1
# Payload mass: ~5,000 kg
# Orbit: SSO
# Customer: <td>Various
# </td>
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 106
# Length of Flight No. array: 3061
# Length of Date array: 2954
# Length of Time array: 2847
# Length of Version Booster array: 2628
# Length of Launch site array: 2204
# Length of Payload array: 2097
# Length of Payload mass array: 1142
# Length of Orbit array: 1142
# Length of Customer array: 1134
# Length of Launch outcome array: 1132
# Length of Booster landing array: 1132
# Flight No.: 107
# Date: 4 February 2021
# Time: 06:19
# Version Booster: F9 B5 ♺
# Launch site: CCSFS
# Payload: Starlink
# Payload mass: 15,600 kg
# Orbit: LEO
# Customer: <td><a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# </td>
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 107
# Length of Flight No. array: 3062
# Length of Date array: 2955
# Length of Time array: 2848
# Length of Version Booster array: 2629
# Length of Launch site array: 2205
# Length of Payload array: 2098
# Length of Payload mass array: 1143
# Length of Orbit array: 1143
# Length of Customer array: 1135
# Length of Launch outcome array: 1133
# Length of Booster landing array: 1133
# Flight No.: 108
# Date: 16 February 2021
# Time: 03:59:37
# Version Booster: F9 B5 ♺
# Launch site: CCSFS
# Payload: Starlink
# Payload mass: 15,600 kg
# Orbit: LEO
# Customer: <td><a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# </td>
# Launch outcome: Success
#
# Booster landing: Failure
# Extracted row: 108
# Length of Flight No. array: 3063
# Length of Date array: 2956
# Length of Time array: 2849
# Length of Version Booster array: 2630
# Length of Launch site array: 2206
# Length of Payload array: 2099
# Length of Payload mass array: 1144
# Length of Orbit array: 1144
# Length of Customer array: 1136
# Length of Launch outcome array: 1134
# Length of Booster landing array: 1134
# Flight No.: 109
# Date: 4 March 2021
# Time: 08:24
# Version Booster: F9 B5 ♺
# Launch site: KSC
# Payload: Starlink
# Payload mass: 15,600 kg
# Orbit: LEO
# Customer: <td><a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# </td>
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 109
# Length of Flight No. array: 3064
# Length of Date array: 2957
# Length of Time array: 2850
# Length of Version Booster array: 2631
# Length of Launch site array: 2207
# Length of Payload array: 2100
# Length of Payload mass array: 1145
# Length of Orbit array: 1145
# Length of Customer array: 1137
# Length of Launch outcome array: 1135
# Length of Booster landing array: 1135
# Flight No.: 110
# Date: 11 March 2021
# Time: 08:13:29
# Version Booster: F9 B5 ♺
# Launch site: CCSFS
# Payload: Starlink
# Payload mass: 15,600 kg
# Orbit: LEO
# Customer: <td><a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# </td>
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 110
# Length of Flight No. array: 3065
# Length of Date array: 2958
# Length of Time array: 2851
# Length of Version Booster array: 2632
# Length of Launch site array: 2208
# Length of Payload array: 2101
# Length of Payload mass array: 1146
# Length of Orbit array: 1146
# Length of Customer array: 1138
# Length of Launch outcome array: 1136
# Length of Booster landing array: 1136
# Flight No.: 111
# Date: 14 March 2021
# Time: 10:01
# Version Booster: F9 B5 ♺
# Launch site: KSC
# Payload: Starlink
# Payload mass: 15,600 kg
# Orbit: LEO
# Customer: <td><a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# </td>
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 111
# Length of Flight No. array: 3066
# Length of Date array: 2959
# Length of Time array: 2852
# Length of Version Booster array: 2633
# Length of Launch site array: 2209
# Length of Payload array: 2102
# Length of Payload mass array: 1147
# Length of Orbit array: 1147
# Length of Customer array: 1139
# Length of Launch outcome array: 1137
# Length of Booster landing array: 1137
# Flight No.: 112
# Date: 24 March 2021
# Time: 08:28
# Version Booster: F9 B5B1060.6
# Launch site: CCSFS
# Payload: Starlink
# Payload mass: 15,600 kg
# Orbit: LEO
# Customer: <td><a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# </td>
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 112
# Length of Flight No. array: 3067
# Length of Date array: 2960
# Length of Time array: 2853
# Length of Version Booster array: 2634
# Length of Launch site array: 2210
# Length of Payload array: 2103
# Length of Payload mass array: 1148
# Length of Orbit array: 1148
# Length of Customer array: 1140
# Length of Launch outcome array: 1138
# Length of Booster landing array: 1138
# Flight No.: 113
# Date: 7 April 2021
# Time: 16:34
# Version Booster: F9 B5 ♺
# Launch site: CCSFS
# Payload: Starlink
# Payload mass: 15,600 kg
# Orbit: LEO
# Customer: <td><a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# </td>
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 113
# Length of Flight No. array: 3068
# Length of Date array: 2961
# Length of Time array: 2854
# Length of Version Booster array: 2635
# Length of Launch site array: 2211
# Length of Payload array: 2104
# Length of Payload mass array: 1149
# Length of Orbit array: 1149
# Length of Customer array: 1141
# Length of Launch outcome array: 1139
# Length of Booster landing array: 1139
# Flight No.: 114
# Date: 23 April 2021
# Time: 9:49
# Version Booster: F9 B5B1061.2
# Launch site: KSC
# Payload: Crew-2
# Payload mass: ~13,000 kg
# Orbit: LEO
# Customer: <td><a href="/wiki/NASA" title="NASA">NASA</a> (<a class="mw-redirect" href="/wiki/ISS_Crew_Transportation_Services" title="ISS Crew Transportation Services">CTS</a>)<sup class="reference" id="cite_ref-CCD6_509-2"><a href="#cite_note-CCD6-509">[497]</a></sup>
# </td>
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 114
# Length of Flight No. array: 3069
# Length of Date array: 2962
# Length of Time array: 2855
# Length of Version Booster array: 2636
# Length of Launch site array: 2212
# Length of Payload array: 2105
# Length of Payload mass array: 1150
# Length of Orbit array: 1150
# Length of Customer array: 1142
# Length of Launch outcome array: 1140
# Length of Booster landing array: 1140
# Flight No.: 115
# Date: 29 April 2021
# Time: 03:44
# Version Booster: F9 B5B1060.7
# Launch site: CCSFS
# Payload: Starlink
# Payload mass: 15,600 kg
# Orbit: LEO
# Customer: <td><a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# </td>
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 115
# Length of Flight No. array: 3070
# Length of Date array: 2963
# Length of Time array: 2856
# Length of Version Booster array: 2637
# Length of Launch site array: 2213
# Length of Payload array: 2106
# Length of Payload mass array: 1151
# Length of Orbit array: 1151
# Length of Customer array: 1143
# Length of Launch outcome array: 1141
# Length of Booster landing array: 1141
# Flight No.: 116
# Date: 4 May 2021
# Time: 19:01
# Version Booster: F9 B5B1049.9
# Launch site: KSC
# Payload: Starlink
# Payload mass: 15,600 kg
# Orbit: LEO
# Customer: <td><a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# </td>
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 116
# Length of Flight No. array: 3071
# Length of Date array: 2964
# Length of Time array: 2857
# Length of Version Booster array: 2638
# Length of Launch site array: 2214
# Length of Payload array: 2107
# Length of Payload mass array: 1152
# Length of Orbit array: 1152
# Length of Customer array: 1144
# Length of Launch outcome array: 1142
# Length of Booster landing array: 1142
# Flight No.: 117
# Date: 9 May 2021
# Time: 06:42
# Version Booster: F9 B5B1051.10
# Launch site: CCSFS
# Payload: Starlink
# Payload mass: 15,600 kg
# Orbit: LEO
# Customer: <td><a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# </td>
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 117
# Length of Flight No. array: 3072
# Length of Date array: 2965
# Length of Time array: 2858
# Length of Version Booster array: 2639
# Length of Launch site array: 2215
# Length of Payload array: 2108
# Length of Payload mass array: 1153
# Length of Orbit array: 1153
# Length of Customer array: 1145
# Length of Launch outcome array: 1143
# Length of Booster landing array: 1143
# Flight No.: 118
# Date: 15 May 2021
# Time: 22:56
# Version Booster: F9 B5B1058.8
# Launch site: KSCLC-39A
# Payload: Starlink
# Payload mass: ~14,000 kg
# Orbit: LEO
# Customer: <td><a href="/wiki/SpaceX" title="SpaceX">SpaceX</a><br/> <a href="/wiki/Capella_Space" title="Capella Space">Capella Space</a> and <a href="/wiki/Tyvak" title="Tyvak">Tyvak</a>
# </td>
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 118
# Length of Flight No. array: 3073
# Length of Date array: 2966
# Length of Time array: 2859
# Length of Version Booster array: 2640
# Length of Launch site array: 2216
# Length of Payload array: 2109
# Length of Payload mass array: 1154
# Length of Orbit array: 1154
# Length of Customer array: 1146
# Length of Launch outcome array: 1144
# Length of Booster landing array: 1144
# Flight No.: 119
# Date: 26 May 2021
# Time: 18:59
# Version Booster: F9 B5B1063.2
# Launch site: CCSFSSLC-40
# Payload: Starlink
# Payload mass: 15,600 kg
# Orbit: LEO
# Customer: <td><a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# </td>
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 119
# Length of Flight No. array: 3074
# Length of Date array: 2967
# Length of Time array: 2860
# Length of Version Booster array: 2641
# Length of Launch site array: 2217
# Length of Payload array: 2110
# Length of Payload mass array: 1155
# Length of Orbit array: 1155
# Length of Customer array: 1147
# Length of Launch outcome array: 1145
# Length of Booster landing array: 1145
# Flight No.: 120
# Date: 3 June 2021
# Time: 17:29
# Version Booster: F9 B5B1067.1
# Launch site: KSC
# Payload: SpaceX CRS-22
# Payload mass: 3,328 kg
# Orbit: LEO
# Customer: <td><a href="/wiki/NASA" title="NASA">NASA</a> (<a href="/wiki/Commercial_Resupply_Services" title="Commercial Resupply Services">CRS</a>)
# </td>
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 120
# Length of Flight No. array: 3075
# Length of Date array: 2968
# Length of Time array: 2861
# Length of Version Booster array: 2642
# Length of Launch site array: 2218
# Length of Payload array: 2111
# Length of Payload mass array: 1156
# Length of Orbit array: 1156
# Length of Customer array: 1148
# Length of Launch outcome array: 1146
# Length of Booster landing array: 1146
# Flight No.: 121
# Date: 6 June 2021
# Time: 04:26
# Version Booster: F9 B5
# Launch site: CCSFS
# Payload: SXM-8
# Payload mass: 7,000 kg
# Orbit: GTO
# Customer: <td><a href="/wiki/Sirius_XM" title="Sirius XM">Sirius XM</a>
# </td>
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 121
# Length of Flight No. array: 3076
# Length of Date array: 2969
# Length of Time array: 2862
# Length of Version Booster array: 2643
# Length of Launch site array: 2219
# Length of Payload array: 2112
# Length of Payload mass array: 1157
# Length of Orbit array: 1157
# Length of Customer array: 1149
# Length of Launch outcome array: 1147
# Length of Booster landing array: 1147

# %% [markdown]
# After you have fill in the parsed launch record values into `launch_dict`, you can create a dataframe from it.

# %%
#create a numpy array from the dict
import numpy as np
np_array = np.array(list(launch_dict.values()))
#transpose the array
np_array=np_array.T
#create a dataframe from the array
import pandas as pd
df = pd.DataFrame(np_array, columns=launch_dict.keys())
df.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[73], line 3
#       1 #create a numpy array from the dict
#       2 import numpy as np
# ----> 3 np_array = np.array(list(launch_dict.values()))
#       4 #transpose the array
#       5 np_array=np_array.T
#
# ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (11,) + inhomogeneous part.

# %% [markdown]
# We can now export it to a <b>CSV</b> for the next section, but to make the answers consistent and in case you have difficulties finishing this lab.
#
# Following labs will be using a provided dataset to make each lab independent.

# %% [markdown]
# <code>df.to_csv('spacex_web_scraped.csv', index=False)</code>

# %% [markdown]
# ## Authors

# %% [markdown]
# <a href="https://www.linkedin.com/in/yan-luo-96288783/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDS0321ENSkillsNetwork26802033-2022-01-01">Yan Luo</a>

# %% [markdown]
# <a href="https://www.linkedin.com/in/nayefaboutayoun/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDS0321ENSkillsNetwork26802033-2022-01-01">Nayef Abou Tayoun</a>

# %% [markdown]
# ## Change Log

# %% [markdown]
# | Date (YYYY-MM-DD) | Version | Changed By | Change Description          |
# | ----------------- | ------- | ---------- | --------------------------- |
# | 2021-06-09        | 1.0     | Yan Luo    | Tasks updates               |
# | 2020-11-10        | 1.0     | Nayef      | Created the initial version |

# %% [markdown]
# Copyright © 2021 IBM Corporation. All rights reserved.
