# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDS0321ENSkillsNetwork26802033-2022-01-01" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Space X  Falcon 9 First Stage Landing Prediction**

# %% [markdown]
# ## Web scraping Falcon 9 and Falcon Heavy Launches Records from Wikipedia

# %% [markdown]
# Estimated time needed: **40** minutes

# %% [markdown]
# In this lab, you will be performing web scraping to collect Falcon 9 historical launch records from a Wikipedia page titled `List of Falcon 9 and Falcon Heavy launches`
#
# [https://en.wikipedia.org/wiki/List_of_Falcon\_9\_and_Falcon_Heavy_launches](https://en.wikipedia.org/wiki/List_of_Falcon\_9\_and_Falcon_Heavy_launches?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDS0321ENSkillsNetwork26802033-2022-01-01)

# %% [markdown]
# ![](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module\_1\_L2/images/Falcon9\_rocket_family.svg)

# %% [markdown]
# Falcon 9 first stage will land successfully

# %% [markdown]
# Several examples of an unsuccessful landing are shown here:

# %% [markdown]
# More specifically, the launch records are stored in a HTML table shown below:

# %% [markdown]
# ![](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module\_1\_L2/images/falcon9-launches-wiki.png)

# %% [markdown]
# ## Objectives
#
# Web scrap Falcon 9 launch records with `BeautifulSoup`:
#
# *   Extract a Falcon 9 launch records HTML table from Wikipedia
# *   Parse the table and convert it into a Pandas data frame

# %% [markdown]
# First let's import required packages for this lab

# %%
# !pip3 install beautifulsoup4
# !pip3 install requests
# Out:
# Requirement already satisfied: beautifulsoup4 in c:\users\ktpra\appdata\local\programs\python\python311\lib\site-packages (4.11.2)
# Requirement already satisfied: soupsieve>1.2 in c:\users\ktpra\appdata\local\programs\python\python311\lib\site-packages (from beautifulsoup4) (2.4)
# Requirement already satisfied: requests in c:\users\ktpra\appdata\local\programs\python\python311\lib\site-packages (2.28.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ktpra\appdata\local\programs\python\python311\lib\site-packages (from requests) (3.0.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ktpra\appdata\local\programs\python\python311\lib\site-packages (from requests) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\ktpra\appdata\local\programs\python\python311\lib\site-packages (from requests) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ktpra\appdata\local\programs\python\python311\lib\site-packages (from requests) (2022.12.7)

# %%
import sys

import requests
from bs4 import BeautifulSoup
import re
import unicodedata
import pandas as pd

# %% [markdown]
# and we will provide some helper functions for you to process web scraped HTML table

# %%
def date_time(table_cells):
    """
    This function returns the data and time from the HTML  table cell
    Input: the  element of a table data cell extracts extra row
    """
    return [data_time.strip() for data_time in list(table_cells.strings)][0:2]

def booster_version(table_cells):
    """
    This function returns the booster version from the HTML  table cell 
    Input: the  element of a table data cell extracts extra row
    """
    out=''.join([booster_version for i,booster_version in enumerate( table_cells.strings) if i%2==0][0:-1])
    return out

def landing_status(table_cells):
    """
    This function returns the landing status from the HTML table cell 
    Input: the  element of a table data cell extracts extra row
    """
    out=[i for i in table_cells.strings][0]
    return out


def get_mass(table_cells):
    mass=unicodedata.normalize("NFKD", table_cells.text).strip()
    if mass:
        mass.find("kg")
        new_mass=mass[0:mass.find("kg")+2]
    else:
        new_mass=0
    return new_mass


def extract_column_from_header(row):
    """
    This function returns the landing status from the HTML table cell 
    Input: the  element of a table data cell extracts extra row
    """
    if (row.br):
        row.br.extract()
    if row.a:
        row.a.extract()
    if row.sup:
        row.sup.extract()
        
    colunm_name = ' '.join(row.contents)
    
    # Filter the digit and empty names
    if not(colunm_name.strip().isdigit()):
        colunm_name = colunm_name.strip()
        return colunm_name

# %% [markdown]
# To keep the lab tasks consistent, you will be asked to scrape the data from a snapshot of the  `List of Falcon 9 and Falcon Heavy launches` Wikipage updated on
# `9th June 2021`

# %%
static_url = "https://en.wikipedia.org/w/index.php?title=List_of_Falcon_9_and_Falcon_Heavy_launches&oldid=1027686922"

# %% [markdown]
# Next, request the HTML page from the above URL and get a `response` object

# %% [markdown]
# ### TASK 1: Request the Falcon9 Launch Wiki page from its URL

# %% [markdown]
# First, let's perform an HTTP GET method to request the Falcon9 Launch HTML page, as an HTTP response.

# %%
# use requests.get() method with the provided static_url
# assign the response to a object
response = requests.get(static_url)

# %% [markdown]
# Create a `BeautifulSoup` object from the HTML `response`

# %%
# Use BeautifulSoup() to create a BeautifulSoup object from a response text content
soup = BeautifulSoup(response.text, 'html.parser')

# %% [markdown]
# Print the page title to verify if the `BeautifulSoup` object was created properly

# %%
# Use soup.title attribute
print(soup.title)
# Out:
# <title>List of Falcon 9 and Falcon Heavy launches - Wikipedia</title>

# %% [markdown]
# ### TASK 2: Extract all column/variable names from the HTML table header

# %% [markdown]
# Next, we want to collect all relevant column names from the HTML table header

# %% [markdown]
# Let's try to find all tables on the wiki page first. If you need to refresh your memory about `BeautifulSoup`, please check the external reference link towards the end of this lab

# %%
# Use the find_all function in the BeautifulSoup object, with element type `table`
# Assign the result to a list called `html_tables`
html_tables = soup.find_all('table')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 # Use the find_all function in the BeautifulSoup object, with element type `table`
#       2 # Assign the result to a list called `html_tables`
# ----> 3 html_tables = soup.find_all('table')
#
# NameError: name 'soup' is not defined

# %% [markdown]
# Starting from the third table is our target table contains the actual launch records.

# %%
# Let's print the third table and check its content
first_launch_table = html_tables[2]
print(first_launch_table)
# Out:
# <table class="wikitable plainrowheaders collapsible" style="width: 100%;">
# <tbody><tr>
# <th scope="col">Flight No.
# </th>
# <th scope="col">Date and<br/>time (<a href="/wiki/Coordinated_Universal_Time" title="Coordinated Universal Time">UTC</a>)
# </th>
# <th scope="col"><a href="/wiki/List_of_Falcon_9_first-stage_boosters" title="List of Falcon 9 first-stage boosters">Version,<br/>Booster</a> <sup class="reference" id="cite_ref-booster_11-0"><a href="#cite_note-booster-11">[b]</a></sup>
# </th>
# <th scope="col">Launch site
# </th>
# <th scope="col">Payload<sup class="reference" id="cite_ref-Dragon_12-0"><a href="#cite_note-Dragon-12">[c]</a></sup>
# </th>
# <th scope="col">Payload mass
# </th>
# <th scope="col">Orbit
# </th>
# <th scope="col">Customer
# </th>
# <th scope="col">Launch<br/>outcome
# </th>
# <th scope="col"><a href="/wiki/Falcon_9_first-stage_landing_tests" title="Falcon 9 first-stage landing tests">Booster<br/>landing</a>
# </th></tr>
# <tr>
# <th rowspan="2" scope="row" style="text-align:center;">1
# </th>
# <td>4 June 2010,<br/>18:45
# </td>
# <td><a href="/wiki/Falcon_9_v1.0" title="Falcon 9 v1.0">F9 v1.0</a><sup class="reference" id="cite_ref-MuskMay2012_13-0"><a href="#cite_note-MuskMay2012-13">[7]</a></sup><br/>B0003.1<sup class="reference" id="cite_ref-block_numbers_14-0"><a href="#cite_note-block_numbers-14">[8]</a></sup>
# </td>
# <td><a href="/wiki/Cape_Canaveral_Space_Force_Station" title="Cape Canaveral Space Force Station">CCAFS</a>,<br/><a href="/wiki/Cape_Canaveral_Space_Launch_Complex_40" title="Cape Canaveral Space Launch Complex 40">SLC-40</a>
# </td>
# <td><a href="/wiki/Dragon_Spacecraft_Qualification_Unit" title="Dragon Spacecraft Qualification Unit">Dragon Spacecraft Qualification Unit</a>
# </td>
# <td>
# </td>
# <td><a href="/wiki/Low_Earth_orbit" title="Low Earth orbit">LEO</a>
# </td>
# <td><a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# </td>
# <td class="table-success" style="background: #9EFF9E; vertical-align: middle; text-align: center;">Success
# </td>
# <td class="table-failure" style="background: #FFC7C7; vertical-align: middle; text-align: center;">Failure<sup class="reference" id="cite_ref-ns20110930_15-0"><a href="#cite_note-ns20110930-15">[9]</a></sup><sup class="reference" id="cite_ref-16"><a href="#cite_note-16">[10]</a></sup><br/><small>(parachute)</small>
# </td></tr>
# <tr>
# <td colspan="9">First flight of Falcon 9 v1.0.<sup class="reference" id="cite_ref-sfn20100604_17-0"><a href="#cite_note-sfn20100604-17">[11]</a></sup> Used a boilerplate version of Dragon capsule which was not designed to separate from the second stage.<small>(<a href="#First_flight_of_Falcon_9">more details below</a>)</small> Attempted to recover the first stage by parachuting it into the ocean, but it burned up on reentry, before the parachutes even deployed.<sup class="reference" id="cite_ref-parachute_18-0"><a href="#cite_note-parachute-18">[12]</a></sup>
# </td></tr>
# <tr>
# <th rowspan="2" scope="row" style="text-align:center;">2
# </th>
# <td>8 December 2010,<br/>15:43<sup class="reference" id="cite_ref-spaceflightnow_Clark_Launch_Report_19-0"><a href="#cite_note-spaceflightnow_Clark_Launch_Report-19">[13]</a></sup>
# </td>
# <td><a href="/wiki/Falcon_9_v1.0" title="Falcon 9 v1.0">F9 v1.0</a><sup class="reference" id="cite_ref-MuskMay2012_13-1"><a href="#cite_note-MuskMay2012-13">[7]</a></sup><br/>B0004.1<sup class="reference" id="cite_ref-block_numbers_14-1"><a href="#cite_note-block_numbers-14">[8]</a></sup>
# </td>
# <td><a href="/wiki/Cape_Canaveral_Space_Force_Station" title="Cape Canaveral Space Force Station">CCAFS</a>,<br/><a href="/wiki/Cape_Canaveral_Space_Launch_Complex_40" title="Cape Canaveral Space Launch Complex 40">SLC-40</a>
# </td>
# <td><a href="/wiki/SpaceX_Dragon" title="SpaceX Dragon">Dragon</a> <a class="mw-redirect" href="/wiki/COTS_Demo_Flight_1" title="COTS Demo Flight 1">demo flight C1</a><br/>(Dragon C101)
# </td>
# <td>
# </td>
# <td><a href="/wiki/Low_Earth_orbit" title="Low Earth orbit">LEO</a> (<a href="/wiki/International_Space_Station" title="International Space Station">ISS</a>)
# </td>
# <td><style data-mw-deduplicate="TemplateStyles:r1126788409">.mw-parser-output .plainlist ol,.mw-parser-output .plainlist ul{line-height:inherit;list-style:none;margin:0;padding:0}.mw-parser-output .plainlist ol li,.mw-parser-output .plainlist ul li{margin-bottom:0}</style><div class="plainlist">
# <ul><li><a href="/wiki/NASA" title="NASA">NASA</a> (<a href="/wiki/Commercial_Orbital_Transportation_Services" title="Commercial Orbital Transportation Services">COTS</a>)</li>
# <li><a href="/wiki/National_Reconnaissance_Office" title="National Reconnaissance Office">NRO</a></li></ul>
# </div>
# </td>
# <td class="table-success" style="background: #9EFF9E; vertical-align: middle; text-align: center;">Success<sup class="reference" id="cite_ref-ns20110930_15-1"><a href="#cite_note-ns20110930-15">[9]</a></sup>
# </td>
# <td class="table-failure" style="background: #FFC7C7; vertical-align: middle; text-align: center;">Failure<sup class="reference" id="cite_ref-ns20110930_15-2"><a href="#cite_note-ns20110930-15">[9]</a></sup><sup class="reference" id="cite_ref-20"><a href="#cite_note-20">[14]</a></sup><br/><small>(parachute)</small>
# </td></tr>
# <tr>
# <td colspan="9">Maiden flight of <a class="mw-redirect" href="/wiki/Dragon_capsule" title="Dragon capsule">Dragon capsule</a>, consisting of over 3 hours of testing thruster maneuvering and reentry.<sup class="reference" id="cite_ref-spaceflightnow_Clark_unleashing_Dragon_21-0"><a href="#cite_note-spaceflightnow_Clark_unleashing_Dragon-21">[15]</a></sup> Attempted to recover the first stage by parachuting it into the ocean, but it disintegrated upon reentry, before the parachutes were deployed.<sup class="reference" id="cite_ref-parachute_18-1"><a href="#cite_note-parachute-18">[12]</a></sup> <small>(<a href="#COTS_demo_missions">more details below</a>)</small> It also included two <a href="/wiki/CubeSat" title="CubeSat">CubeSats</a>,<sup class="reference" id="cite_ref-NRO_Taps_Boeing_for_Next_Batch_of_CubeSats_22-0"><a href="#cite_note-NRO_Taps_Boeing_for_Next_Batch_of_CubeSats-22">[16]</a></sup> and a wheel of <a href="/wiki/Brou%C3%A8re" title="Brouère">Brouère</a> cheese.
# </td></tr>
# <tr>
# <th rowspan="2" scope="row" style="text-align:center;">3
# </th>
# <td>22 May 2012,<br/>07:44<sup class="reference" id="cite_ref-BBC_new_era_23-0"><a href="#cite_note-BBC_new_era-23">[17]</a></sup>
# </td>
# <td><a href="/wiki/Falcon_9_v1.0" title="Falcon 9 v1.0">F9 v1.0</a><sup class="reference" id="cite_ref-MuskMay2012_13-2"><a href="#cite_note-MuskMay2012-13">[7]</a></sup><br/>B0005.1<sup class="reference" id="cite_ref-block_numbers_14-2"><a href="#cite_note-block_numbers-14">[8]</a></sup>
# </td>
# <td><a href="/wiki/Cape_Canaveral_Space_Force_Station" title="Cape Canaveral Space Force Station">CCAFS</a>,<br/><a href="/wiki/Cape_Canaveral_Space_Launch_Complex_40" title="Cape Canaveral Space Launch Complex 40">SLC-40</a>
# </td>
# <td><a href="/wiki/SpaceX_Dragon" title="SpaceX Dragon">Dragon</a> <a class="mw-redirect" href="/wiki/Dragon_C2%2B" title="Dragon C2+">demo flight C2+</a><sup class="reference" id="cite_ref-C2_24-0"><a href="#cite_note-C2-24">[18]</a></sup><br/>(Dragon C102)
# </td>
# <td>525 kg (1,157 lb)<sup class="reference" id="cite_ref-25"><a href="#cite_note-25">[19]</a></sup>
# </td>
# <td><a href="/wiki/Low_Earth_orbit" title="Low Earth orbit">LEO</a> (<a href="/wiki/International_Space_Station" title="International Space Station">ISS</a>)
# </td>
# <td><a href="/wiki/NASA" title="NASA">NASA</a> (<a href="/wiki/Commercial_Orbital_Transportation_Services" title="Commercial Orbital Transportation Services">COTS</a>)
# </td>
# <td class="table-success" style="background: #9EFF9E; vertical-align: middle; text-align: center;">Success<sup class="reference" id="cite_ref-26"><a href="#cite_note-26">[20]</a></sup>
# </td>
# <td class="table-noAttempt" style="background: #EEE; vertical-align: middle; white-space: nowrap; text-align: center;">No attempt
# </td></tr>
# <tr>
# <td colspan="9">Dragon spacecraft demonstrated a series of tests before it was allowed to approach the <a href="/wiki/International_Space_Station" title="International Space Station">International Space Station</a>. Two days later, it became the first commercial spacecraft to board the ISS.<sup class="reference" id="cite_ref-BBC_new_era_23-1"><a href="#cite_note-BBC_new_era-23">[17]</a></sup> <small>(<a href="#COTS_demo_missions">more details below</a>)</small>
# </td></tr>
# <tr>
# <th rowspan="3" scope="row" style="text-align:center;">4
# </th>
# <td rowspan="2">8 October 2012,<br/>00:35<sup class="reference" id="cite_ref-SFN_LLog_27-0"><a href="#cite_note-SFN_LLog-27">[21]</a></sup>
# </td>
# <td rowspan="2"><a href="/wiki/Falcon_9_v1.0" title="Falcon 9 v1.0">F9 v1.0</a><sup class="reference" id="cite_ref-MuskMay2012_13-3"><a href="#cite_note-MuskMay2012-13">[7]</a></sup><br/>B0006.1<sup class="reference" id="cite_ref-block_numbers_14-3"><a href="#cite_note-block_numbers-14">[8]</a></sup>
# </td>
# <td rowspan="2"><a href="/wiki/Cape_Canaveral_Space_Force_Station" title="Cape Canaveral Space Force Station">CCAFS</a>,<br/><a href="/wiki/Cape_Canaveral_Space_Launch_Complex_40" title="Cape Canaveral Space Launch Complex 40">SLC-40</a>
# </td>
# <td><a href="/wiki/SpaceX_CRS-1" title="SpaceX CRS-1">SpaceX CRS-1</a><sup class="reference" id="cite_ref-sxManifest20120925_28-0"><a href="#cite_note-sxManifest20120925-28">[22]</a></sup><br/>(Dragon C103)
# </td>
# <td>4,700 kg (10,400 lb)
# </td>
# <td><a href="/wiki/Low_Earth_orbit" title="Low Earth orbit">LEO</a> (<a href="/wiki/International_Space_Station" title="International Space Station">ISS</a>)
# </td>
# <td><a href="/wiki/NASA" title="NASA">NASA</a> (<a href="/wiki/Commercial_Resupply_Services" title="Commercial Resupply Services">CRS</a>)
# </td>
# <td class="table-success" style="background: #9EFF9E; vertical-align: middle; text-align: center;">Success
# </td>
# <td rowspan="2" style="background:#ececec; text-align:center;"><span class="nowrap">No attempt</span>
# </td></tr>
# <tr>
# <td><a href="/wiki/Orbcomm_(satellite)" title="Orbcomm (satellite)">Orbcomm-OG2</a><sup class="reference" id="cite_ref-Orbcomm_29-0"><a href="#cite_note-Orbcomm-29">[23]</a></sup>
# </td>
# <td>172 kg (379 lb)<sup class="reference" id="cite_ref-gunter-og2_30-0"><a href="#cite_note-gunter-og2-30">[24]</a></sup>
# </td>
# <td><a href="/wiki/Low_Earth_orbit" title="Low Earth orbit">LEO</a>
# </td>
# <td><a href="/wiki/Orbcomm" title="Orbcomm">Orbcomm</a>
# </td>
# <td class="table-partial" style="background: #FE9; vertical-align: middle; text-align: center;">Partial failure<sup class="reference" id="cite_ref-nyt-20121030_31-0"><a href="#cite_note-nyt-20121030-31">[25]</a></sup>
# </td></tr>
# <tr>
# <td colspan="9">CRS-1 was successful, but the <a href="/wiki/Secondary_payload" title="Secondary payload">secondary payload</a> was inserted into an abnormally low orbit and subsequently lost. This was due to one of the nine <a href="/wiki/SpaceX_Merlin" title="SpaceX Merlin">Merlin engines</a> shutting down during the launch, and NASA declining a second reignition, as per <a href="/wiki/International_Space_Station" title="International Space Station">ISS</a> visiting vehicle safety rules, the primary payload owner is contractually allowed to decline a second reignition. NASA stated that this was because SpaceX could not guarantee a high enough likelihood of the second stage completing the second burn successfully which was required to avoid any risk of secondary payload's collision with the ISS.<sup class="reference" id="cite_ref-OrbcommTotalLoss_32-0"><a href="#cite_note-OrbcommTotalLoss-32">[26]</a></sup><sup class="reference" id="cite_ref-sn20121011_33-0"><a href="#cite_note-sn20121011-33">[27]</a></sup><sup class="reference" id="cite_ref-34"><a href="#cite_note-34">[28]</a></sup>
# </td></tr>
# <tr>
# <th rowspan="2" scope="row" style="text-align:center;">5
# </th>
# <td>1 March 2013,<br/>15:10
# </td>
# <td><a href="/wiki/Falcon_9_v1.0" title="Falcon 9 v1.0">F9 v1.0</a><sup class="reference" id="cite_ref-MuskMay2012_13-4"><a href="#cite_note-MuskMay2012-13">[7]</a></sup><br/>B0007.1<sup class="reference" id="cite_ref-block_numbers_14-4"><a href="#cite_note-block_numbers-14">[8]</a></sup>
# </td>
# <td><a href="/wiki/Cape_Canaveral_Space_Force_Station" title="Cape Canaveral Space Force Station">CCAFS</a>,<br/><a href="/wiki/Cape_Canaveral_Space_Launch_Complex_40" title="Cape Canaveral Space Launch Complex 40">SLC-40</a>
# </td>
# <td><a href="/wiki/SpaceX_CRS-2" title="SpaceX CRS-2">SpaceX CRS-2</a><sup class="reference" id="cite_ref-sxManifest20120925_28-1"><a href="#cite_note-sxManifest20120925-28">[22]</a></sup><br/>(Dragon C104)
# </td>
# <td>4,877 kg (10,752 lb)
# </td>
# <td><a href="/wiki/Low_Earth_orbit" title="Low Earth orbit">LEO</a> (<a class="mw-redirect" href="/wiki/ISS" title="ISS">ISS</a>)
# </td>
# <td><a href="/wiki/NASA" title="NASA">NASA</a> (<a href="/wiki/Commercial_Resupply_Services" title="Commercial Resupply Services">CRS</a>)
# </td>
# <td class="table-success" style="background: #9EFF9E; vertical-align: middle; text-align: center;">Success
# </td>
# <td class="table-noAttempt" style="background: #EEE; vertical-align: middle; white-space: nowrap; text-align: center;">No attempt
# </td></tr>
# <tr>
# <td colspan="9">Last launch of the original Falcon 9 v1.0 <a href="/wiki/Launch_vehicle" title="Launch vehicle">launch vehicle</a>, first use of the unpressurized trunk section of Dragon.<sup class="reference" id="cite_ref-sxf9_20110321_35-0"><a href="#cite_note-sxf9_20110321-35">[29]</a></sup>
# </td></tr>
# <tr>
# <th rowspan="2" scope="row" style="text-align:center;">6
# </th>
# <td>29 September 2013,<br/>16:00<sup class="reference" id="cite_ref-pa20130930_36-0"><a href="#cite_note-pa20130930-36">[30]</a></sup>
# </td>
# <td><a href="/wiki/Falcon_9_v1.1" title="Falcon 9 v1.1">F9 v1.1</a><sup class="reference" id="cite_ref-MuskMay2012_13-5"><a href="#cite_note-MuskMay2012-13">[7]</a></sup><br/>B1003<sup class="reference" id="cite_ref-block_numbers_14-5"><a href="#cite_note-block_numbers-14">[8]</a></sup>
# </td>
# <td><a class="mw-redirect" href="/wiki/Vandenberg_Air_Force_Base" title="Vandenberg Air Force Base">VAFB</a>,<br/><a href="/wiki/Vandenberg_Space_Launch_Complex_4" title="Vandenberg Space Launch Complex 4">SLC-4E</a>
# </td>
# <td><a href="/wiki/CASSIOPE" title="CASSIOPE">CASSIOPE</a><sup class="reference" id="cite_ref-sxManifest20120925_28-2"><a href="#cite_note-sxManifest20120925-28">[22]</a></sup><sup class="reference" id="cite_ref-CASSIOPE_MDA_37-0"><a href="#cite_note-CASSIOPE_MDA-37">[31]</a></sup>
# </td>
# <td>500 kg (1,100 lb)
# </td>
# <td><a href="/wiki/Polar_orbit" title="Polar orbit">Polar orbit</a> <a href="/wiki/Low_Earth_orbit" title="Low Earth orbit">LEO</a>
# </td>
# <td><a href="/wiki/Maxar_Technologies" title="Maxar Technologies">MDA</a>
# </td>
# <td class="table-success" style="background: #9EFF9E; vertical-align: middle; text-align: center;">Success<sup class="reference" id="cite_ref-pa20130930_36-1"><a href="#cite_note-pa20130930-36">[30]</a></sup>
# </td>
# <td class="table-no2" style="background: #FFE3E3; color: black; vertical-align: middle; text-align: center;">Uncontrolled<br/><small>(ocean)</small><sup class="reference" id="cite_ref-ocean_landing_38-0"><a href="#cite_note-ocean_landing-38">[d]</a></sup>
# </td></tr>
# <tr>
# <td colspan="9">First commercial mission with a private customer, first launch from Vandenberg, and demonstration flight of Falcon 9 v1.1 with an improved 13-tonne to LEO capacity.<sup class="reference" id="cite_ref-sxf9_20110321_35-1"><a href="#cite_note-sxf9_20110321-35">[29]</a></sup> After separation from the second stage carrying Canadian commercial and scientific satellites, the first stage booster performed a controlled reentry,<sup class="reference" id="cite_ref-39"><a href="#cite_note-39">[32]</a></sup> and an <a href="/wiki/Falcon_9_first-stage_landing_tests" title="Falcon 9 first-stage landing tests">ocean touchdown test</a> for the first time. This provided good test data, even though the booster started rolling as it neared the ocean, leading to the shutdown of the central engine as the roll depleted it of fuel, resulting in a hard impact with the ocean.<sup class="reference" id="cite_ref-pa20130930_36-2"><a href="#cite_note-pa20130930-36">[30]</a></sup> This was the first known attempt of a rocket engine being lit to perform a supersonic retro propulsion, and allowed SpaceX to enter a public-private partnership with <a href="/wiki/NASA" title="NASA">NASA</a> and its Mars entry, descent, and landing technologies research projects.<sup class="reference" id="cite_ref-40"><a href="#cite_note-40">[33]</a></sup> <small>(<a href="#Maiden_flight_of_v1.1">more details below</a>)</small>
# </td></tr>
# <tr>
# <th rowspan="2" scope="row" style="text-align:center;">7
# </th>
# <td>3 December 2013,<br/>22:41<sup class="reference" id="cite_ref-sfn_wwls20130624_41-0"><a href="#cite_note-sfn_wwls20130624-41">[34]</a></sup>
# </td>
# <td><a href="/wiki/Falcon_9_v1.1" title="Falcon 9 v1.1">F9 v1.1</a><br/>B1004
# </td>
# <td><a href="/wiki/Cape_Canaveral_Space_Force_Station" title="Cape Canaveral Space Force Station">CCAFS</a>,<br/><a href="/wiki/Cape_Canaveral_Space_Launch_Complex_40" title="Cape Canaveral Space Launch Complex 40">SLC-40</a>
# </td>
# <td><a href="/wiki/SES-8" title="SES-8">SES-8</a><sup class="reference" id="cite_ref-sxManifest20120925_28-3"><a href="#cite_note-sxManifest20120925-28">[22]</a></sup><sup class="reference" id="cite_ref-spx-pr_42-0"><a href="#cite_note-spx-pr-42">[35]</a></sup><sup class="reference" id="cite_ref-aw20110323_43-0"><a href="#cite_note-aw20110323-43">[36]</a></sup>
# </td>
# <td>3,170 kg (6,990 lb)
# </td>
# <td><a href="/wiki/Geostationary_transfer_orbit" title="Geostationary transfer orbit">GTO</a>
# </td>
# <td><a href="/wiki/SES_S.A." title="SES S.A.">SES</a>
# </td>
# <td class="table-success" style="background: #9EFF9E; vertical-align: middle; text-align: center;">Success<sup class="reference" id="cite_ref-SNMissionStatus7_44-0"><a href="#cite_note-SNMissionStatus7-44">[37]</a></sup>
# </td>
# <td class="table-noAttempt" style="background: #EEE; vertical-align: middle; white-space: nowrap; text-align: center;">No attempt<br/><sup class="reference" id="cite_ref-sf10120131203_45-0"><a href="#cite_note-sf10120131203-45">[38]</a></sup>
# </td></tr>
# <tr>
# <td colspan="9">First <a href="/wiki/Geostationary_transfer_orbit" title="Geostationary transfer orbit">Geostationary transfer orbit</a> (GTO) launch for Falcon 9,<sup class="reference" id="cite_ref-spx-pr_42-1"><a href="#cite_note-spx-pr-42">[35]</a></sup> and first successful reignition of the second stage.<sup class="reference" id="cite_ref-46"><a href="#cite_note-46">[39]</a></sup> SES-8 was inserted into a <a href="/wiki/Geostationary_transfer_orbit" title="Geostationary transfer orbit">Super-Synchronous Transfer Orbit</a> of 79,341 km (49,300 mi) in apogee with an <a href="/wiki/Orbital_inclination" title="Orbital inclination">inclination</a> of 20.55° to the <a href="/wiki/Equator" title="Equator">equator</a>.
# </td></tr></tbody></table>

# %% [markdown]
# You should able to see the columns names embedded in the table header elements `<th>` as follows:

# %% [markdown]
# ```
# <tr>
# <th scope="col">Flight No.
# </th>
# <th scope="col">Date and<br/>time (<a href="/wiki/Coordinated_Universal_Time" title="Coordinated Universal Time">UTC</a>)
# </th>
# <th scope="col"><a href="/wiki/List_of_Falcon_9_first-stage_boosters" title="List of Falcon 9 first-stage boosters">Version,<br/>Booster</a> <sup class="reference" id="cite_ref-booster_11-0"><a href="#cite_note-booster-11">[b]</a></sup>
# </th>
# <th scope="col">Launch site
# </th>
# <th scope="col">Payload<sup class="reference" id="cite_ref-Dragon_12-0"><a href="#cite_note-Dragon-12">[c]</a></sup>
# </th>
# <th scope="col">Payload mass
# </th>
# <th scope="col">Orbit
# </th>
# <th scope="col">Customer
# </th>
# <th scope="col">Launch<br/>outcome
# </th>
# <th scope="col"><a href="/wiki/Falcon_9_first-stage_landing_tests" title="Falcon 9 first-stage landing tests">Booster<br/>landing</a>
# </th></tr>
# ```

# %% [markdown]
# Next, we just need to iterate through the `<th>` elements and apply the provided `extract_column_from_header()` to extract column name one by one

# %%
column_names = []

# Apply find_all() function with `th` element on first_launch_table
# Iterate each th element and apply the provided extract_column_from_header() to get a column name
# Append the Non-empty column name (`if name is not None and len(name) > 0`) into a list called column_names
for th in first_launch_table.find_all('th'):
    name = extract_column_from_header(th)
    if name is not None and len(name) > 0:
        column_names.append(name)

# %% [markdown]
# Check the extracted column names

# %%
print(column_names)
# Out:
# ['Flight No.', 'Date and time ( )', 'Launch site', 'Payload', 'Payload mass', 'Orbit', 'Customer', 'Launch outcome']

# %% [markdown]
# ## TASK 3: Create a data frame by parsing the launch HTML tables

# %% [markdown]
# We will create an empty dictionary with keys from the extracted column names in the previous task. Later, this dictionary will be converted into a Pandas dataframe

# %%
launch_dict= dict.fromkeys(column_names)

# Remove an irrelvant column
del launch_dict['Date and time ( )']

# Let's initial the launch_dict with each value to be an empty list
launch_dict['Flight No.'] = []
launch_dict['Date']=[]
launch_dict['Time']=[]
launch_dict['Launch site'] = []
launch_dict['Payload'] = []
launch_dict['Payload mass'] = []
launch_dict['Orbit'] = []
launch_dict['Customer'] = []
launch_dict['Launch outcome'] = []
# Added some new columns
launch_dict['Version Booster']=[]
launch_dict['Booster landing']=[]


print(launch_dict)
# Out:
# {'Flight No.': [], 'Launch site': [], 'Payload': [], 'Payload mass': [], 'Orbit': [], 'Customer': [], 'Launch outcome': [], 'Date': [], 'Time': [], 'Version Booster': [], 'Booster landing': []}

# %% [markdown]
# Next, we just need to fill up the `launch_dict` with launch records extracted from table rows.

# %% [markdown]
# Usually, HTML tables in Wiki pages are likely to contain unexpected annotations and other types of noises, such as reference links `B0004.1[8]`, missing values `N/A [e]`, inconsistent formatting, etc.

# %% [markdown]
# To simplify the parsing process, we have provided an incomplete code snippet below to help you to fill up the `launch_dict`. Please complete the following code snippet with TODOs or you can choose to write your own logic to parse all launch tables:

# %%
extracted_row = 0
#Extract each table and enumerate over each table use the soup object ot find all tables with class wikitable plainrowheaders collapsible
for table_number,table in enumerate(soup.find_all('table',class_="wikitable plainrowheaders collapsible")):

   # get table row 
    for rows in table.find_all('tr'):
        #check to see if first table heading is as number corresponding to launch a number 
        if rows.th:
            if rows.th.string:
                flight_number=rows.th.string.strip()
                flag=flight_number.isdigit()
        else:
            flag=False
        #get table element 
        row=rows.find_all('td')
        #if it is number save cells in a dictonary 
        if flag:
            extracted_row += 1
            # Flight Number value
            # TODO: Append the flight_number into launch_dict with key `Flight No.`
            launch_dict['Flight No.'].append(flight_number)
            print(f"Flight No.: {flight_number}")

            datatimelist=date_time(row[0])

            
            # Date value
            # TODO: Append the date into launch_dict with key `Date
            date = datatimelist[0].strip(',')
            launch_dict['Date'].append(date)
            print(f"Date: {date}")
            
            # Time value
            # TODO: Append the time into launch_dict with key `Time`
            time = datatimelist[1].strip(',')
            launch_dict['Time'].append(time)
            print(f"Time: {time}")
              
            # Booster version
            # TODO: Append the bv into launch_dict with key `Version Booster` using booster_version function, strip trailing and leading spaces
            bv=booster_version(row[1])
            launch_dict['Version Booster'].append(bv)
            if not(bv):
                bv=row[1]
            print(f"Version Booster: {bv}")
            
            # Launch Site
            # TODO: Append the bv into launch_dict with key `Launch Site`
            launch_site = booster_version(row[2])
            launch_dict['Launch site'].append(launch_site.strip(','))
            if not (launch_site):
                launch_site = row[2]
            print(f"Launch site: {launch_site}")
            
            # Payload
            # TODO: Append the payload into launch_dict with key `Payload`
            payload = row[3].a.string
            launch_dict['Payload'].append(payload)
            print(f"Payload: {payload}")
            
            # Payload Mass
            # TODO: Append the payload_mass into launch_dict with key `Payload mass`
            payload_mass = get_mass(row[4])
            launch_dict['Payload mass'].append(payload_mass)
            print(f"Payload mass: {payload_mass}")
            
            # Orbit
            # TODO: Append the orbit into launch_dict with key `Orbit`
            orbit = row[5].a.string
            launch_dict['Orbit'].append(orbit)
            print(f"Orbit: {orbit}")
            
            # Customer
            # TODO: Append the customer into launch_dict with key `Customer`
            customer = row[6]
            launch_dict['Customer'].append(customer)
            print(f"Customer: {customer}")
            
            # Launch outcome
            # TODO: Append the launch_outcome into launch_dict with key `Launch outcome`
            launch_outcome = list(row[7].strings)[0]
            launch_dict['Launch outcome'].append(launch_outcome)
            print(f"Launch outcome: {launch_outcome}")
            
            # Booster landing
            # TODO: Append the launch_outcome into launch_dict with key `Booster landing`
            booster_landing = landing_status(row[8])
            launch_dict['Booster landing'].append(launch_outcome)
            print(f"Booster landing: {booster_landing}")
            
             # Debugging
            print(f"Extracted row: {extracted_row}")
            print(f"Length of Flight No. array: {len(launch_dict['Flight No.'])}")
            print(f"Length of Date array: {len(launch_dict['Date'])}")
            print(f"Length of Time array: {len(launch_dict['Time'])}")
            print(f"Length of Version Booster array: {len(launch_dict['Version Booster'])}")
            print(f"Length of Launch site array: {len(launch_dict['Launch site'])}")
            print(f"Length of Payload array: {len(launch_dict['Payload'])}")
            print(f"Length of Payload mass array: {len(launch_dict['Payload mass'])}")
            print(f"Length of Orbit array: {len(launch_dict['Orbit'])}")
            print(f"Length of Customer array: {len(launch_dict['Customer'])}")
            print(f"Length of Launch outcome array: {len(launch_dict['Launch outcome'])}")
            print(f"Length of Booster landing array: {len(launch_dict['Booster landing'])}")
# Out:
# Flight No.: 1
# Date: 4 June 2010
# Time: 18:45
# Version Booster: F9 v1.0B0003.1
# Launch site: CCAFS
# Payload: Dragon Spacecraft Qualification Unit
# Payload mass: 0
# Orbit: LEO
# Customer: <td><a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# </td>
# Launch outcome: Success
#
# Booster landing: Failure
# Extracted row: 1
# Length of Flight No. array: 108
# Length of Date array: 108
# Length of Time array: 108
# Length of Version Booster array: 108
# Length of Launch site array: 108
# Length of Payload array: 108
# Length of Payload mass array: 108
# Length of Orbit array: 108
# Length of Customer array: 106
# Length of Launch outcome array: 106
# Length of Booster landing array: 106
# Flight No.: 2
# Date: 8 December 2010
# Time: 15:43
# Version Booster: F9 v1.0B0004.1
# Launch site: CCAFS
# Payload: Dragon
# Payload mass: 0
# Orbit: LEO
# Customer: <td><style data-mw-deduplicate="TemplateStyles:r1126788409">.mw-parser-output .plainlist ol,.mw-parser-output .plainlist ul{line-height:inherit;list-style:none;margin:0;padding:0}.mw-parser-output .plainlist ol li,.mw-parser-output .plainlist ul li{margin-bottom:0}</style><div class="plainlist">
# <ul><li><a href="/wiki/NASA" title="NASA">NASA</a> (<a href="/wiki/Commercial_Orbital_Transportation_Services" title="Commercial Orbital Transportation Services">COTS</a>)</li>
# <li><a href="/wiki/National_Reconnaissance_Office" title="National Reconnaissance Office">NRO</a></li></ul>
# </div>
# </td>
# Launch outcome: Success
# Booster landing: Failure
# Extracted row: 2
# Length of Flight No. array: 109
# Length of Date array: 109
# Length of Time array: 109
# Length of Version Booster array: 109
# Length of Launch site array: 109
# Length of Payload array: 109
# Length of Payload mass array: 109
# Length of Orbit array: 109
# Length of Customer array: 107
# Length of Launch outcome array: 107
# Length of Booster landing array: 107
# Flight No.: 3
# Date: 22 May 2012
# Time: 07:44
# Version Booster: F9 v1.0B0005.1
# Launch site: CCAFS
# Payload: Dragon
# Payload mass: 525 kg
# Orbit: LEO
# Customer: <td><a href="/wiki/NASA" title="NASA">NASA</a> (<a href="/wiki/Commercial_Orbital_Transportation_Services" title="Commercial Orbital Transportation Services">COTS</a>)
# </td>
# Launch outcome: Success
# Booster landing: No attempt
#
# Extracted row: 3
# Length of Flight No. array: 110
# Length of Date array: 110
# Length of Time array: 110
# Length of Version Booster array: 110
# Length of Launch site array: 110
# Length of Payload array: 110
# Length of Payload mass array: 110
# Length of Orbit array: 110
# Length of Customer array: 108
# Length of Launch outcome array: 108
# Length of Booster landing array: 108
# Flight No.: 4
# Date: 8 October 2012
# Time: 00:35
# Version Booster: F9 v1.0B0006.1
# Launch site: CCAFS
# Payload: SpaceX CRS-1
# Payload mass: 4,700 kg
# Orbit: LEO
# Customer: <td><a href="/wiki/NASA" title="NASA">NASA</a> (<a href="/wiki/Commercial_Resupply_Services" title="Commercial Resupply Services">CRS</a>)
# </td>
# Launch outcome: Success
#
# Booster landing: No attempt
# Extracted row: 4
# Length of Flight No. array: 111
# Length of Date array: 111
# Length of Time array: 111
# Length of Version Booster array: 111
# Length of Launch site array: 111
# Length of Payload array: 111
# Length of Payload mass array: 111
# Length of Orbit array: 111
# Length of Customer array: 109
# Length of Launch outcome array: 109
# Length of Booster landing array: 109
# Flight No.: 5
# Date: 1 March 2013
# Time: 15:10
# Version Booster: F9 v1.0B0007.1
# Launch site: CCAFS
# Payload: SpaceX CRS-2
# Payload mass: 4,877 kg
# Orbit: LEO
# Customer: <td><a href="/wiki/NASA" title="NASA">NASA</a> (<a href="/wiki/Commercial_Resupply_Services" title="Commercial Resupply Services">CRS</a>)
# </td>
# Launch outcome: Success
#
# Booster landing: No attempt
#
# Extracted row: 5
# Length of Flight No. array: 112
# Length of Date array: 112
# Length of Time array: 112
# Length of Version Booster array: 112
# Length of Launch site array: 112
# Length of Payload array: 112
# Length of Payload mass array: 112
# Length of Orbit array: 112
# Length of Customer array: 110
# Length of Launch outcome array: 110
# Length of Booster landing array: 110
# Flight No.: 6
# Date: 29 September 2013
# Time: 16:00
# Version Booster: F9 v1.1B1003
# Launch site: VAFB
# Payload: CASSIOPE
# Payload mass: 500 kg
# Orbit: Polar orbit
# Customer: <td><a href="/wiki/Maxar_Technologies" title="Maxar Technologies">MDA</a>
# </td>
# Launch outcome: Success
# Booster landing: Uncontrolled
# Extracted row: 6
# Length of Flight No. array: 113
# Length of Date array: 113
# Length of Time array: 113
# Length of Version Booster array: 113
# Length of Launch site array: 113
# Length of Payload array: 113
# Length of Payload mass array: 113
# Length of Orbit array: 113
# Length of Customer array: 111
# Length of Launch outcome array: 111
# Length of Booster landing array: 111
# Flight No.: 7
# Date: 3 December 2013
# Time: 22:41
# Version Booster: <td><a href="/wiki/Falcon_9_v1.1" title="Falcon 9 v1.1">F9 v1.1</a><br/>B1004
# </td>
# Launch site: CCAFS
# Payload: SES-8
# Payload mass: 3,170 kg
# Orbit: GTO
# Customer: <td><a href="/wiki/SES_S.A." title="SES S.A.">SES</a>
# </td>
# Launch outcome: Success
# Booster landing: No attempt
# Extracted row: 7
# Length of Flight No. array: 114
# Length of Date array: 114
# Length of Time array: 114
# Length of Version Booster array: 114
# Length of Launch site array: 114
# Length of Payload array: 114
# Length of Payload mass array: 114
# Length of Orbit array: 114
# Length of Customer array: 112
# Length of Launch outcome array: 112
# Length of Booster landing array: 112
# Flight No.: 8
# Date: 6 January 2014
# Time: 22:06
# Version Booster: <td><a href="/wiki/Falcon_9_v1.1" title="Falcon 9 v1.1">F9 v1.1</a>
# </td>
# Launch site: CCAFS
# Payload: Thaicom 6
# Payload mass: 3,325 kg
# Orbit: GTO
# Customer: <td><a href="/wiki/Thaicom" title="Thaicom">Thaicom</a>
# </td>
# Launch outcome: Success
# Booster landing: No attempt
# Extracted row: 8
# Length of Flight No. array: 115
# Length of Date array: 115
# Length of Time array: 115
# Length of Version Booster array: 115
# Length of Launch site array: 115
# Length of Payload array: 115
# Length of Payload mass array: 115
# Length of Orbit array: 115
# Length of Customer array: 113
# Length of Launch outcome array: 113
# Length of Booster landing array: 113
# Flight No.: 9
# Date: 18 April 2014
# Time: 19:25
# Version Booster: <td><a href="/wiki/Falcon_9_v1.1" title="Falcon 9 v1.1">F9 v1.1</a>
# </td>
# Launch site: Cape Canaveral
# Payload: SpaceX CRS-3
# Payload mass: 2,296 kg
# Orbit: LEO
# Customer: <td><a href="/wiki/NASA" title="NASA">NASA</a> (<a href="/wiki/Commercial_Resupply_Services" title="Commercial Resupply Services">CRS</a>)
# </td>
# Launch outcome: Success
#
# Booster landing: Controlled
# Extracted row: 9
# Length of Flight No. array: 116
# Length of Date array: 116
# Length of Time array: 116
# Length of Version Booster array: 116
# Length of Launch site array: 116
# Length of Payload array: 116
# Length of Payload mass array: 116
# Length of Orbit array: 116
# Length of Customer array: 114
# Length of Launch outcome array: 114
# Length of Booster landing array: 114
# Flight No.: 10
# Date: 14 July 2014
# Time: 15:15
# Version Booster: <td><a href="/wiki/Falcon_9_v1.1" title="Falcon 9 v1.1">F9 v1.1</a>
# </td>
# Launch site: Cape Canaveral
# Payload: Orbcomm-OG2
# Payload mass: 1,316 kg
# Orbit: LEO
# Customer: <td><a href="/wiki/Orbcomm" title="Orbcomm">Orbcomm</a>
# </td>
# Launch outcome: Success
# Booster landing: Controlled
# Extracted row: 10
# Length of Flight No. array: 117
# Length of Date array: 117
# Length of Time array: 117
# Length of Version Booster array: 117
# Length of Launch site array: 117
# Length of Payload array: 117
# Length of Payload mass array: 117
# Length of Orbit array: 117
# Length of Customer array: 115
# Length of Launch outcome array: 115
# Length of Booster landing array: 115
# Flight No.: 11
# Date: 5 August 2014
# Time: 08:00
# Version Booster: <td><a href="/wiki/Falcon_9_v1.1" title="Falcon 9 v1.1">F9 v1.1</a>
# </td>
# Launch site: Cape Canaveral
# Payload: AsiaSat 8
# Payload mass: 4,535 kg
# Orbit: GTO
# Customer: <td><a href="/wiki/AsiaSat" title="AsiaSat">AsiaSat</a>
# </td>
# Launch outcome: Success
# Booster landing: No attempt
# Extracted row: 11
# Length of Flight No. array: 118
# Length of Date array: 118
# Length of Time array: 118
# Length of Version Booster array: 118
# Length of Launch site array: 118
# Length of Payload array: 118
# Length of Payload mass array: 118
# Length of Orbit array: 118
# Length of Customer array: 116
# Length of Launch outcome array: 116
# Length of Booster landing array: 116
# Flight No.: 12
# Date: 7 September 2014
# Time: 05:00
# Version Booster: F9 v1.1
# Launch site: Cape Canaveral
# Payload: AsiaSat 6
# Payload mass: 4,428 kg
# Orbit: GTO
# Customer: <td><a href="/wiki/AsiaSat" title="AsiaSat">AsiaSat</a>
# </td>
# Launch outcome: Success
# Booster landing: No attempt
#
# Extracted row: 12
# Length of Flight No. array: 119
# Length of Date array: 119
# Length of Time array: 119
# Length of Version Booster array: 119
# Length of Launch site array: 119
# Length of Payload array: 119
# Length of Payload mass array: 119
# Length of Orbit array: 119
# Length of Customer array: 117
# Length of Launch outcome array: 117
# Length of Booster landing array: 117
# Flight No.: 13
# Date: 21 September 2014
# Time: 05:52
# Version Booster: F9 v1.1
# Launch site: Cape Canaveral
# Payload: SpaceX CRS-4
# Payload mass: 2,216 kg
# Orbit: LEO
# Customer: <td><a href="/wiki/NASA" title="NASA">NASA</a> (<a href="/wiki/Commercial_Resupply_Services" title="Commercial Resupply Services">CRS</a>)
# </td>
# Launch outcome: Success
# Booster landing: Uncontrolled
# Extracted row: 13
# Length of Flight No. array: 120
# Length of Date array: 120
# Length of Time array: 120
# Length of Version Booster array: 120
# Length of Launch site array: 120
# Length of Payload array: 120
# Length of Payload mass array: 120
# Length of Orbit array: 120
# Length of Customer array: 118
# Length of Launch outcome array: 118
# Length of Booster landing array: 118
# Flight No.: 14
# Date: 10 January 2015
# Time: 09:47
# Version Booster: F9 v1.1
# Launch site: Cape Canaveral
# Payload: SpaceX CRS-5
# Payload mass: 2,395 kg
# Orbit: LEO
# Customer: <td><a href="/wiki/NASA" title="NASA">NASA</a> (<a href="/wiki/Commercial_Resupply_Services" title="Commercial Resupply Services">CRS</a>)
# </td>
# Launch outcome: Success
# Booster landing: Failure
# Extracted row: 14
# Length of Flight No. array: 121
# Length of Date array: 121
# Length of Time array: 121
# Length of Version Booster array: 121
# Length of Launch site array: 121
# Length of Payload array: 121
# Length of Payload mass array: 121
# Length of Orbit array: 121
# Length of Customer array: 119
# Length of Launch outcome array: 119
# Length of Booster landing array: 119
# Flight No.: 15
# Date: 11 February 2015
# Time: 23:03
# Version Booster: F9 v1.1
# Launch site: Cape Canaveral
# Payload: DSCOVR
# Payload mass: 570 kg
# Orbit: HEO
# Customer: <td><link href="mw-data:TemplateStyles:r1126788409" rel="mw-deduplicated-inline-style"/><div class="plainlist">
# <ul><li><a href="/wiki/United_States_Air_Force" title="United States Air Force">USAF</a></li>
# <li><a href="/wiki/NASA" title="NASA">NASA</a></li>
# <li><a class="mw-redirect" href="/wiki/NOAA" title="NOAA">NOAA</a></li></ul>
# </div>
# </td>
# Launch outcome: Success
#
# Booster landing: Controlled
# Extracted row: 15
# Length of Flight No. array: 122
# Length of Date array: 122
# Length of Time array: 122
# Length of Version Booster array: 122
# Length of Launch site array: 122
# Length of Payload array: 122
# Length of Payload mass array: 122
# Length of Orbit array: 122
# Length of Customer array: 120
# Length of Launch outcome array: 120
# Length of Booster landing array: 120
# Flight No.: 16
# Date: 2 March 2015
# Time: 03:50
# Version Booster: F9 v1.1
# Launch site: Cape Canaveral
# Payload: ABS-3A
# Payload mass: 4,159 kg
# Orbit: GTO
# Customer: <td><link href="mw-data:TemplateStyles:r1126788409" rel="mw-deduplicated-inline-style"/><div class="plainlist">
# <ul><li><a class="mw-redirect" href="/wiki/Asia_Broadcast_Satellite" title="Asia Broadcast Satellite">ABS</a></li>
# <li><a href="/wiki/Eutelsat" title="Eutelsat">Eutelsat</a></li></ul>
# </div>
# </td>
# Launch outcome: Success
#
# Booster landing: No attempt
# Extracted row: 16
# Length of Flight No. array: 123
# Length of Date array: 123
# Length of Time array: 123
# Length of Version Booster array: 123
# Length of Launch site array: 123
# Length of Payload array: 123
# Length of Payload mass array: 123
# Length of Orbit array: 123
# Length of Customer array: 121
# Length of Launch outcome array: 121
# Length of Booster landing array: 121
# Flight No.: 17
# Date: 14 April 2015
# Time: 20:10
# Version Booster: F9 v1.1
# Launch site: Cape Canaveral
# Payload: SpaceX CRS-6
# Payload mass: 1,898 kg
# Orbit: LEO
# Customer: <td><a href="/wiki/NASA" title="NASA">NASA</a> (<a href="/wiki/Commercial_Resupply_Services" title="Commercial Resupply Services">CRS</a>)
# </td>
# Launch outcome: Success
#
# Booster landing: Failure
# Extracted row: 17
# Length of Flight No. array: 124
# Length of Date array: 124
# Length of Time array: 124
# Length of Version Booster array: 124
# Length of Launch site array: 124
# Length of Payload array: 124
# Length of Payload mass array: 124
# Length of Orbit array: 124
# Length of Customer array: 122
# Length of Launch outcome array: 122
# Length of Booster landing array: 122
# Flight No.: 18
# Date: 27 April 2015
# Time: 23:03
# Version Booster: F9 v1.1
# Launch site: Cape Canaveral
# Payload: TürkmenÄlem 52°E / MonacoSAT
# Payload mass: 4,707 kg
# Orbit: GTO
# Customer: <td><a href="/wiki/Turkmenistan_National_Space_Agency" title="Turkmenistan National Space Agency">Turkmenistan National<br/>Space Agency</a><sup class="reference" id="cite_ref-95"><a href="#cite_note-95">[88]</a></sup>
# </td>
# Launch outcome: Success
#
# Booster landing: No attempt
# Extracted row: 18
# Length of Flight No. array: 125
# Length of Date array: 125
# Length of Time array: 125
# Length of Version Booster array: 125
# Length of Launch site array: 125
# Length of Payload array: 125
# Length of Payload mass array: 125
# Length of Orbit array: 125
# Length of Customer array: 123
# Length of Launch outcome array: 123
# Length of Booster landing array: 123
# Flight No.: 19
# Date: 28 June 2015
# Time: 14:21
# Version Booster: F9 v1.1
# Launch site: Cape Canaveral
# Payload: SpaceX CRS-7
# Payload mass: 1,952 kg
# Orbit: LEO
# Customer: <td><a href="/wiki/NASA" title="NASA">NASA</a> (<a href="/wiki/Commercial_Resupply_Services" title="Commercial Resupply Services">CRS</a>)
# </td>
# Launch outcome: Failure
# Booster landing: Precluded
# Extracted row: 19
# Length of Flight No. array: 126
# Length of Date array: 126
# Length of Time array: 126
# Length of Version Booster array: 126
# Length of Launch site array: 126
# Length of Payload array: 126
# Length of Payload mass array: 126
# Length of Orbit array: 126
# Length of Customer array: 124
# Length of Launch outcome array: 124
# Length of Booster landing array: 124
# Flight No.: 20
# Date: 22 December 2015
# Time: 01:29
# Version Booster: F9 FT
# Launch site: Cape Canaveral
# Payload: Orbcomm-OG2
# Payload mass: 2,034 kg
# Orbit: LEO
# Customer: <td><a href="/wiki/Orbcomm" title="Orbcomm">Orbcomm</a>
# </td>
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 20
# Length of Flight No. array: 127
# Length of Date array: 127
# Length of Time array: 127
# Length of Version Booster array: 127
# Length of Launch site array: 127
# Length of Payload array: 127
# Length of Payload mass array: 127
# Length of Orbit array: 127
# Length of Customer array: 125
# Length of Launch outcome array: 125
# Length of Booster landing array: 125
# Flight No.: 21
# Date: 17 January 2016
# Time: 18:42
# Version Booster: F9 v1.1
# Launch site: VAFB
# Payload: Jason-3
# Payload mass: 553 kg
# Orbit: LEO
# Customer: <td><link href="mw-data:TemplateStyles:r1126788409" rel="mw-deduplicated-inline-style"/><div class="plainlist">
# <ul><li><a href="/wiki/NASA" title="NASA">NASA</a> (<a class="mw-redirect" href="/wiki/Launch_Services_Program" title="Launch Services Program">LSP</a>)</li>
# <li><a class="mw-redirect" href="/wiki/NOAA" title="NOAA">NOAA</a></li>
# <li><a href="/wiki/CNES" title="CNES">CNES</a></li></ul>
# </div>
# </td>
# Launch outcome: Success
#
# Booster landing: Failure
# Extracted row: 21
# Length of Flight No. array: 128
# Length of Date array: 128
# Length of Time array: 128
# Length of Version Booster array: 128
# Length of Launch site array: 128
# Length of Payload array: 128
# Length of Payload mass array: 128
# Length of Orbit array: 128
# Length of Customer array: 126
# Length of Launch outcome array: 126
# Length of Booster landing array: 126
# Flight No.: 22
# Date: 4 March 2016
# Time: 23:35
# Version Booster: F9 FT
# Launch site: Cape Canaveral
# Payload: SES-9
# Payload mass: 5,271 kg
# Orbit: GTO
# Customer: <td><a href="/wiki/SES_S.A." title="SES S.A.">SES</a>
# </td>
# Launch outcome: Success
#
# Booster landing: Failure
# Extracted row: 22
# Length of Flight No. array: 129
# Length of Date array: 129
# Length of Time array: 129
# Length of Version Booster array: 129
# Length of Launch site array: 129
# Length of Payload array: 129
# Length of Payload mass array: 129
# Length of Orbit array: 129
# Length of Customer array: 127
# Length of Launch outcome array: 127
# Length of Booster landing array: 127
# Flight No.: 23
# Date: 8 April 2016
# Time: 20:43
# Version Booster: F9 FT
# Launch site: Cape Canaveral
# Payload: SpaceX CRS-8
# Payload mass: 3,136 kg
# Orbit: LEO
# Customer: <td><a href="/wiki/NASA" title="NASA">NASA</a> (<a href="/wiki/Commercial_Resupply_Services" title="Commercial Resupply Services">CRS</a>)
# </td>
# Launch outcome: Success
# Booster landing: Success
# Extracted row: 23
# Length of Flight No. array: 130
# Length of Date array: 130
# Length of Time array: 130
# Length of Version Booster array: 130
# Length of Launch site array: 130
# Length of Payload array: 130
# Length of Payload mass array: 130
# Length of Orbit array: 130
# Length of Customer array: 128
# Length of Launch outcome array: 128
# Length of Booster landing array: 128
# Flight No.: 24
# Date: 6 May 2016
# Time: 05:21
# Version Booster: F9 FT
# Launch site: Cape Canaveral
# Payload: JCSAT-14
# Payload mass: 4,696 kg
# Orbit: GTO
# Customer: <td><a href="/wiki/SKY_Perfect_JSAT" title="SKY Perfect JSAT">SKY Perfect JSAT Group</a>
# </td>
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 24
# Length of Flight No. array: 131
# Length of Date array: 131
# Length of Time array: 131
# Length of Version Booster array: 131
# Length of Launch site array: 131
# Length of Payload array: 131
# Length of Payload mass array: 131
# Length of Orbit array: 131
# Length of Customer array: 129
# Length of Launch outcome array: 129
# Length of Booster landing array: 129
# Flight No.: 25
# Date: 27 May 2016
# Time: 21:39
# Version Booster: F9 FT
# Launch site: Cape Canaveral
# Payload: Thaicom 8
# Payload mass: 3,100 kg
# Orbit: GTO
# Customer: <td><a href="/wiki/Thaicom" title="Thaicom">Thaicom</a>
# </td>
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 25
# Length of Flight No. array: 132
# Length of Date array: 132
# Length of Time array: 132
# Length of Version Booster array: 132
# Length of Launch site array: 132
# Length of Payload array: 132
# Length of Payload mass array: 132
# Length of Orbit array: 132
# Length of Customer array: 130
# Length of Launch outcome array: 130
# Length of Booster landing array: 130
# Flight No.: 26
# Date: 15 June 2016
# Time: 14:29
# Version Booster: F9 FT
# Launch site: Cape Canaveral
# Payload: ABS-2A
# Payload mass: 3,600 kg
# Orbit: GTO
# Customer: <td><link href="mw-data:TemplateStyles:r1126788409" rel="mw-deduplicated-inline-style"/><div class="plainlist">
# <ul><li><a class="mw-redirect" href="/wiki/Asia_Broadcast_Satellite" title="Asia Broadcast Satellite">ABS</a></li>
# <li><a href="/wiki/Eutelsat" title="Eutelsat">Eutelsat</a></li></ul>
# </div>
# </td>
# Launch outcome: Success
#
# Booster landing: Failure
# Extracted row: 26
# Length of Flight No. array: 133
# Length of Date array: 133
# Length of Time array: 133
# Length of Version Booster array: 133
# Length of Launch site array: 133
# Length of Payload array: 133
# Length of Payload mass array: 133
# Length of Orbit array: 133
# Length of Customer array: 131
# Length of Launch outcome array: 131
# Length of Booster landing array: 131
# Flight No.: 27
# Date: 18 July 2016
# Time: 04:45
# Version Booster: F9 FT
# Launch site: Cape Canaveral
# Payload: SpaceX CRS-9
# Payload mass: 2,257 kg
# Orbit: LEO
# Customer: <td><a href="/wiki/NASA" title="NASA">NASA</a> (<a href="/wiki/Commercial_Resupply_Services" title="Commercial Resupply Services">CRS</a>)
# </td>
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 27
# Length of Flight No. array: 134
# Length of Date array: 134
# Length of Time array: 134
# Length of Version Booster array: 134
# Length of Launch site array: 134
# Length of Payload array: 134
# Length of Payload mass array: 134
# Length of Orbit array: 134
# Length of Customer array: 132
# Length of Launch outcome array: 132
# Length of Booster landing array: 132
# Flight No.: 28
# Date: 14 August 2016
# Time: 05:26
# Version Booster: F9 FT
# Launch site: Cape Canaveral
# Payload: JCSAT-16
# Payload mass: 4,600 kg
# Orbit: GTO
# Customer: <td><a class="mw-redirect" href="/wiki/SKY_Perfect_JSAT_Group" title="SKY Perfect JSAT Group">SKY Perfect JSAT Group</a>
# </td>
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 28
# Length of Flight No. array: 135
# Length of Date array: 135
# Length of Time array: 135
# Length of Version Booster array: 135
# Length of Launch site array: 135
# Length of Payload array: 135
# Length of Payload mass array: 135
# Length of Orbit array: 135
# Length of Customer array: 133
# Length of Launch outcome array: 133
# Length of Booster landing array: 133
# Flight No.: 29
# Date: 14 January 2017
# Time: 17:54
# Version Booster: F9 FT
# Launch site: VAFB
# Payload: Iridium NEXT
# Payload mass: 9,600 kg
# Orbit: Polar
# Customer: <td><a href="/wiki/Iridium_Communications" title="Iridium Communications">Iridium Communications</a>
# </td>
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 29
# Length of Flight No. array: 136
# Length of Date array: 136
# Length of Time array: 136
# Length of Version Booster array: 136
# Length of Launch site array: 136
# Length of Payload array: 136
# Length of Payload mass array: 136
# Length of Orbit array: 136
# Length of Customer array: 134
# Length of Launch outcome array: 134
# Length of Booster landing array: 134
# Flight No.: 30
# Date: 19 February 2017
# Time: 14:39
# Version Booster: F9 FT
# Launch site: KSC
# Payload: SpaceX CRS-10
# Payload mass: 2,490 kg
# Orbit: LEO
# Customer: <td><a href="/wiki/NASA" title="NASA">NASA</a> (<a href="/wiki/Commercial_Resupply_Services" title="Commercial Resupply Services">CRS</a>)
# </td>
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 30
# Length of Flight No. array: 137
# Length of Date array: 137
# Length of Time array: 137
# Length of Version Booster array: 137
# Length of Launch site array: 137
# Length of Payload array: 137
# Length of Payload mass array: 137
# Length of Orbit array: 137
# Length of Customer array: 135
# Length of Launch outcome array: 135
# Length of Booster landing array: 135
# Flight No.: 31
# Date: 16 March 2017
# Time: 06:00
# Version Booster: F9 FT
# Launch site: KSC
# Payload: EchoStar 23
# Payload mass: 5,600 kg
# Orbit: GTO
# Customer: <td><a href="/wiki/EchoStar" title="EchoStar">EchoStar</a>
# </td>
# Launch outcome: Success
#
# Booster landing: No attempt
# Extracted row: 31
# Length of Flight No. array: 138
# Length of Date array: 138
# Length of Time array: 138
# Length of Version Booster array: 138
# Length of Launch site array: 138
# Length of Payload array: 138
# Length of Payload mass array: 138
# Length of Orbit array: 138
# Length of Customer array: 136
# Length of Launch outcome array: 136
# Length of Booster landing array: 136
# Flight No.: 32
# Date: 30 March 2017
# Time: 22:27
# Version Booster: F9 FT♺
# Launch site: KSC
# Payload: SES-10
# Payload mass: 5,300 kg
# Orbit: GTO
# Customer: <td><a href="/wiki/SES_S.A." title="SES S.A.">SES</a>
# </td>
# Launch outcome: Success
# Booster landing: Success
# Extracted row: 32
# Length of Flight No. array: 139
# Length of Date array: 139
# Length of Time array: 139
# Length of Version Booster array: 139
# Length of Launch site array: 139
# Length of Payload array: 139
# Length of Payload mass array: 139
# Length of Orbit array: 139
# Length of Customer array: 137
# Length of Launch outcome array: 137
# Length of Booster landing array: 137
# Flight No.: 33
# Date: 1 May 2017
# Time: 11:15
# Version Booster: F9 FT
# Launch site: KSC
# Payload: NROL-76
# Payload mass: C
# Orbit: LEO
# Customer: <td><a href="/wiki/National_Reconnaissance_Office" title="National Reconnaissance Office">NRO</a>
# </td>
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 33
# Length of Flight No. array: 140
# Length of Date array: 140
# Length of Time array: 140
# Length of Version Booster array: 140
# Length of Launch site array: 140
# Length of Payload array: 140
# Length of Payload mass array: 140
# Length of Orbit array: 140
# Length of Customer array: 138
# Length of Launch outcome array: 138
# Length of Booster landing array: 138
# Flight No.: 34
# Date: 15 May 2017
# Time: 23:21
# Version Booster: F9 FT
# Launch site: KSC
# Payload: Inmarsat-5 F4
# Payload mass: 6,070 kg
# Orbit: GTO
# Customer: <td><a href="/wiki/Inmarsat" title="Inmarsat">Inmarsat</a>
# </td>
# Launch outcome: Success
#
# Booster landing: No attempt
# Extracted row: 34
# Length of Flight No. array: 141
# Length of Date array: 141
# Length of Time array: 141
# Length of Version Booster array: 141
# Length of Launch site array: 141
# Length of Payload array: 141
# Length of Payload mass array: 141
# Length of Orbit array: 141
# Length of Customer array: 139
# Length of Launch outcome array: 139
# Length of Booster landing array: 139
# Flight No.: 35
# Date: 3 June 2017
# Time: 21:07
# Version Booster: F9 FT
# Launch site: KSC
# Payload: SpaceX CRS-11
# Payload mass: 2,708 kg
# Orbit: LEO
# Customer: <td><a href="/wiki/NASA" title="NASA">NASA</a> (<a href="/wiki/Commercial_Resupply_Services" title="Commercial Resupply Services">CRS</a>)
# </td>
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 35
# Length of Flight No. array: 142
# Length of Date array: 142
# Length of Time array: 142
# Length of Version Booster array: 142
# Length of Launch site array: 142
# Length of Payload array: 142
# Length of Payload mass array: 142
# Length of Orbit array: 142
# Length of Customer array: 140
# Length of Launch outcome array: 140
# Length of Booster landing array: 140
# Flight No.: 36
# Date: 23 June 2017
# Time: 19:10
# Version Booster: F9 FTB1029.2
# Launch site: KSC
# Payload: BulgariaSat-1
# Payload mass: 3,669 kg
# Orbit: GTO
# Customer: <td><a href="/wiki/Bulsatcom" title="Bulsatcom">Bulsatcom</a>
# </td>
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 36
# Length of Flight No. array: 143
# Length of Date array: 143
# Length of Time array: 143
# Length of Version Booster array: 143
# Length of Launch site array: 143
# Length of Payload array: 143
# Length of Payload mass array: 143
# Length of Orbit array: 143
# Length of Customer array: 141
# Length of Launch outcome array: 141
# Length of Booster landing array: 141
# Flight No.: 37
# Date: 25 June 2017
# Time: 20:25
# Version Booster: F9 FT
# Launch site: VAFB
# Payload: Iridium NEXT
# Payload mass: 9,600 kg
# Orbit: LEO
# Customer: <td><a href="/wiki/Iridium_Communications" title="Iridium Communications">Iridium Communications</a>
# </td>
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 37
# Length of Flight No. array: 144
# Length of Date array: 144
# Length of Time array: 144
# Length of Version Booster array: 144
# Length of Launch site array: 144
# Length of Payload array: 144
# Length of Payload mass array: 144
# Length of Orbit array: 144
# Length of Customer array: 142
# Length of Launch outcome array: 142
# Length of Booster landing array: 142
# Flight No.: 38
# Date: 5 July 2017
# Time: 23:38
# Version Booster: F9 FT
# Launch site: KSC
# Payload: Intelsat 35e
# Payload mass: 6,761 kg
# Orbit: GTO
# Customer: <td><a href="/wiki/Intelsat" title="Intelsat">Intelsat</a>
# </td>
# Launch outcome: Success
#
# Booster landing: No attempt
# Extracted row: 38
# Length of Flight No. array: 145
# Length of Date array: 145
# Length of Time array: 145
# Length of Version Booster array: 145
# Length of Launch site array: 145
# Length of Payload array: 145
# Length of Payload mass array: 145
# Length of Orbit array: 145
# Length of Customer array: 143
# Length of Launch outcome array: 143
# Length of Booster landing array: 143
# Flight No.: 39
# Date: 14 August 2017
# Time: 16:31
# Version Booster: F9 B4
# Launch site: KSC
# Payload: SpaceX CRS-12
# Payload mass: 3,310 kg
# Orbit: LEO
# Customer: <td><a href="/wiki/NASA" title="NASA">NASA</a> (<a href="/wiki/Commercial_Resupply_Services" title="Commercial Resupply Services">CRS</a>)
# </td>
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 39
# Length of Flight No. array: 146
# Length of Date array: 146
# Length of Time array: 146
# Length of Version Booster array: 146
# Length of Launch site array: 146
# Length of Payload array: 146
# Length of Payload mass array: 146
# Length of Orbit array: 146
# Length of Customer array: 144
# Length of Launch outcome array: 144
# Length of Booster landing array: 144
# Flight No.: 40
# Date: 24 August 2017
# Time: 18:51
# Version Booster: F9 FT
# Launch site: VAFB
# Payload: Formosat-5
# Payload mass: 475 kg
# Orbit: SSO
# Customer: <td><a class="mw-redirect" href="/wiki/National_Space_Organization" title="National Space Organization">NSPO</a>
# </td>
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 40
# Length of Flight No. array: 147
# Length of Date array: 147
# Length of Time array: 147
# Length of Version Booster array: 147
# Length of Launch site array: 147
# Length of Payload array: 147
# Length of Payload mass array: 147
# Length of Orbit array: 147
# Length of Customer array: 145
# Length of Launch outcome array: 145
# Length of Booster landing array: 145
# Flight No.: 41
# Date: 7 September 2017
# Time: 14:00
# Version Booster: F9 B4
# Launch site: KSC
# Payload: Boeing X-37B
# Payload mass: 4,990 kg
# Orbit: LEO
# Customer: <td><a href="/wiki/United_States_Air_Force" title="United States Air Force">USAF</a>
# </td>
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 41
# Length of Flight No. array: 148
# Length of Date array: 148
# Length of Time array: 148
# Length of Version Booster array: 148
# Length of Launch site array: 148
# Length of Payload array: 148
# Length of Payload mass array: 148
# Length of Orbit array: 148
# Length of Customer array: 146
# Length of Launch outcome array: 146
# Length of Booster landing array: 146
# Flight No.: 42
# Date: 9 October 2017
# Time: 12:37
# Version Booster: F9 B4
# Launch site: VAFB
# Payload: Iridium NEXT
# Payload mass: 9,600 kg
# Orbit: Polar
# Customer: <td><a href="/wiki/Iridium_Communications" title="Iridium Communications">Iridium Communications</a>
# </td>
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 42
# Length of Flight No. array: 149
# Length of Date array: 149
# Length of Time array: 149
# Length of Version Booster array: 149
# Length of Launch site array: 149
# Length of Payload array: 149
# Length of Payload mass array: 149
# Length of Orbit array: 149
# Length of Customer array: 147
# Length of Launch outcome array: 147
# Length of Booster landing array: 147
# Flight No.: 43
# Date: 11 October 2017
# Time: 22:53:00
# Version Booster: F9 FTB1031.2
# Launch site: KSC
# Payload: SES-11
# Payload mass: 5,200 kg
# Orbit: GTO
# Customer: <td><link href="mw-data:TemplateStyles:r1126788409" rel="mw-deduplicated-inline-style"/><div class="plainlist">
# <ul><li><a href="/wiki/SES_S.A." title="SES S.A.">SES S.A.</a></li>
# <li><a href="/wiki/EchoStar" title="EchoStar">EchoStar</a></li></ul>
# </div>
# </td>
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 43
# Length of Flight No. array: 150
# Length of Date array: 150
# Length of Time array: 150
# Length of Version Booster array: 150
# Length of Launch site array: 150
# Length of Payload array: 150
# Length of Payload mass array: 150
# Length of Orbit array: 150
# Length of Customer array: 148
# Length of Launch outcome array: 148
# Length of Booster landing array: 148
# Flight No.: 44
# Date: 30 October 2017
# Time: 19:34
# Version Booster: F9 B4
# Launch site: KSC
# Payload: Koreasat 5A
# Payload mass: 3,500 kg
# Orbit: GTO
# Customer: <td><a href="/wiki/KT_Corporation" title="KT Corporation">KT Corporation</a>
# </td>
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 44
# Length of Flight No. array: 151
# Length of Date array: 151
# Length of Time array: 151
# Length of Version Booster array: 151
# Length of Launch site array: 151
# Length of Payload array: 151
# Length of Payload mass array: 151
# Length of Orbit array: 151
# Length of Customer array: 149
# Length of Launch outcome array: 149
# Length of Booster landing array: 149
# Flight No.: 45
# Date: 15 December 2017
# Time: 15:36
# Version Booster: F9 FTB1035.2
# Launch site: Cape Canaveral
# Payload: SpaceX CRS-13
# Payload mass: 2,205 kg
# Orbit: LEO
# Customer: <td><a href="/wiki/NASA" title="NASA">NASA</a> (<a href="/wiki/Commercial_Resupply_Services" title="Commercial Resupply Services">CRS</a>)
# </td>
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 45
# Length of Flight No. array: 152
# Length of Date array: 152
# Length of Time array: 152
# Length of Version Booster array: 152
# Length of Launch site array: 152
# Length of Payload array: 152
# Length of Payload mass array: 152
# Length of Orbit array: 152
# Length of Customer array: 150
# Length of Launch outcome array: 150
# Length of Booster landing array: 150
# Flight No.: 46
# Date: 23 December 2017
# Time: 01:27
# Version Booster: F9 FTB1036.2
# Launch site: VAFB
# Payload: Iridium NEXT
# Payload mass: 9,600 kg
# Orbit: Polar
# Customer: <td><a href="/wiki/Iridium_Communications" title="Iridium Communications">Iridium Communications</a>
# </td>
# Launch outcome: Success
# Booster landing: Controlled
# Extracted row: 46
# Length of Flight No. array: 153
# Length of Date array: 153
# Length of Time array: 153
# Length of Version Booster array: 153
# Length of Launch site array: 153
# Length of Payload array: 153
# Length of Payload mass array: 153
# Length of Orbit array: 153
# Length of Customer array: 151
# Length of Launch outcome array: 151
# Length of Booster landing array: 151
# Flight No.: 47
# Date: 8 January 2018
# Time: 01:00
# Version Booster: F9 B4
# Launch site: CCAFS
# Payload: Zuma
# Payload mass: C
# Orbit: LEO
# Customer: <td><a href="/wiki/Northrop_Grumman" title="Northrop Grumman">Northrop Grumman</a> <sup class="reference" id="cite_ref-249"><a href="#cite_note-249">[f]</a></sup><sup class="reference" id="cite_ref-zuma_246-2"><a href="#cite_note-zuma-246">[238]</a></sup>
# </td>
# Launch outcome: Success
# Booster landing: Success
# Extracted row: 47
# Length of Flight No. array: 154
# Length of Date array: 154
# Length of Time array: 154
# Length of Version Booster array: 154
# Length of Launch site array: 154
# Length of Payload array: 154
# Length of Payload mass array: 154
# Length of Orbit array: 154
# Length of Customer array: 152
# Length of Launch outcome array: 152
# Length of Booster landing array: 152
# Flight No.: 48
# Date: 31 January 2018
# Time: 21:25
# Version Booster: F9 FTB1032.2
# Launch site: CCAFS
# Payload: GovSat-1
# Payload mass: 4,230 kg
# Orbit: GTO
# Customer: <td><a href="/wiki/SES_S.A." title="SES S.A.">SES</a>
# </td>
# Launch outcome: Success
# Booster landing: Controlled
# Extracted row: 48
# Length of Flight No. array: 155
# Length of Date array: 155
# Length of Time array: 155
# Length of Version Booster array: 155
# Length of Launch site array: 155
# Length of Payload array: 155
# Length of Payload mass array: 155
# Length of Orbit array: 155
# Length of Customer array: 153
# Length of Launch outcome array: 153
# Length of Booster landing array: 153
# Flight No.: 49
# Date: 22 February 2018
# Time: 14:17
# Version Booster: F9 FTB1038.2
# Launch site: VAFB
# Payload: Paz
# Payload mass: 2,150 kg
# Orbit: SSO
# Customer: <td><link href="mw-data:TemplateStyles:r1126788409" rel="mw-deduplicated-inline-style"/><div class="plainlist">
# <ul><li><a href="/wiki/Hisdesat" title="Hisdesat">Hisdesat</a></li>
# <li><a href="/wiki/ExactEarth" title="ExactEarth">exactEarth</a></li>
# <li><a href="/wiki/SpaceX" title="SpaceX">SpaceX</a></li></ul>
# </div>
# </td>
# Launch outcome: Success
# Booster landing: No attempt
# Extracted row: 49
# Length of Flight No. array: 156
# Length of Date array: 156
# Length of Time array: 156
# Length of Version Booster array: 156
# Length of Launch site array: 156
# Length of Payload array: 156
# Length of Payload mass array: 156
# Length of Orbit array: 156
# Length of Customer array: 154
# Length of Launch outcome array: 154
# Length of Booster landing array: 154
# Flight No.: 50
# Date: 6 March 2018
# Time: 05:33
# Version Booster: F9 B4
# Launch site: CCAFS
# Payload: Hispasat 30W-6
# Payload mass: 6,092 kg
# Orbit: GTO
# Customer: <td><link href="mw-data:TemplateStyles:r1126788409" rel="mw-deduplicated-inline-style"/><div class="plainlist">
# <ul><li><a href="/wiki/Hispasat" title="Hispasat">Hispasat</a><sup class="reference" id="cite_ref-spx20150914_286-1"><a href="#cite_note-spx20150914-286">[277]</a></sup></li>
# <li><a href="/wiki/NovaWurks" title="NovaWurks">NovaWurks</a></li></ul>
# </div>
# </td>
# Launch outcome: Success
# Booster landing: No attempt
# Extracted row: 50
# Length of Flight No. array: 157
# Length of Date array: 157
# Length of Time array: 157
# Length of Version Booster array: 157
# Length of Launch site array: 157
# Length of Payload array: 157
# Length of Payload mass array: 157
# Length of Orbit array: 157
# Length of Customer array: 155
# Length of Launch outcome array: 155
# Length of Booster landing array: 155
# Flight No.: 51
# Date: 30 March 2018
# Time: 14:14
# Version Booster: F9 B4B1041.2
# Launch site: VAFB
# Payload: Iridium NEXT
# Payload mass: 9,600 kg
# Orbit: Polar
# Customer: <td><a href="/wiki/Iridium_Communications" title="Iridium Communications">Iridium Communications</a>
# </td>
# Launch outcome: Success
# Booster landing: No attempt
# Extracted row: 51
# Length of Flight No. array: 158
# Length of Date array: 158
# Length of Time array: 158
# Length of Version Booster array: 158
# Length of Launch site array: 158
# Length of Payload array: 158
# Length of Payload mass array: 158
# Length of Orbit array: 158
# Length of Customer array: 156
# Length of Launch outcome array: 156
# Length of Booster landing array: 156
# Flight No.: 52
# Date: 2 April 2018
# Time: 20:30
# Version Booster: F9 B4B1039.2
# Launch site: CCAFS
# Payload: SpaceX CRS-14
# Payload mass: 2,647 kg
# Orbit: LEO
# Customer: <td><a href="/wiki/NASA" title="NASA">NASA</a> (<a href="/wiki/Commercial_Resupply_Services" title="Commercial Resupply Services">CRS</a>)
# </td>
# Launch outcome: Success
# Booster landing: No attempt
# Extracted row: 52
# Length of Flight No. array: 159
# Length of Date array: 159
# Length of Time array: 159
# Length of Version Booster array: 159
# Length of Launch site array: 159
# Length of Payload array: 159
# Length of Payload mass array: 159
# Length of Orbit array: 159
# Length of Customer array: 157
# Length of Launch outcome array: 157
# Length of Booster landing array: 157
# Flight No.: 53
# Date: 18 April 2018
# Time: 22:51
# Version Booster: F9 B4
# Launch site: CCAFS
# Payload: Transiting Exoplanet Survey Satellite
# Payload mass: 362 kg
# Orbit: HEO
# Customer: <td><a href="/wiki/NASA" title="NASA">NASA</a> (<a class="mw-redirect" href="/wiki/Launch_Services_Program" title="Launch Services Program">LSP</a>)
# </td>
# Launch outcome: Success
# Booster landing: Success
# Extracted row: 53
# Length of Flight No. array: 160
# Length of Date array: 160
# Length of Time array: 160
# Length of Version Booster array: 160
# Length of Launch site array: 160
# Length of Payload array: 160
# Length of Payload mass array: 160
# Length of Orbit array: 160
# Length of Customer array: 158
# Length of Launch outcome array: 158
# Length of Booster landing array: 158
# Flight No.: 54
# Date: 11 May 2018
# Time: 20:14
# Version Booster: F9 B5B1046.1
# Launch site: KSC
# Payload: Bangabandhu-1
# Payload mass: 3,600 kg
# Orbit: GTO
# Customer: <td><a href="/wiki/Thales_Alenia_Space" title="Thales Alenia Space">Thales-Alenia</a> / <a href="/wiki/Bangladesh_Telecommunication_Regulatory_Commission" title="Bangladesh Telecommunication Regulatory Commission">BTRC</a>
# </td>
# Launch outcome: Success
# Booster landing: Success
# Extracted row: 54
# Length of Flight No. array: 161
# Length of Date array: 161
# Length of Time array: 161
# Length of Version Booster array: 161
# Length of Launch site array: 161
# Length of Payload array: 161
# Length of Payload mass array: 161
# Length of Orbit array: 161
# Length of Customer array: 159
# Length of Launch outcome array: 159
# Length of Booster landing array: 159
# Flight No.: 55
# Date: 22 May 2018
# Time: 19:47
# Version Booster: F9 B4B1043.2
# Launch site: VAFB
# Payload: Iridium NEXT
# Payload mass: 6,460 kg
# Orbit: Polar
# Customer: <td><link href="mw-data:TemplateStyles:r1126788409" rel="mw-deduplicated-inline-style"/><div class="plainlist">
# <ul><li><a href="/wiki/Iridium_Communications" title="Iridium Communications">Iridium Communications</a></li>
# <li><a href="/wiki/GFZ_German_Research_Centre_for_Geosciences" title="GFZ German Research Centre for Geosciences">GFZ</a> • <a href="/wiki/NASA" title="NASA">NASA</a></li></ul>
# </div>
# </td>
# Launch outcome: Success
# Booster landing: No attempt
# Extracted row: 55
# Length of Flight No. array: 162
# Length of Date array: 162
# Length of Time array: 162
# Length of Version Booster array: 162
# Length of Launch site array: 162
# Length of Payload array: 162
# Length of Payload mass array: 162
# Length of Orbit array: 162
# Length of Customer array: 160
# Length of Launch outcome array: 160
# Length of Booster landing array: 160
# Flight No.: 56
# Date: 4 June 2018
# Time: 04:45
# Version Booster: F9 B4B1040.2
# Launch site: CCAFS
# Payload: SES-12
# Payload mass: 5,384 kg
# Orbit: GTO
# Customer: <td><a href="/wiki/SES_S.A." title="SES S.A.">SES</a>
# </td>
# Launch outcome: Success
# Booster landing: No attempt
# Extracted row: 56
# Length of Flight No. array: 163
# Length of Date array: 163
# Length of Time array: 163
# Length of Version Booster array: 163
# Length of Launch site array: 163
# Length of Payload array: 163
# Length of Payload mass array: 163
# Length of Orbit array: 163
# Length of Customer array: 161
# Length of Launch outcome array: 161
# Length of Booster landing array: 161
# Flight No.: 57
# Date: 29 June 2018
# Time: 09:42
# Version Booster: F9 B4B1045.2
# Launch site: CCAFS
# Payload: SpaceX CRS-15
# Payload mass: 2,697 kg
# Orbit: LEO
# Customer: <td><a href="/wiki/NASA" title="NASA">NASA</a> (<a href="/wiki/Commercial_Resupply_Services" title="Commercial Resupply Services">CRS</a>)
# </td>
# Launch outcome: Success
# Booster landing: No attempt
# Extracted row: 57
# Length of Flight No. array: 164
# Length of Date array: 164
# Length of Time array: 164
# Length of Version Booster array: 164
# Length of Launch site array: 164
# Length of Payload array: 164
# Length of Payload mass array: 164
# Length of Orbit array: 164
# Length of Customer array: 162
# Length of Launch outcome array: 162
# Length of Booster landing array: 162
# Flight No.: 58
# Date: 22 July 2018
# Time: 05:50
# Version Booster: F9 B5
# Launch site: CCAFS
# Payload: Telstar 19V
# Payload mass: 7,075 kg
# Orbit: GTO
# Customer: <td><a href="/wiki/Telesat" title="Telesat">Telesat</a>
# </td>
# Launch outcome: Success
# Booster landing: Success
# Extracted row: 58
# Length of Flight No. array: 165
# Length of Date array: 165
# Length of Time array: 165
# Length of Version Booster array: 165
# Length of Launch site array: 165
# Length of Payload array: 165
# Length of Payload mass array: 165
# Length of Orbit array: 165
# Length of Customer array: 163
# Length of Launch outcome array: 163
# Length of Booster landing array: 163
# Flight No.: 59
# Date: 25 July 2018
# Time: 11:39
# Version Booster: F9 B5B1048
# Launch site: VAFB
# Payload: Iridium NEXT
# Payload mass: 9,600 kg
# Orbit: Polar
# Customer: <td><a href="/wiki/Iridium_Communications" title="Iridium Communications">Iridium Communications</a>
# </td>
# Launch outcome: Success
# Booster landing: Success
# Extracted row: 59
# Length of Flight No. array: 166
# Length of Date array: 166
# Length of Time array: 166
# Length of Version Booster array: 166
# Length of Launch site array: 166
# Length of Payload array: 166
# Length of Payload mass array: 166
# Length of Orbit array: 166
# Length of Customer array: 164
# Length of Launch outcome array: 164
# Length of Booster landing array: 164
# Flight No.: 60
# Date: 7 August 2018
# Time: 05:18
# Version Booster: F9 B5B1046.2
# Launch site: CCAFS
# Payload: Merah Putih
# Payload mass: 5,800 kg
# Orbit: GTO
# Customer: <td><a href="/wiki/Telkom_Indonesia" title="Telkom Indonesia">Telkom Indonesia</a>
# </td>
# Launch outcome: Success
# Booster landing: Success
# Extracted row: 60
# Length of Flight No. array: 167
# Length of Date array: 167
# Length of Time array: 167
# Length of Version Booster array: 167
# Length of Launch site array: 167
# Length of Payload array: 167
# Length of Payload mass array: 167
# Length of Orbit array: 167
# Length of Customer array: 165
# Length of Launch outcome array: 165
# Length of Booster landing array: 165
# Flight No.: 61
# Date: 10 September 2018
# Time: 04:45
# Version Booster: F9 B5
# Launch site: CCAFS
# Payload: Telstar 18V
# Payload mass: 7,060 kg
# Orbit: GTO
# Customer: <td><a href="/wiki/Telesat" title="Telesat">Telesat</a>
# </td>
# Launch outcome: Success
# Booster landing: Success
# Extracted row: 61
# Length of Flight No. array: 168
# Length of Date array: 168
# Length of Time array: 168
# Length of Version Booster array: 168
# Length of Launch site array: 168
# Length of Payload array: 168
# Length of Payload mass array: 168
# Length of Orbit array: 168
# Length of Customer array: 166
# Length of Launch outcome array: 166
# Length of Booster landing array: 166
# Flight No.: 62
# Date: 8 October 2018
# Time: 02:22
# Version Booster: F9 B5B1048.2
# Launch site: VAFB
# Payload: SAOCOM 1A
# Payload mass: 3,000 kg
# Orbit: SSO
# Customer: <td><a href="/wiki/Comisi%C3%B3n_Nacional_de_Actividades_Espaciales" title="Comisión Nacional de Actividades Espaciales">CONAE</a>
# </td>
# Launch outcome: Success
# Booster landing: Success
# Extracted row: 62
# Length of Flight No. array: 169
# Length of Date array: 169
# Length of Time array: 169
# Length of Version Booster array: 169
# Length of Launch site array: 169
# Length of Payload array: 169
# Length of Payload mass array: 169
# Length of Orbit array: 169
# Length of Customer array: 167
# Length of Launch outcome array: 167
# Length of Booster landing array: 167
# Flight No.: 63
# Date: 15 November 2018
# Time: 20:46
# Version Booster: F9 B5B1047.2
# Launch site: KSC
# Payload: Es'hail 2
# Payload mass: 5,300 kg
# Orbit: GTO
# Customer: <td><a href="/wiki/Es%27hailSat" title="Es'hailSat">Es'hailSat</a>
# </td>
# Launch outcome: Success
# Booster landing: Success
# Extracted row: 63
# Length of Flight No. array: 170
# Length of Date array: 170
# Length of Time array: 170
# Length of Version Booster array: 170
# Length of Launch site array: 170
# Length of Payload array: 170
# Length of Payload mass array: 170
# Length of Orbit array: 170
# Length of Customer array: 168
# Length of Launch outcome array: 168
# Length of Booster landing array: 168
# Flight No.: 64
# Date: 3 December 2018
# Time: 18:34:05
# Version Booster: F9 B5B1046.3
# Launch site: VAFB
# Payload: SSO-A
# Payload mass: ~4,000 kg
# Orbit: SSO
# Customer: <td><a href="/wiki/Spaceflight_Industries" title="Spaceflight Industries">Spaceflight Industries</a>
# </td>
# Launch outcome: Success
# Booster landing: Success
# Extracted row: 64
# Length of Flight No. array: 171
# Length of Date array: 171
# Length of Time array: 171
# Length of Version Booster array: 171
# Length of Launch site array: 171
# Length of Payload array: 171
# Length of Payload mass array: 171
# Length of Orbit array: 171
# Length of Customer array: 169
# Length of Launch outcome array: 169
# Length of Booster landing array: 169
# Flight No.: 65
# Date: 5 December 2018
# Time: 18:16
# Version Booster: F9 B5
# Launch site: CCAFS
# Payload: SpaceX CRS-16
# Payload mass: 2,500 kg
# Orbit: LEO
# Customer: <td><a href="/wiki/NASA" title="NASA">NASA</a> (<a href="/wiki/Commercial_Resupply_Services" title="Commercial Resupply Services">CRS</a>)
# </td>
# Launch outcome: Success
#
# Booster landing: Failure
# Extracted row: 65
# Length of Flight No. array: 172
# Length of Date array: 172
# Length of Time array: 172
# Length of Version Booster array: 172
# Length of Launch site array: 172
# Length of Payload array: 172
# Length of Payload mass array: 172
# Length of Orbit array: 172
# Length of Customer array: 170
# Length of Launch outcome array: 170
# Length of Booster landing array: 170
# Flight No.: 66
# Date: 23 December 2018
# Time: 13:51
# Version Booster: F9 B5
# Launch site: CCAFS
# Payload: GPS III
# Payload mass: 4,400 kg
# Orbit: MEO
# Customer: <td><a href="/wiki/United_States_Air_Force" title="United States Air Force">USAF</a>
# </td>
# Launch outcome: Success
# Booster landing: No attempt
# Extracted row: 66
# Length of Flight No. array: 173
# Length of Date array: 173
# Length of Time array: 173
# Length of Version Booster array: 173
# Length of Launch site array: 173
# Length of Payload array: 173
# Length of Payload mass array: 173
# Length of Orbit array: 173
# Length of Customer array: 171
# Length of Launch outcome array: 171
# Length of Booster landing array: 171
# Flight No.: 67
# Date: 11 January 2019
# ...
# Customer: <td><a href="/wiki/NASA" title="NASA">NASA</a> (<a href="/wiki/Commercial_Crew_Program" title="Commercial Crew Program">CCP</a>)<sup class="reference" id="cite_ref-CCD6_509-1"><a href="#cite_note-CCD6-509">[497]</a></sup>
# </td>
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 98
# Length of Flight No. array: 205
# Length of Date array: 205
# Length of Time array: 205
# Length of Version Booster array: 205
# Length of Launch site array: 205
# Length of Payload array: 205
# Length of Payload mass array: 205
# Length of Orbit array: 205
# Length of Customer array: 203
# Length of Launch outcome array: 203
# Length of Booster landing array: 203
# Flight No.: 99
# Date: 21 November 2020
# Time: 17:17:08
# Version Booster: F9 B5
# Launch site: VAFB
# Payload: Sentinel-6 Michael Freilich (Jason-CS A)
# Payload mass: 1,192 kg
# Orbit: LEO
# Customer: <td><a href="/wiki/NASA" title="NASA">NASA</a> / <a class="mw-redirect" href="/wiki/NOAA" title="NOAA">NOAA</a> / <a class="mw-redirect" href="/wiki/ESA" title="ESA">ESA</a> / <a class="mw-redirect" href="/wiki/EUMETSAT" title="EUMETSAT">EUMETSAT</a>
# </td>
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 99
# Length of Flight No. array: 206
# Length of Date array: 206
# Length of Time array: 206
# Length of Version Booster array: 206
# Length of Launch site array: 206
# Length of Payload array: 206
# Length of Payload mass array: 206
# Length of Orbit array: 206
# Length of Customer array: 204
# Length of Launch outcome array: 204
# Length of Booster landing array: 204
# Flight No.: 100
# Date: 25 November 2020
# Time: 02:13
# Version Booster: F9 B5 ♺
# Launch site: CCAFS
# Payload: Starlink
# Payload mass: 15,600 kg
# Orbit: LEO
# Customer: <td><a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# </td>
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 100
# Length of Flight No. array: 207
# Length of Date array: 207
# Length of Time array: 207
# Length of Version Booster array: 207
# Length of Launch site array: 207
# Length of Payload array: 207
# Length of Payload mass array: 207
# Length of Orbit array: 207
# Length of Customer array: 205
# Length of Launch outcome array: 205
# Length of Booster landing array: 205
# Flight No.: 101
# Date: 6 December 2020
# Time: 16:17:08
# Version Booster: F9 B5 ♺
# Launch site: KSC
# Payload: SpaceX CRS-21
# Payload mass: 2,972 kg
# Orbit: LEO
# Customer: <td><a href="/wiki/NASA" title="NASA">NASA</a> (<a href="/wiki/Commercial_Resupply_Services" title="Commercial Resupply Services">CRS</a>)
# </td>
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 101
# Length of Flight No. array: 208
# Length of Date array: 208
# Length of Time array: 208
# Length of Version Booster array: 208
# Length of Launch site array: 208
# Length of Payload array: 208
# Length of Payload mass array: 208
# Length of Orbit array: 208
# Length of Customer array: 206
# Length of Launch outcome array: 206
# Length of Booster landing array: 206
# Flight No.: 102
# Date: 13 December 2020
# Time: 17:30:00
# Version Booster: F9 B5 ♺
# Launch site: CCSFSSLC-40
# Payload: SXM-7
# Payload mass: 7,000 kg
# Orbit: GTO
# Customer: <td><a href="/wiki/Sirius_XM" title="Sirius XM">Sirius XM</a>
# </td>
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 102
# Length of Flight No. array: 209
# Length of Date array: 209
# Length of Time array: 209
# Length of Version Booster array: 209
# Length of Launch site array: 209
# Length of Payload array: 209
# Length of Payload mass array: 209
# Length of Orbit array: 209
# Length of Customer array: 207
# Length of Launch outcome array: 207
# Length of Booster landing array: 207
# Flight No.: 103
# Date: 19 December 2020
# Time: 14:00:00
# Version Booster: F9 B5 ♺
# Launch site: KSC
# Payload: NROL-108
# Payload mass: C
# Orbit: LEO
# Customer: <td><a href="/wiki/National_Reconnaissance_Office" title="National Reconnaissance Office">NRO</a>
# </td>
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 103
# Length of Flight No. array: 210
# Length of Date array: 210
# Length of Time array: 210
# Length of Version Booster array: 210
# Length of Launch site array: 210
# Length of Payload array: 210
# Length of Payload mass array: 210
# Length of Orbit array: 210
# Length of Customer array: 208
# Length of Launch outcome array: 208
# Length of Booster landing array: 208
# Flight No.: 104
# Date: 8 January 2021
# Time: 02:15
# Version Booster: F9 B5
# Launch site: CCSFS
# Payload: Türksat 5A
# Payload mass: 3,500 kg
# Orbit: GTO
# Customer: <td><a href="/wiki/T%C3%BCrksat_(company)" title="Türksat (company)">Türksat</a>
# </td>
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 104
# Length of Flight No. array: 211
# Length of Date array: 211
# Length of Time array: 211
# Length of Version Booster array: 211
# Length of Launch site array: 211
# Length of Payload array: 211
# Length of Payload mass array: 211
# Length of Orbit array: 211
# Length of Customer array: 209
# Length of Launch outcome array: 209
# Length of Booster landing array: 209
# Flight No.: 105
# Date: 20 January 2021
# Time: 13:02
# Version Booster: F9 B5B1051.8
# Launch site: KSC
# Payload: Starlink
# Payload mass: 15,600 kg
# Orbit: LEO
# Customer: <td><a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# </td>
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 105
# Length of Flight No. array: 212
# Length of Date array: 212
# Length of Time array: 212
# Length of Version Booster array: 212
# Length of Launch site array: 212
# Length of Payload array: 212
# Length of Payload mass array: 212
# Length of Orbit array: 212
# Length of Customer array: 210
# Length of Launch outcome array: 210
# Length of Booster landing array: 210
# Flight No.: 106
# Date: 24 January 2021
# Time: 15:00
# Version Booster: F9 B5B1058.5
# Launch site: CCSFS
# Payload: Transporter-1
# Payload mass: ~5,000 kg
# Orbit: SSO
# Customer: <td>Various
# </td>
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 106
# Length of Flight No. array: 213
# Length of Date array: 213
# Length of Time array: 213
# Length of Version Booster array: 213
# Length of Launch site array: 213
# Length of Payload array: 213
# Length of Payload mass array: 213
# Length of Orbit array: 213
# Length of Customer array: 211
# Length of Launch outcome array: 211
# Length of Booster landing array: 211
# Flight No.: 107
# Date: 4 February 2021
# Time: 06:19
# Version Booster: F9 B5 ♺
# Launch site: CCSFS
# Payload: Starlink
# Payload mass: 15,600 kg
# Orbit: LEO
# Customer: <td><a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# </td>
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 107
# Length of Flight No. array: 214
# Length of Date array: 214
# Length of Time array: 214
# Length of Version Booster array: 214
# Length of Launch site array: 214
# Length of Payload array: 214
# Length of Payload mass array: 214
# Length of Orbit array: 214
# Length of Customer array: 212
# Length of Launch outcome array: 212
# Length of Booster landing array: 212
# Flight No.: 108
# Date: 16 February 2021
# Time: 03:59:37
# Version Booster: F9 B5 ♺
# Launch site: CCSFS
# Payload: Starlink
# Payload mass: 15,600 kg
# Orbit: LEO
# Customer: <td><a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# </td>
# Launch outcome: Success
#
# Booster landing: Failure
# Extracted row: 108
# Length of Flight No. array: 215
# Length of Date array: 215
# Length of Time array: 215
# Length of Version Booster array: 215
# Length of Launch site array: 215
# Length of Payload array: 215
# Length of Payload mass array: 215
# Length of Orbit array: 215
# Length of Customer array: 213
# Length of Launch outcome array: 213
# Length of Booster landing array: 213
# Flight No.: 109
# Date: 4 March 2021
# Time: 08:24
# Version Booster: F9 B5 ♺
# Launch site: KSC
# Payload: Starlink
# Payload mass: 15,600 kg
# Orbit: LEO
# Customer: <td><a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# </td>
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 109
# Length of Flight No. array: 216
# Length of Date array: 216
# Length of Time array: 216
# Length of Version Booster array: 216
# Length of Launch site array: 216
# Length of Payload array: 216
# Length of Payload mass array: 216
# Length of Orbit array: 216
# Length of Customer array: 214
# Length of Launch outcome array: 214
# Length of Booster landing array: 214
# Flight No.: 110
# Date: 11 March 2021
# Time: 08:13:29
# Version Booster: F9 B5 ♺
# Launch site: CCSFS
# Payload: Starlink
# Payload mass: 15,600 kg
# Orbit: LEO
# Customer: <td><a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# </td>
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 110
# Length of Flight No. array: 217
# Length of Date array: 217
# Length of Time array: 217
# Length of Version Booster array: 217
# Length of Launch site array: 217
# Length of Payload array: 217
# Length of Payload mass array: 217
# Length of Orbit array: 217
# Length of Customer array: 215
# Length of Launch outcome array: 215
# Length of Booster landing array: 215
# Flight No.: 111
# Date: 14 March 2021
# Time: 10:01
# Version Booster: F9 B5 ♺
# Launch site: KSC
# Payload: Starlink
# Payload mass: 15,600 kg
# Orbit: LEO
# Customer: <td><a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# </td>
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 111
# Length of Flight No. array: 218
# Length of Date array: 218
# Length of Time array: 218
# Length of Version Booster array: 218
# Length of Launch site array: 218
# Length of Payload array: 218
# Length of Payload mass array: 218
# Length of Orbit array: 218
# Length of Customer array: 216
# Length of Launch outcome array: 216
# Length of Booster landing array: 216
# Flight No.: 112
# Date: 24 March 2021
# Time: 08:28
# Version Booster: F9 B5B1060.6
# Launch site: CCSFS
# Payload: Starlink
# Payload mass: 15,600 kg
# Orbit: LEO
# Customer: <td><a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# </td>
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 112
# Length of Flight No. array: 219
# Length of Date array: 219
# Length of Time array: 219
# Length of Version Booster array: 219
# Length of Launch site array: 219
# Length of Payload array: 219
# Length of Payload mass array: 219
# Length of Orbit array: 219
# Length of Customer array: 217
# Length of Launch outcome array: 217
# Length of Booster landing array: 217
# Flight No.: 113
# Date: 7 April 2021
# Time: 16:34
# Version Booster: F9 B5 ♺
# Launch site: CCSFS
# Payload: Starlink
# Payload mass: 15,600 kg
# Orbit: LEO
# Customer: <td><a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# </td>
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 113
# Length of Flight No. array: 220
# Length of Date array: 220
# Length of Time array: 220
# Length of Version Booster array: 220
# Length of Launch site array: 220
# Length of Payload array: 220
# Length of Payload mass array: 220
# Length of Orbit array: 220
# Length of Customer array: 218
# Length of Launch outcome array: 218
# Length of Booster landing array: 218
# Flight No.: 114
# Date: 23 April 2021
# Time: 9:49
# Version Booster: F9 B5B1061.2
# Launch site: KSC
# Payload: Crew-2
# Payload mass: ~13,000 kg
# Orbit: LEO
# Customer: <td><a href="/wiki/NASA" title="NASA">NASA</a> (<a class="mw-redirect" href="/wiki/ISS_Crew_Transportation_Services" title="ISS Crew Transportation Services">CTS</a>)<sup class="reference" id="cite_ref-CCD6_509-2"><a href="#cite_note-CCD6-509">[497]</a></sup>
# </td>
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 114
# Length of Flight No. array: 221
# Length of Date array: 221
# Length of Time array: 221
# Length of Version Booster array: 221
# Length of Launch site array: 221
# Length of Payload array: 221
# Length of Payload mass array: 221
# Length of Orbit array: 221
# Length of Customer array: 219
# Length of Launch outcome array: 219
# Length of Booster landing array: 219
# Flight No.: 115
# Date: 29 April 2021
# Time: 03:44
# Version Booster: F9 B5B1060.7
# Launch site: CCSFS
# Payload: Starlink
# Payload mass: 15,600 kg
# Orbit: LEO
# Customer: <td><a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# </td>
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 115
# Length of Flight No. array: 222
# Length of Date array: 222
# Length of Time array: 222
# Length of Version Booster array: 222
# Length of Launch site array: 222
# Length of Payload array: 222
# Length of Payload mass array: 222
# Length of Orbit array: 222
# Length of Customer array: 220
# Length of Launch outcome array: 220
# Length of Booster landing array: 220
# Flight No.: 116
# Date: 4 May 2021
# Time: 19:01
# Version Booster: F9 B5B1049.9
# Launch site: KSC
# Payload: Starlink
# Payload mass: 15,600 kg
# Orbit: LEO
# Customer: <td><a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# </td>
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 116
# Length of Flight No. array: 223
# Length of Date array: 223
# Length of Time array: 223
# Length of Version Booster array: 223
# Length of Launch site array: 223
# Length of Payload array: 223
# Length of Payload mass array: 223
# Length of Orbit array: 223
# Length of Customer array: 221
# Length of Launch outcome array: 221
# Length of Booster landing array: 221
# Flight No.: 117
# Date: 9 May 2021
# Time: 06:42
# Version Booster: F9 B5B1051.10
# Launch site: CCSFS
# Payload: Starlink
# Payload mass: 15,600 kg
# Orbit: LEO
# Customer: <td><a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# </td>
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 117
# Length of Flight No. array: 224
# Length of Date array: 224
# Length of Time array: 224
# Length of Version Booster array: 224
# Length of Launch site array: 224
# Length of Payload array: 224
# Length of Payload mass array: 224
# Length of Orbit array: 224
# Length of Customer array: 222
# Length of Launch outcome array: 222
# Length of Booster landing array: 222
# Flight No.: 118
# Date: 15 May 2021
# Time: 22:56
# Version Booster: F9 B5B1058.8
# Launch site: KSCLC-39A
# Payload: Starlink
# Payload mass: ~14,000 kg
# Orbit: LEO
# Customer: <td><a href="/wiki/SpaceX" title="SpaceX">SpaceX</a><br/> <a href="/wiki/Capella_Space" title="Capella Space">Capella Space</a> and <a href="/wiki/Tyvak" title="Tyvak">Tyvak</a>
# </td>
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 118
# Length of Flight No. array: 225
# Length of Date array: 225
# Length of Time array: 225
# Length of Version Booster array: 225
# Length of Launch site array: 225
# Length of Payload array: 225
# Length of Payload mass array: 225
# Length of Orbit array: 225
# Length of Customer array: 223
# Length of Launch outcome array: 223
# Length of Booster landing array: 223
# Flight No.: 119
# Date: 26 May 2021
# Time: 18:59
# Version Booster: F9 B5B1063.2
# Launch site: CCSFSSLC-40
# Payload: Starlink
# Payload mass: 15,600 kg
# Orbit: LEO
# Customer: <td><a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# </td>
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 119
# Length of Flight No. array: 226
# Length of Date array: 226
# Length of Time array: 226
# Length of Version Booster array: 226
# Length of Launch site array: 226
# Length of Payload array: 226
# Length of Payload mass array: 226
# Length of Orbit array: 226
# Length of Customer array: 224
# Length of Launch outcome array: 224
# Length of Booster landing array: 224
# Flight No.: 120
# Date: 3 June 2021
# Time: 17:29
# Version Booster: F9 B5B1067.1
# Launch site: KSC
# Payload: SpaceX CRS-22
# Payload mass: 3,328 kg
# Orbit: LEO
# Customer: <td><a href="/wiki/NASA" title="NASA">NASA</a> (<a href="/wiki/Commercial_Resupply_Services" title="Commercial Resupply Services">CRS</a>)
# </td>
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 120
# Length of Flight No. array: 227
# Length of Date array: 227
# Length of Time array: 227
# Length of Version Booster array: 227
# Length of Launch site array: 227
# Length of Payload array: 227
# Length of Payload mass array: 227
# Length of Orbit array: 227
# Length of Customer array: 225
# Length of Launch outcome array: 225
# Length of Booster landing array: 225
# Flight No.: 121
# Date: 6 June 2021
# Time: 04:26
# Version Booster: F9 B5
# Launch site: CCSFS
# Payload: SXM-8
# Payload mass: 7,000 kg
# Orbit: GTO
# Customer: <td><a href="/wiki/Sirius_XM" title="Sirius XM">Sirius XM</a>
# </td>
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 121
# Length of Flight No. array: 228
# Length of Date array: 228
# Length of Time array: 228
# Length of Version Booster array: 228
# Length of Launch site array: 228
# Length of Payload array: 228
# Length of Payload mass array: 228
# Length of Orbit array: 228
# Length of Customer array: 226
# Length of Launch outcome array: 226
# Length of Booster landing array: 226

# %% [markdown]
# After you have fill in the parsed launch record values into `launch_dict`, you can create a dataframe from it.

# %%
df = pd.DataFrame({ key:pd.Series(value) for key, value in launch_dict.items()})
# Out:
#   Flight No. Launch site                               Payload Payload mass  \
# 0          1       CCAFS  Dragon Spacecraft Qualification Unit            0
# 1          1       CCAFS  Dragon Spacecraft Qualification Unit            0
# 2          2       CCAFS                                Dragon            0
# 3          3       CCAFS                                Dragon       525 kg
# 4          4       CCAFS                          SpaceX CRS-1     4,700 kg
#
#   Orbit Customer Launch outcome             Date   Time Version Booster  \
# 0   LEO   SpaceX      Success\n      4 June 2010  18:45  F9 v1.0B0003.1
# 1   LEO     NASA        Success      4 June 2010  18:45  F9 v1.0B0003.1
# 2   LEO     NASA        Success  8 December 2010  15:43  F9 v1.0B0004.1
# 3   LEO     NASA      Success\n      22 May 2012  07:44  F9 v1.0B0005.1
# 4   LEO     NASA      Success\n   8 October 2012  00:35  F9 v1.0B0006.1
#
#   Booster landing
# 0       Success\n
# 1         Success
# 2         Success
# 3       Success\n
# 4       Success\n

# %%
df.to_csv('spacex_web_scraped.csv', index=False)

# %% [markdown]
# We can now export it to a <b>CSV</b> for the next section, but to make the answers consistent and in case you have difficulties finishing this lab.
#
# Following labs will be using a provided dataset to make each lab independent.

# %% [markdown]
# <code>df.to_csv('spacex_web_scraped.csv', index=False)</code>

# %% [markdown]
# ## Authors

# %% [markdown]
# <a href="https://www.linkedin.com/in/yan-luo-96288783/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDS0321ENSkillsNetwork26802033-2022-01-01">Yan Luo</a>

# %% [markdown]
# <a href="https://www.linkedin.com/in/nayefaboutayoun/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDS0321ENSkillsNetwork26802033-2022-01-01">Nayef Abou Tayoun</a>

# %% [markdown]
# ## Change Log

# %% [markdown]
# | Date (YYYY-MM-DD) | Version | Changed By | Change Description          |
# | ----------------- | ------- | ---------- | --------------------------- |
# | 2021-06-09        | 1.0     | Yan Luo    | Tasks updates               |
# | 2020-11-10        | 1.0     | Nayef      | Created the initial version |

# %% [markdown]
# Copyright © 2021 IBM Corporation. All rights reserved.
