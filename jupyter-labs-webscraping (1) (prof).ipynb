# %%
{
    "nbformat": 4.0,
    "nbformat_minor": 5
}
# Out:
# {'nbformat': 4.0, 'nbformat_minor': 5}

# %%
pip install beautifulsoup4
# Out:
# Requirement already satisfied: beautifulsoup4 in c:\users\ktpra\appdata\local\programs\python\python311\lib\site-packages (4.12.0)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: soupsieve>1.2 in c:\users\ktpra\appdata\local\programs\python\python311\lib\site-packages (from beautifulsoup4) (2.4)

# %% [markdown]
# # **Space X  Falcon 9 First Stage Landing Prediction**

# %% [markdown]
# ## Web scraping Falcon 9 and Falcon Heavy Launches Records from Wikipedia

# %% [markdown]
# ![](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module\_1\_L2/images/Falcon9\_rocket_family.svg)

# %% [markdown]
# Falcon 9 first stage will land successfully

# %% [markdown]
# Several examples of an unsuccessful landing are shown here:

# %% [markdown]
# More specifically, the launch records are stored in a HTML table shown below:

# %% [markdown]
# ![](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module\_1\_L2/images/falcon9-launches-wiki.png)

# %% [markdown]
# ## Objectives
#
# Web scrap Falcon 9 launch records with `BeautifulSoup`:
#
# *   Extract a Falcon 9 launch records HTML table from Wikipedia
# *   Parse the table and convert it into a Pandas data frame

# %% [markdown]
# First let's import required packages for this lab

# %%
#import os
import requests 
from bs4 import BeautifulSoup
import re
import unicodedata
import pandas as pd

# %% [markdown]
# Below are some helper functions to help process the web scraped HTML table.

# %%
def date_time(table_cells):
    """
    This function returns the data and time from the HTML  table cell
    Input: the  element of a table data cell extracts extra row
    """
    return [data_time.strip() for data_time in list(table_cells.strings)][0:2]

def booster_version(table_cells):
    """
    This function returns the booster version from the HTML  table cell 
    Input: the  element of a table data cell extracts extra row
    """
    out=''.join([booster_version for i,booster_version in enumerate( table_cells.strings) if i%2==0][0:-1])
    return out

def landing_status(table_cells):
    """
    This function returns the landing status from the HTML table cell 
    Input: the  element of a table data cell extracts extra row
    """
    out=[i for i in table_cells.strings][0]
    return out


def get_mass(table_cells):
    mass=unicodedata.normalize("NFKD", table_cells.text).strip()
    if mass:
        mass.find("kg")
        new_mass=mass[0:mass.find("kg")+2]
    else:
        new_mass=0
    return new_mass


def extract_column_from_header(row):
    """
    This function returns the landing status from the HTML table cell 
    Input: the  element of a table data cell extracts extra row
    """
    if (row.br):
        row.br.extract()
    if row.a:
        row.a.extract()
    if row.sup:
        row.sup.extract()
        
    colunm_name = ' '.join(row.contents)
    
    # Filter the digit and empty names
    if not(colunm_name.strip().isdigit()):
        colunm_name = colunm_name.strip()
        return colunm_name

# %% [markdown]
# To keep the lab tasks consistent, we scrape the data from a snapshot of the  `List of Falcon 9 and Falcon Heavy launches` Wikipage updated on
# `9th June 2021`

# %%
static_url = "https://en.wikipedia.org/w/index.php?title=List_of_Falcon_9_and_Falcon_Heavy_launches&oldid=1027686922"

# %% [markdown]
# Next, request the HTML page from the above URL and get a `response` object

# %% [markdown]
#  Request the Falcon9 Launch Wiki page from its `URL`

# %% [markdown]
# First, let's `perform an HTTP GET method` to `request` the Falcon9 Launch HTML page, as an `HTTP response.`

# %%
# use requests.get() method with the provided static_url
# to get the HTML content of the page we call response
response = requests.get(static_url)

# %% [markdown]
# Create a `BeautifulSoup` object from the HTML `response`

# %%
# Use BeautifulSoup() to create a BeautifulSoup object from response text content
soup = BeautifulSoup(response.text, 'html.parser')

# %% [markdown]
# Print the page title to verify if the `BeautifulSoup` object was created properly

# %%
# Use soup.title attribute
print(soup.title)
# Out:
# <title>List of Falcon 9 and Falcon Heavy launches - Wikipedia</title>

# %% [markdown]
# ### Extract all column/variable names from the HTML table header

# %% [markdown]
# Next, we should collect all relevant column names from the HTML table header

# %% [markdown]
# To test, let's try to find all tables on the wiki page first.

# %%
# Use the find_all function in the BeautifulSoup object, with element type `table`
# Assign the result to a list called `html_tables`
html_tables = soup.find_all('table')

# %% [markdown]
# Starting from the third table is our target table contains the actual launch records.

# %%
# Let's print the third table and check its content
first_launch_table = html_tables[2]
print(first_launch_table)
# Out:
# <table class="wikitable plainrowheaders collapsible" style="width: 100%;">
# <tbody><tr>
# <th scope="col">Flight No.
# </th>
# <th scope="col">Date and<br/>time (<a href="/wiki/Coordinated_Universal_Time" title="Coordinated Universal Time">UTC</a>)
# </th>
# <th scope="col"><a href="/wiki/List_of_Falcon_9_first-stage_boosters" title="List of Falcon 9 first-stage boosters">Version,<br/>Booster</a> <sup class="reference" id="cite_ref-booster_11-0"><a href="#cite_note-booster-11">[b]</a></sup>
# </th>
# <th scope="col">Launch site
# </th>
# <th scope="col">Payload<sup class="reference" id="cite_ref-Dragon_12-0"><a href="#cite_note-Dragon-12">[c]</a></sup>
# </th>
# <th scope="col">Payload mass
# </th>
# <th scope="col">Orbit
# </th>
# <th scope="col">Customer
# </th>
# <th scope="col">Launch<br/>outcome
# </th>
# <th scope="col"><a href="/wiki/Falcon_9_first-stage_landing_tests" title="Falcon 9 first-stage landing tests">Booster<br/>landing</a>
# </th></tr>
# <tr>
# <th rowspan="2" scope="row" style="text-align:center;">1
# </th>
# <td>4 June 2010,<br/>18:45
# </td>
# <td><a href="/wiki/Falcon_9_v1.0" title="Falcon 9 v1.0">F9 v1.0</a><sup class="reference" id="cite_ref-MuskMay2012_13-0"><a href="#cite_note-MuskMay2012-13">[7]</a></sup><br/>B0003.1<sup class="reference" id="cite_ref-block_numbers_14-0"><a href="#cite_note-block_numbers-14">[8]</a></sup>
# </td>
# <td><a href="/wiki/Cape_Canaveral_Space_Force_Station" title="Cape Canaveral Space Force Station">CCAFS</a>,<br/><a href="/wiki/Cape_Canaveral_Space_Launch_Complex_40" title="Cape Canaveral Space Launch Complex 40">SLC-40</a>
# </td>
# <td><a href="/wiki/Dragon_Spacecraft_Qualification_Unit" title="Dragon Spacecraft Qualification Unit">Dragon Spacecraft Qualification Unit</a>
# </td>
# <td>
# </td>
# <td><a href="/wiki/Low_Earth_orbit" title="Low Earth orbit">LEO</a>
# </td>
# <td><a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# </td>
# <td class="table-success" style="background: #9EFF9E; vertical-align: middle; text-align: center;">Success
# </td>
# <td class="table-failure" style="background: #FFC7C7; vertical-align: middle; text-align: center;">Failure<sup class="reference" id="cite_ref-ns20110930_15-0"><a href="#cite_note-ns20110930-15">[9]</a></sup><sup class="reference" id="cite_ref-16"><a href="#cite_note-16">[10]</a></sup><br/><small>(parachute)</small>
# </td></tr>
# <tr>
# <td colspan="9">First flight of Falcon 9 v1.0.<sup class="reference" id="cite_ref-sfn20100604_17-0"><a href="#cite_note-sfn20100604-17">[11]</a></sup> Used a boilerplate version of Dragon capsule which was not designed to separate from the second stage.<small>(<a href="#First_flight_of_Falcon_9">more details below</a>)</small> Attempted to recover the first stage by parachuting it into the ocean, but it burned up on reentry, before the parachutes even deployed.<sup class="reference" id="cite_ref-parachute_18-0"><a href="#cite_note-parachute-18">[12]</a></sup>
# </td></tr>
# <tr>
# <th rowspan="2" scope="row" style="text-align:center;">2
# </th>
# <td>8 December 2010,<br/>15:43<sup class="reference" id="cite_ref-spaceflightnow_Clark_Launch_Report_19-0"><a href="#cite_note-spaceflightnow_Clark_Launch_Report-19">[13]</a></sup>
# </td>
# <td><a href="/wiki/Falcon_9_v1.0" title="Falcon 9 v1.0">F9 v1.0</a><sup class="reference" id="cite_ref-MuskMay2012_13-1"><a href="#cite_note-MuskMay2012-13">[7]</a></sup><br/>B0004.1<sup class="reference" id="cite_ref-block_numbers_14-1"><a href="#cite_note-block_numbers-14">[8]</a></sup>
# </td>
# <td><a href="/wiki/Cape_Canaveral_Space_Force_Station" title="Cape Canaveral Space Force Station">CCAFS</a>,<br/><a href="/wiki/Cape_Canaveral_Space_Launch_Complex_40" title="Cape Canaveral Space Launch Complex 40">SLC-40</a>
# </td>
# <td><a href="/wiki/SpaceX_Dragon" title="SpaceX Dragon">Dragon</a> <a class="mw-redirect" href="/wiki/COTS_Demo_Flight_1" title="COTS Demo Flight 1">demo flight C1</a><br/>(Dragon C101)
# </td>
# <td>
# </td>
# <td><a href="/wiki/Low_Earth_orbit" title="Low Earth orbit">LEO</a> (<a href="/wiki/International_Space_Station" title="International Space Station">ISS</a>)
# </td>
# <td><style data-mw-deduplicate="TemplateStyles:r1126788409">.mw-parser-output .plainlist ol,.mw-parser-output .plainlist ul{line-height:inherit;list-style:none;margin:0;padding:0}.mw-parser-output .plainlist ol li,.mw-parser-output .plainlist ul li{margin-bottom:0}</style><div class="plainlist">
# <ul><li><a href="/wiki/NASA" title="NASA">NASA</a> (<a href="/wiki/Commercial_Orbital_Transportation_Services" title="Commercial Orbital Transportation Services">COTS</a>)</li>
# <li><a href="/wiki/National_Reconnaissance_Office" title="National Reconnaissance Office">NRO</a></li></ul>
# </div>
# </td>
# <td class="table-success" style="background: #9EFF9E; vertical-align: middle; text-align: center;">Success<sup class="reference" id="cite_ref-ns20110930_15-1"><a href="#cite_note-ns20110930-15">[9]</a></sup>
# </td>
# <td class="table-failure" style="background: #FFC7C7; vertical-align: middle; text-align: center;">Failure<sup class="reference" id="cite_ref-ns20110930_15-2"><a href="#cite_note-ns20110930-15">[9]</a></sup><sup class="reference" id="cite_ref-20"><a href="#cite_note-20">[14]</a></sup><br/><small>(parachute)</small>
# </td></tr>
# <tr>
# <td colspan="9">Maiden flight of <a class="mw-redirect" href="/wiki/Dragon_capsule" title="Dragon capsule">Dragon capsule</a>, consisting of over 3 hours of testing thruster maneuvering and reentry.<sup class="reference" id="cite_ref-spaceflightnow_Clark_unleashing_Dragon_21-0"><a href="#cite_note-spaceflightnow_Clark_unleashing_Dragon-21">[15]</a></sup> Attempted to recover the first stage by parachuting it into the ocean, but it disintegrated upon reentry, before the parachutes were deployed.<sup class="reference" id="cite_ref-parachute_18-1"><a href="#cite_note-parachute-18">[12]</a></sup> <small>(<a href="#COTS_demo_missions">more details below</a>)</small> It also included two <a href="/wiki/CubeSat" title="CubeSat">CubeSats</a>,<sup class="reference" id="cite_ref-NRO_Taps_Boeing_for_Next_Batch_of_CubeSats_22-0"><a href="#cite_note-NRO_Taps_Boeing_for_Next_Batch_of_CubeSats-22">[16]</a></sup> and a wheel of <a href="/wiki/Brou%C3%A8re" title="Brouère">Brouère</a> cheese.
# </td></tr>
# <tr>
# <th rowspan="2" scope="row" style="text-align:center;">3
# </th>
# <td>22 May 2012,<br/>07:44<sup class="reference" id="cite_ref-BBC_new_era_23-0"><a href="#cite_note-BBC_new_era-23">[17]</a></sup>
# </td>
# <td><a href="/wiki/Falcon_9_v1.0" title="Falcon 9 v1.0">F9 v1.0</a><sup class="reference" id="cite_ref-MuskMay2012_13-2"><a href="#cite_note-MuskMay2012-13">[7]</a></sup><br/>B0005.1<sup class="reference" id="cite_ref-block_numbers_14-2"><a href="#cite_note-block_numbers-14">[8]</a></sup>
# </td>
# <td><a href="/wiki/Cape_Canaveral_Space_Force_Station" title="Cape Canaveral Space Force Station">CCAFS</a>,<br/><a href="/wiki/Cape_Canaveral_Space_Launch_Complex_40" title="Cape Canaveral Space Launch Complex 40">SLC-40</a>
# </td>
# <td><a href="/wiki/SpaceX_Dragon" title="SpaceX Dragon">Dragon</a> <a class="mw-redirect" href="/wiki/Dragon_C2%2B" title="Dragon C2+">demo flight C2+</a><sup class="reference" id="cite_ref-C2_24-0"><a href="#cite_note-C2-24">[18]</a></sup><br/>(Dragon C102)
# </td>
# <td>525 kg (1,157 lb)<sup class="reference" id="cite_ref-25"><a href="#cite_note-25">[19]</a></sup>
# </td>
# <td><a href="/wiki/Low_Earth_orbit" title="Low Earth orbit">LEO</a> (<a href="/wiki/International_Space_Station" title="International Space Station">ISS</a>)
# </td>
# <td><a href="/wiki/NASA" title="NASA">NASA</a> (<a href="/wiki/Commercial_Orbital_Transportation_Services" title="Commercial Orbital Transportation Services">COTS</a>)
# </td>
# <td class="table-success" style="background: #9EFF9E; vertical-align: middle; text-align: center;">Success<sup class="reference" id="cite_ref-26"><a href="#cite_note-26">[20]</a></sup>
# </td>
# <td class="table-noAttempt" style="background: #EEE; vertical-align: middle; white-space: nowrap; text-align: center;">No attempt
# </td></tr>
# <tr>
# <td colspan="9">Dragon spacecraft demonstrated a series of tests before it was allowed to approach the <a href="/wiki/International_Space_Station" title="International Space Station">International Space Station</a>. Two days later, it became the first commercial spacecraft to board the ISS.<sup class="reference" id="cite_ref-BBC_new_era_23-1"><a href="#cite_note-BBC_new_era-23">[17]</a></sup> <small>(<a href="#COTS_demo_missions">more details below</a>)</small>
# </td></tr>
# <tr>
# <th rowspan="3" scope="row" style="text-align:center;">4
# </th>
# <td rowspan="2">8 October 2012,<br/>00:35<sup class="reference" id="cite_ref-SFN_LLog_27-0"><a href="#cite_note-SFN_LLog-27">[21]</a></sup>
# </td>
# <td rowspan="2"><a href="/wiki/Falcon_9_v1.0" title="Falcon 9 v1.0">F9 v1.0</a><sup class="reference" id="cite_ref-MuskMay2012_13-3"><a href="#cite_note-MuskMay2012-13">[7]</a></sup><br/>B0006.1<sup class="reference" id="cite_ref-block_numbers_14-3"><a href="#cite_note-block_numbers-14">[8]</a></sup>
# </td>
# <td rowspan="2"><a href="/wiki/Cape_Canaveral_Space_Force_Station" title="Cape Canaveral Space Force Station">CCAFS</a>,<br/><a href="/wiki/Cape_Canaveral_Space_Launch_Complex_40" title="Cape Canaveral Space Launch Complex 40">SLC-40</a>
# </td>
# <td><a href="/wiki/SpaceX_CRS-1" title="SpaceX CRS-1">SpaceX CRS-1</a><sup class="reference" id="cite_ref-sxManifest20120925_28-0"><a href="#cite_note-sxManifest20120925-28">[22]</a></sup><br/>(Dragon C103)
# </td>
# <td>4,700 kg (10,400 lb)
# </td>
# <td><a href="/wiki/Low_Earth_orbit" title="Low Earth orbit">LEO</a> (<a href="/wiki/International_Space_Station" title="International Space Station">ISS</a>)
# </td>
# <td><a href="/wiki/NASA" title="NASA">NASA</a> (<a href="/wiki/Commercial_Resupply_Services" title="Commercial Resupply Services">CRS</a>)
# </td>
# <td class="table-success" style="background: #9EFF9E; vertical-align: middle; text-align: center;">Success
# </td>
# <td rowspan="2" style="background:#ececec; text-align:center;"><span class="nowrap">No attempt</span>
# </td></tr>
# <tr>
# <td><a href="/wiki/Orbcomm_(satellite)" title="Orbcomm (satellite)">Orbcomm-OG2</a><sup class="reference" id="cite_ref-Orbcomm_29-0"><a href="#cite_note-Orbcomm-29">[23]</a></sup>
# </td>
# <td>172 kg (379 lb)<sup class="reference" id="cite_ref-gunter-og2_30-0"><a href="#cite_note-gunter-og2-30">[24]</a></sup>
# </td>
# <td><a href="/wiki/Low_Earth_orbit" title="Low Earth orbit">LEO</a>
# </td>
# <td><a href="/wiki/Orbcomm" title="Orbcomm">Orbcomm</a>
# </td>
# <td class="table-partial" style="background: #FE9; vertical-align: middle; text-align: center;">Partial failure<sup class="reference" id="cite_ref-nyt-20121030_31-0"><a href="#cite_note-nyt-20121030-31">[25]</a></sup>
# </td></tr>
# <tr>
# <td colspan="9">CRS-1 was successful, but the <a href="/wiki/Secondary_payload" title="Secondary payload">secondary payload</a> was inserted into an abnormally low orbit and subsequently lost. This was due to one of the nine <a href="/wiki/SpaceX_Merlin" title="SpaceX Merlin">Merlin engines</a> shutting down during the launch, and NASA declining a second reignition, as per <a href="/wiki/International_Space_Station" title="International Space Station">ISS</a> visiting vehicle safety rules, the primary payload owner is contractually allowed to decline a second reignition. NASA stated that this was because SpaceX could not guarantee a high enough likelihood of the second stage completing the second burn successfully which was required to avoid any risk of secondary payload's collision with the ISS.<sup class="reference" id="cite_ref-OrbcommTotalLoss_32-0"><a href="#cite_note-OrbcommTotalLoss-32">[26]</a></sup><sup class="reference" id="cite_ref-sn20121011_33-0"><a href="#cite_note-sn20121011-33">[27]</a></sup><sup class="reference" id="cite_ref-34"><a href="#cite_note-34">[28]</a></sup>
# </td></tr>
# <tr>
# <th rowspan="2" scope="row" style="text-align:center;">5
# </th>
# <td>1 March 2013,<br/>15:10
# </td>
# <td><a href="/wiki/Falcon_9_v1.0" title="Falcon 9 v1.0">F9 v1.0</a><sup class="reference" id="cite_ref-MuskMay2012_13-4"><a href="#cite_note-MuskMay2012-13">[7]</a></sup><br/>B0007.1<sup class="reference" id="cite_ref-block_numbers_14-4"><a href="#cite_note-block_numbers-14">[8]</a></sup>
# </td>
# <td><a href="/wiki/Cape_Canaveral_Space_Force_Station" title="Cape Canaveral Space Force Station">CCAFS</a>,<br/><a href="/wiki/Cape_Canaveral_Space_Launch_Complex_40" title="Cape Canaveral Space Launch Complex 40">SLC-40</a>
# </td>
# <td><a href="/wiki/SpaceX_CRS-2" title="SpaceX CRS-2">SpaceX CRS-2</a><sup class="reference" id="cite_ref-sxManifest20120925_28-1"><a href="#cite_note-sxManifest20120925-28">[22]</a></sup><br/>(Dragon C104)
# </td>
# <td>4,877 kg (10,752 lb)
# </td>
# <td><a href="/wiki/Low_Earth_orbit" title="Low Earth orbit">LEO</a> (<a class="mw-redirect" href="/wiki/ISS" title="ISS">ISS</a>)
# </td>
# <td><a href="/wiki/NASA" title="NASA">NASA</a> (<a href="/wiki/Commercial_Resupply_Services" title="Commercial Resupply Services">CRS</a>)
# </td>
# <td class="table-success" style="background: #9EFF9E; vertical-align: middle; text-align: center;">Success
# </td>
# <td class="table-noAttempt" style="background: #EEE; vertical-align: middle; white-space: nowrap; text-align: center;">No attempt
# </td></tr>
# <tr>
# <td colspan="9">Last launch of the original Falcon 9 v1.0 <a href="/wiki/Launch_vehicle" title="Launch vehicle">launch vehicle</a>, first use of the unpressurized trunk section of Dragon.<sup class="reference" id="cite_ref-sxf9_20110321_35-0"><a href="#cite_note-sxf9_20110321-35">[29]</a></sup>
# </td></tr>
# <tr>
# <th rowspan="2" scope="row" style="text-align:center;">6
# </th>
# <td>29 September 2013,<br/>16:00<sup class="reference" id="cite_ref-pa20130930_36-0"><a href="#cite_note-pa20130930-36">[30]</a></sup>
# </td>
# <td><a href="/wiki/Falcon_9_v1.1" title="Falcon 9 v1.1">F9 v1.1</a><sup class="reference" id="cite_ref-MuskMay2012_13-5"><a href="#cite_note-MuskMay2012-13">[7]</a></sup><br/>B1003<sup class="reference" id="cite_ref-block_numbers_14-5"><a href="#cite_note-block_numbers-14">[8]</a></sup>
# </td>
# <td><a class="mw-redirect" href="/wiki/Vandenberg_Air_Force_Base" title="Vandenberg Air Force Base">VAFB</a>,<br/><a href="/wiki/Vandenberg_Space_Launch_Complex_4" title="Vandenberg Space Launch Complex 4">SLC-4E</a>
# </td>
# <td><a href="/wiki/CASSIOPE" title="CASSIOPE">CASSIOPE</a><sup class="reference" id="cite_ref-sxManifest20120925_28-2"><a href="#cite_note-sxManifest20120925-28">[22]</a></sup><sup class="reference" id="cite_ref-CASSIOPE_MDA_37-0"><a href="#cite_note-CASSIOPE_MDA-37">[31]</a></sup>
# </td>
# <td>500 kg (1,100 lb)
# </td>
# <td><a href="/wiki/Polar_orbit" title="Polar orbit">Polar orbit</a> <a href="/wiki/Low_Earth_orbit" title="Low Earth orbit">LEO</a>
# </td>
# <td><a href="/wiki/Maxar_Technologies" title="Maxar Technologies">MDA</a>
# </td>
# <td class="table-success" style="background: #9EFF9E; vertical-align: middle; text-align: center;">Success<sup class="reference" id="cite_ref-pa20130930_36-1"><a href="#cite_note-pa20130930-36">[30]</a></sup>
# </td>
# <td class="table-no2" style="background: #FFE3E3; color: black; vertical-align: middle; text-align: center;">Uncontrolled<br/><small>(ocean)</small><sup class="reference" id="cite_ref-ocean_landing_38-0"><a href="#cite_note-ocean_landing-38">[d]</a></sup>
# </td></tr>
# <tr>
# <td colspan="9">First commercial mission with a private customer, first launch from Vandenberg, and demonstration flight of Falcon 9 v1.1 with an improved 13-tonne to LEO capacity.<sup class="reference" id="cite_ref-sxf9_20110321_35-1"><a href="#cite_note-sxf9_20110321-35">[29]</a></sup> After separation from the second stage carrying Canadian commercial and scientific satellites, the first stage booster performed a controlled reentry,<sup class="reference" id="cite_ref-39"><a href="#cite_note-39">[32]</a></sup> and an <a href="/wiki/Falcon_9_first-stage_landing_tests" title="Falcon 9 first-stage landing tests">ocean touchdown test</a> for the first time. This provided good test data, even though the booster started rolling as it neared the ocean, leading to the shutdown of the central engine as the roll depleted it of fuel, resulting in a hard impact with the ocean.<sup class="reference" id="cite_ref-pa20130930_36-2"><a href="#cite_note-pa20130930-36">[30]</a></sup> This was the first known attempt of a rocket engine being lit to perform a supersonic retro propulsion, and allowed SpaceX to enter a public-private partnership with <a href="/wiki/NASA" title="NASA">NASA</a> and its Mars entry, descent, and landing technologies research projects.<sup class="reference" id="cite_ref-40"><a href="#cite_note-40">[33]</a></sup> <small>(<a href="#Maiden_flight_of_v1.1">more details below</a>)</small>
# </td></tr>
# <tr>
# <th rowspan="2" scope="row" style="text-align:center;">7
# </th>
# <td>3 December 2013,<br/>22:41<sup class="reference" id="cite_ref-sfn_wwls20130624_41-0"><a href="#cite_note-sfn_wwls20130624-41">[34]</a></sup>
# </td>
# <td><a href="/wiki/Falcon_9_v1.1" title="Falcon 9 v1.1">F9 v1.1</a><br/>B1004
# </td>
# <td><a href="/wiki/Cape_Canaveral_Space_Force_Station" title="Cape Canaveral Space Force Station">CCAFS</a>,<br/><a href="/wiki/Cape_Canaveral_Space_Launch_Complex_40" title="Cape Canaveral Space Launch Complex 40">SLC-40</a>
# </td>
# <td><a href="/wiki/SES-8" title="SES-8">SES-8</a><sup class="reference" id="cite_ref-sxManifest20120925_28-3"><a href="#cite_note-sxManifest20120925-28">[22]</a></sup><sup class="reference" id="cite_ref-spx-pr_42-0"><a href="#cite_note-spx-pr-42">[35]</a></sup><sup class="reference" id="cite_ref-aw20110323_43-0"><a href="#cite_note-aw20110323-43">[36]</a></sup>
# </td>
# <td>3,170 kg (6,990 lb)
# </td>
# <td><a href="/wiki/Geostationary_transfer_orbit" title="Geostationary transfer orbit">GTO</a>
# </td>
# <td><a href="/wiki/SES_S.A." title="SES S.A.">SES</a>
# </td>
# <td class="table-success" style="background: #9EFF9E; vertical-align: middle; text-align: center;">Success<sup class="reference" id="cite_ref-SNMissionStatus7_44-0"><a href="#cite_note-SNMissionStatus7-44">[37]</a></sup>
# </td>
# <td class="table-noAttempt" style="background: #EEE; vertical-align: middle; white-space: nowrap; text-align: center;">No attempt<br/><sup class="reference" id="cite_ref-sf10120131203_45-0"><a href="#cite_note-sf10120131203-45">[38]</a></sup>
# </td></tr>
# <tr>
# <td colspan="9">First <a href="/wiki/Geostationary_transfer_orbit" title="Geostationary transfer orbit">Geostationary transfer orbit</a> (GTO) launch for Falcon 9,<sup class="reference" id="cite_ref-spx-pr_42-1"><a href="#cite_note-spx-pr-42">[35]</a></sup> and first successful reignition of the second stage.<sup class="reference" id="cite_ref-46"><a href="#cite_note-46">[39]</a></sup> SES-8 was inserted into a <a href="/wiki/Geostationary_transfer_orbit" title="Geostationary transfer orbit">Super-Synchronous Transfer Orbit</a> of 79,341 km (49,300 mi) in apogee with an <a href="/wiki/Orbital_inclination" title="Orbital inclination">inclination</a> of 20.55° to the <a href="/wiki/Equator" title="Equator">equator</a>.
# </td></tr></tbody></table>

# %% [markdown]
# You should able to see the columns names embedded in the table header elements `<th>` as follows:
# Flight No.-
# Date and Time-
# Falcon 9 First Stage Boosters-
# Lauch Site-
# Payload, Payload Mass-
# Orbit-
# Customer-
# Launch Outcome-
# Falcon 9 first stage landing test-

# %% [markdown]
# Next, we just need to iterate through the `<th>` elements and apply the provided `extract_column_from_header()` to extract column name one by one

# %%
column_names = []

# Apply find_all() method with `th` element on first_launch_table
# Iterate each th element and apply the provided extract_column_from_header() to get a column name
# Append the Non-empty column name (`if name is not None and len(name) > 0`) into a list called column_names
for th in first_launch_table.find_all('th'):
    name = extract_column_from_header(th)
    if name is not None and len(name) > 0:
        column_names.append(name)

# %% [markdown]
# Check the extracted column names

# %%
print(column_names)
# Out:
# ['Flight No.', 'Date and time ( )', 'Launch site', 'Payload', 'Payload mass', 'Orbit', 'Customer', 'Launch outcome']

# %% [markdown]
# ##  Create a data frame by parsing the launch HTML tables

# %% [markdown]
# We will create an empty dictionary with keys from the extracted column names.

# %%
launch_dict= dict.fromkeys(column_names)

# Remove an irrelvant column
del launch_dict['Date and time ( )']

# Let's initial the launch_dict with each value to be an empty list
launch_dict['Flight No.'] = []
launch_dict['Date']=[]
launch_dict['Time']=[]
launch_dict['Launch site'] = []
launch_dict['Payload'] = []
launch_dict['Payload mass'] = []
launch_dict['Orbit'] = []
launch_dict['Customer'] = []
launch_dict['Launch outcome'] = []
# Added some new columns
launch_dict['Version Booster']=[]
launch_dict['Booster landing']=[]


print(launch_dict)
# Out:
# {'Flight No.': [], 'Launch site': [], 'Payload': [], 'Payload mass': [], 'Orbit': [], 'Customer': [], 'Launch outcome': [], 'Date': [], 'Time': [], 'Version Booster': [], 'Booster landing': []}

# %% [markdown]
# Next, we just need to fill up the `launch_dict` with launch records extracted from table rows.

# %% [markdown]
# We create helper functions to simplify the parsing process

# %%
extracted_row = 0
#Extract each table and enumerate over each table use the soup object to find all tables with class "wikitable-plainrowheaders collapsible"
for table_number,table in enumerate(soup.find_all('table',class_="wikitable plainrowheaders collapsible")):

   # get table row 
    for rows in table.find_all('tr'):
        if rows.th:
            if rows.th.string:
                flight_number=rows.th.string.strip()
                flag=flight_number.isdigit()
        else:
            flag=False
        #get table element 
        row=rows.find_all('td')

        if flag:
            extracted_row += 1
            # Flight Number value
            # TODO: Append the flight_number into launch_dict with key `Flight No.`
            launch_dict['Flight No.'].append(flight_number)
            print(f"Flight No.: {flight_number}")

            datatimelist=date_time(row[0])

            
            # Date value
            # TODO: Append the date into launch_dict with key `Date
            date = datatimelist[0].strip(',')
            launch_dict['Date'].append(date)
            print(f"Date: {date}")
            
            # Time value
            # TODO: Append the time into launch_dict with key `Time`
            time = datatimelist[1].strip(',')
            launch_dict['Time'].append(time)
            print(f"Time: {time}")
              
            # Booster version
            # TODO: Append the bv into launch_dict with key `Version Booster` using booster_version function, strip trailing and leading spaces
            bv=booster_version(row[1])
            launch_dict['Version Booster'].append(bv)
            if not(bv):
                bv=row[1]
            print(f"Version Booster: {bv}")
            
            # Launch Site
            # TODO: Append the bv into launch_dict with key `Launch Site`
            launch_site = booster_version(row[2])
            launch_dict['Launch site'].append(launch_site.strip(','))
            if not (launch_site):
                launch_site = row[2]
            print(f"Launch site: {launch_site}")
            
            # Payload
            # TODO: Append the payload into launch_dict with key `Payload`
            payload = row[3].a.string
            launch_dict['Payload'].append(payload)
            print(f"Payload: {payload}")
            
            # Payload Mass
            # TODO: Append the payload_mass into launch_dict with key `Payload mass`
            payload_mass = get_mass(row[4])
            launch_dict['Payload mass'].append(payload_mass)
            print(f"Payload mass: {payload_mass}")
            
            # Orbit
            # TODO: Append the orbit into launch_dict with key `Orbit`
            orbit = row[5].a.string
            launch_dict['Orbit'].append(orbit)
            print(f"Orbit: {orbit}")
            
            # Customer
            # TODO: Append the customer into launch_dict with key `Customer`
            # Hint: Use the `a` tag to get the customer name
            customer = row[6]
            if customer.a:
                customer = customer.a.string
            else:
                customer = customer.string
                
            launch_dict['Customer'].append(customer)
            print(f"Customer: {customer}")
            
            # Launch outcome
            # TODO: Append the launch_outcome into launch_dict with key `Launch outcome`
            launch_outcome = list(row[7].strings)[0]
            launch_dict['Launch outcome'].append(launch_outcome)
            print(f"Launch outcome: {launch_outcome}")
            
            # Booster landing
            # TODO: Append the launch_outcome into launch_dict with key `Booster landing`
            booster_landing = landing_status(row[8])
            launch_dict['Booster landing'].append(launch_outcome)
            print(f"Booster landing: {booster_landing}")
            
             # Debugging
            print(f"Extracted row: {extracted_row}")
            print(f"Length of Flight No. array: {len(launch_dict['Flight No.'])}")
            print(f"Length of Date array: {len(launch_dict['Date'])}")
            print(f"Length of Time array: {len(launch_dict['Time'])}")
            print(f"Length of Version Booster array: {len(launch_dict['Version Booster'])}")
            print(f"Length of Launch site array: {len(launch_dict['Launch site'])}")
            print(f"Length of Payload array: {len(launch_dict['Payload'])}")
            print(f"Length of Payload mass array: {len(launch_dict['Payload mass'])}")
            print(f"Length of Orbit array: {len(launch_dict['Orbit'])}")
            print(f"Length of Customer array: {len(launch_dict['Customer'])}")
            print(f"Length of Launch outcome array: {len(launch_dict['Launch outcome'])}")
            print(f"Length of Booster landing array: {len(launch_dict['Booster landing'])}")
# Out:
# Flight No.: 1
# Date: 4 June 2010
# Time: 18:45
# Version Booster: F9 v1.0B0003.1
# Launch site: CCAFS
# Payload: Dragon Spacecraft Qualification Unit
# Payload mass: 0
# Orbit: LEO
# Customer: SpaceX
# Launch outcome: Success
#
# Booster landing: Failure
# Extracted row: 1
# Length of Flight No. array: 1534
# Length of Date array: 1531
# Length of Time array: 1531
# Length of Version Booster array: 1531
# Length of Launch site array: 1531
# Length of Payload array: 1531
# Length of Payload mass array: 1531
# Length of Orbit array: 1531
# Length of Customer array: 1526
# Length of Launch outcome array: 1526
# Length of Booster landing array: 1526
# Flight No.: 2
# Date: 8 December 2010
# Time: 15:43
# Version Booster: F9 v1.0B0004.1
# Launch site: CCAFS
# Payload: Dragon
# Payload mass: 0
# Orbit: LEO
# Customer: NASA
# Launch outcome: Success
# Booster landing: Failure
# Extracted row: 2
# Length of Flight No. array: 1535
# Length of Date array: 1532
# Length of Time array: 1532
# Length of Version Booster array: 1532
# Length of Launch site array: 1532
# Length of Payload array: 1532
# Length of Payload mass array: 1532
# Length of Orbit array: 1532
# Length of Customer array: 1527
# Length of Launch outcome array: 1527
# Length of Booster landing array: 1527
# Flight No.: 3
# Date: 22 May 2012
# Time: 07:44
# Version Booster: F9 v1.0B0005.1
# Launch site: CCAFS
# Payload: Dragon
# Payload mass: 525 kg
# Orbit: LEO
# Customer: NASA
# Launch outcome: Success
# Booster landing: No attempt
#
# Extracted row: 3
# Length of Flight No. array: 1536
# Length of Date array: 1533
# Length of Time array: 1533
# Length of Version Booster array: 1533
# Length of Launch site array: 1533
# Length of Payload array: 1533
# Length of Payload mass array: 1533
# Length of Orbit array: 1533
# Length of Customer array: 1528
# Length of Launch outcome array: 1528
# Length of Booster landing array: 1528
# Flight No.: 4
# Date: 8 October 2012
# Time: 00:35
# Version Booster: F9 v1.0B0006.1
# Launch site: CCAFS
# Payload: SpaceX CRS-1
# Payload mass: 4,700 kg
# Orbit: LEO
# Customer: NASA
# Launch outcome: Success
#
# Booster landing: No attempt
# Extracted row: 4
# Length of Flight No. array: 1537
# Length of Date array: 1534
# Length of Time array: 1534
# Length of Version Booster array: 1534
# Length of Launch site array: 1534
# Length of Payload array: 1534
# Length of Payload mass array: 1534
# Length of Orbit array: 1534
# Length of Customer array: 1529
# Length of Launch outcome array: 1529
# Length of Booster landing array: 1529
# Flight No.: 5
# Date: 1 March 2013
# Time: 15:10
# Version Booster: F9 v1.0B0007.1
# Launch site: CCAFS
# Payload: SpaceX CRS-2
# Payload mass: 4,877 kg
# Orbit: LEO
# Customer: NASA
# Launch outcome: Success
#
# Booster landing: No attempt
#
# Extracted row: 5
# Length of Flight No. array: 1538
# Length of Date array: 1535
# Length of Time array: 1535
# Length of Version Booster array: 1535
# Length of Launch site array: 1535
# Length of Payload array: 1535
# Length of Payload mass array: 1535
# Length of Orbit array: 1535
# Length of Customer array: 1530
# Length of Launch outcome array: 1530
# Length of Booster landing array: 1530
# Flight No.: 6
# Date: 29 September 2013
# Time: 16:00
# Version Booster: F9 v1.1B1003
# Launch site: VAFB
# Payload: CASSIOPE
# Payload mass: 500 kg
# Orbit: Polar orbit
# Customer: MDA
# Launch outcome: Success
# Booster landing: Uncontrolled
# Extracted row: 6
# Length of Flight No. array: 1539
# Length of Date array: 1536
# Length of Time array: 1536
# Length of Version Booster array: 1536
# Length of Launch site array: 1536
# Length of Payload array: 1536
# Length of Payload mass array: 1536
# Length of Orbit array: 1536
# Length of Customer array: 1531
# Length of Launch outcome array: 1531
# Length of Booster landing array: 1531
# Flight No.: 7
# Date: 3 December 2013
# Time: 22:41
# Version Booster: <td><a href="/wiki/Falcon_9_v1.1" title="Falcon 9 v1.1">F9 v1.1</a><br/>B1004
# </td>
# Launch site: CCAFS
# Payload: SES-8
# Payload mass: 3,170 kg
# Orbit: GTO
# Customer: SES
# Launch outcome: Success
# Booster landing: No attempt
# Extracted row: 7
# Length of Flight No. array: 1540
# Length of Date array: 1537
# Length of Time array: 1537
# Length of Version Booster array: 1537
# Length of Launch site array: 1537
# Length of Payload array: 1537
# Length of Payload mass array: 1537
# Length of Orbit array: 1537
# Length of Customer array: 1532
# Length of Launch outcome array: 1532
# Length of Booster landing array: 1532
# Flight No.: 8
# Date: 6 January 2014
# Time: 22:06
# Version Booster: <td><a href="/wiki/Falcon_9_v1.1" title="Falcon 9 v1.1">F9 v1.1</a>
# </td>
# Launch site: CCAFS
# Payload: Thaicom 6
# Payload mass: 3,325 kg
# Orbit: GTO
# Customer: Thaicom
# Launch outcome: Success
# Booster landing: No attempt
# Extracted row: 8
# Length of Flight No. array: 1541
# Length of Date array: 1538
# Length of Time array: 1538
# Length of Version Booster array: 1538
# Length of Launch site array: 1538
# Length of Payload array: 1538
# Length of Payload mass array: 1538
# Length of Orbit array: 1538
# Length of Customer array: 1533
# Length of Launch outcome array: 1533
# Length of Booster landing array: 1533
# Flight No.: 9
# Date: 18 April 2014
# Time: 19:25
# Version Booster: <td><a href="/wiki/Falcon_9_v1.1" title="Falcon 9 v1.1">F9 v1.1</a>
# </td>
# Launch site: Cape Canaveral
# Payload: SpaceX CRS-3
# Payload mass: 2,296 kg
# Orbit: LEO
# Customer: NASA
# Launch outcome: Success
#
# Booster landing: Controlled
# Extracted row: 9
# Length of Flight No. array: 1542
# Length of Date array: 1539
# Length of Time array: 1539
# Length of Version Booster array: 1539
# Length of Launch site array: 1539
# Length of Payload array: 1539
# Length of Payload mass array: 1539
# Length of Orbit array: 1539
# Length of Customer array: 1534
# Length of Launch outcome array: 1534
# Length of Booster landing array: 1534
# Flight No.: 10
# Date: 14 July 2014
# Time: 15:15
# Version Booster: <td><a href="/wiki/Falcon_9_v1.1" title="Falcon 9 v1.1">F9 v1.1</a>
# </td>
# Launch site: Cape Canaveral
# Payload: Orbcomm-OG2
# Payload mass: 1,316 kg
# Orbit: LEO
# Customer: Orbcomm
# Launch outcome: Success
# Booster landing: Controlled
# Extracted row: 10
# Length of Flight No. array: 1543
# Length of Date array: 1540
# Length of Time array: 1540
# Length of Version Booster array: 1540
# Length of Launch site array: 1540
# Length of Payload array: 1540
# Length of Payload mass array: 1540
# Length of Orbit array: 1540
# Length of Customer array: 1535
# Length of Launch outcome array: 1535
# Length of Booster landing array: 1535
# Flight No.: 11
# Date: 5 August 2014
# Time: 08:00
# Version Booster: <td><a href="/wiki/Falcon_9_v1.1" title="Falcon 9 v1.1">F9 v1.1</a>
# </td>
# Launch site: Cape Canaveral
# Payload: AsiaSat 8
# Payload mass: 4,535 kg
# Orbit: GTO
# Customer: AsiaSat
# Launch outcome: Success
# Booster landing: No attempt
# Extracted row: 11
# Length of Flight No. array: 1544
# Length of Date array: 1541
# Length of Time array: 1541
# Length of Version Booster array: 1541
# Length of Launch site array: 1541
# Length of Payload array: 1541
# Length of Payload mass array: 1541
# Length of Orbit array: 1541
# Length of Customer array: 1536
# Length of Launch outcome array: 1536
# Length of Booster landing array: 1536
# Flight No.: 12
# Date: 7 September 2014
# Time: 05:00
# Version Booster: F9 v1.1
# Launch site: Cape Canaveral
# Payload: AsiaSat 6
# Payload mass: 4,428 kg
# Orbit: GTO
# Customer: AsiaSat
# Launch outcome: Success
# Booster landing: No attempt
#
# Extracted row: 12
# Length of Flight No. array: 1545
# Length of Date array: 1542
# Length of Time array: 1542
# Length of Version Booster array: 1542
# Length of Launch site array: 1542
# Length of Payload array: 1542
# Length of Payload mass array: 1542
# Length of Orbit array: 1542
# Length of Customer array: 1537
# Length of Launch outcome array: 1537
# Length of Booster landing array: 1537
# Flight No.: 13
# Date: 21 September 2014
# Time: 05:52
# Version Booster: F9 v1.1
# Launch site: Cape Canaveral
# Payload: SpaceX CRS-4
# Payload mass: 2,216 kg
# Orbit: LEO
# Customer: NASA
# Launch outcome: Success
# Booster landing: Uncontrolled
# Extracted row: 13
# Length of Flight No. array: 1546
# Length of Date array: 1543
# Length of Time array: 1543
# Length of Version Booster array: 1543
# Length of Launch site array: 1543
# Length of Payload array: 1543
# Length of Payload mass array: 1543
# Length of Orbit array: 1543
# Length of Customer array: 1538
# Length of Launch outcome array: 1538
# Length of Booster landing array: 1538
# Flight No.: 14
# Date: 10 January 2015
# Time: 09:47
# Version Booster: F9 v1.1
# Launch site: Cape Canaveral
# Payload: SpaceX CRS-5
# Payload mass: 2,395 kg
# Orbit: LEO
# Customer: NASA
# Launch outcome: Success
# Booster landing: Failure
# Extracted row: 14
# Length of Flight No. array: 1547
# Length of Date array: 1544
# Length of Time array: 1544
# Length of Version Booster array: 1544
# Length of Launch site array: 1544
# Length of Payload array: 1544
# Length of Payload mass array: 1544
# Length of Orbit array: 1544
# Length of Customer array: 1539
# Length of Launch outcome array: 1539
# Length of Booster landing array: 1539
# Flight No.: 15
# Date: 11 February 2015
# Time: 23:03
# Version Booster: F9 v1.1
# Launch site: Cape Canaveral
# Payload: DSCOVR
# Payload mass: 570 kg
# Orbit: HEO
# Customer: USAF
# Launch outcome: Success
#
# Booster landing: Controlled
# Extracted row: 15
# Length of Flight No. array: 1548
# Length of Date array: 1545
# Length of Time array: 1545
# Length of Version Booster array: 1545
# Length of Launch site array: 1545
# Length of Payload array: 1545
# Length of Payload mass array: 1545
# Length of Orbit array: 1545
# Length of Customer array: 1540
# Length of Launch outcome array: 1540
# Length of Booster landing array: 1540
# Flight No.: 16
# Date: 2 March 2015
# Time: 03:50
# Version Booster: F9 v1.1
# Launch site: Cape Canaveral
# Payload: ABS-3A
# Payload mass: 4,159 kg
# Orbit: GTO
# Customer: ABS
# Launch outcome: Success
#
# Booster landing: No attempt
# Extracted row: 16
# Length of Flight No. array: 1549
# Length of Date array: 1546
# Length of Time array: 1546
# Length of Version Booster array: 1546
# Length of Launch site array: 1546
# Length of Payload array: 1546
# Length of Payload mass array: 1546
# Length of Orbit array: 1546
# Length of Customer array: 1541
# Length of Launch outcome array: 1541
# Length of Booster landing array: 1541
# Flight No.: 17
# Date: 14 April 2015
# Time: 20:10
# Version Booster: F9 v1.1
# Launch site: Cape Canaveral
# Payload: SpaceX CRS-6
# Payload mass: 1,898 kg
# Orbit: LEO
# Customer: NASA
# Launch outcome: Success
#
# Booster landing: Failure
# Extracted row: 17
# Length of Flight No. array: 1550
# Length of Date array: 1547
# Length of Time array: 1547
# Length of Version Booster array: 1547
# Length of Launch site array: 1547
# Length of Payload array: 1547
# Length of Payload mass array: 1547
# Length of Orbit array: 1547
# Length of Customer array: 1542
# Length of Launch outcome array: 1542
# Length of Booster landing array: 1542
# Flight No.: 18
# Date: 27 April 2015
# Time: 23:03
# Version Booster: F9 v1.1
# Launch site: Cape Canaveral
# Payload: TürkmenÄlem 52°E / MonacoSAT
# Payload mass: 4,707 kg
# Orbit: GTO
# Customer: None
# Launch outcome: Success
#
# Booster landing: No attempt
# Extracted row: 18
# Length of Flight No. array: 1551
# Length of Date array: 1548
# Length of Time array: 1548
# Length of Version Booster array: 1548
# Length of Launch site array: 1548
# Length of Payload array: 1548
# Length of Payload mass array: 1548
# Length of Orbit array: 1548
# Length of Customer array: 1543
# Length of Launch outcome array: 1543
# Length of Booster landing array: 1543
# Flight No.: 19
# Date: 28 June 2015
# Time: 14:21
# Version Booster: F9 v1.1
# Launch site: Cape Canaveral
# Payload: SpaceX CRS-7
# Payload mass: 1,952 kg
# Orbit: LEO
# Customer: NASA
# Launch outcome: Failure
# Booster landing: Precluded
# Extracted row: 19
# Length of Flight No. array: 1552
# Length of Date array: 1549
# Length of Time array: 1549
# Length of Version Booster array: 1549
# Length of Launch site array: 1549
# Length of Payload array: 1549
# Length of Payload mass array: 1549
# Length of Orbit array: 1549
# Length of Customer array: 1544
# Length of Launch outcome array: 1544
# Length of Booster landing array: 1544
# Flight No.: 20
# Date: 22 December 2015
# Time: 01:29
# Version Booster: F9 FT
# Launch site: Cape Canaveral
# Payload: Orbcomm-OG2
# Payload mass: 2,034 kg
# Orbit: LEO
# Customer: Orbcomm
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 20
# Length of Flight No. array: 1553
# Length of Date array: 1550
# Length of Time array: 1550
# Length of Version Booster array: 1550
# Length of Launch site array: 1550
# Length of Payload array: 1550
# Length of Payload mass array: 1550
# Length of Orbit array: 1550
# Length of Customer array: 1545
# Length of Launch outcome array: 1545
# Length of Booster landing array: 1545
# Flight No.: 21
# Date: 17 January 2016
# Time: 18:42
# Version Booster: F9 v1.1
# Launch site: VAFB
# Payload: Jason-3
# Payload mass: 553 kg
# Orbit: LEO
# Customer: NASA
# Launch outcome: Success
#
# Booster landing: Failure
# Extracted row: 21
# Length of Flight No. array: 1554
# Length of Date array: 1551
# Length of Time array: 1551
# Length of Version Booster array: 1551
# Length of Launch site array: 1551
# Length of Payload array: 1551
# Length of Payload mass array: 1551
# Length of Orbit array: 1551
# Length of Customer array: 1546
# Length of Launch outcome array: 1546
# Length of Booster landing array: 1546
# Flight No.: 22
# Date: 4 March 2016
# Time: 23:35
# Version Booster: F9 FT
# Launch site: Cape Canaveral
# Payload: SES-9
# Payload mass: 5,271 kg
# Orbit: GTO
# Customer: SES
# Launch outcome: Success
#
# Booster landing: Failure
# Extracted row: 22
# Length of Flight No. array: 1555
# Length of Date array: 1552
# Length of Time array: 1552
# Length of Version Booster array: 1552
# Length of Launch site array: 1552
# Length of Payload array: 1552
# Length of Payload mass array: 1552
# Length of Orbit array: 1552
# Length of Customer array: 1547
# Length of Launch outcome array: 1547
# Length of Booster landing array: 1547
# Flight No.: 23
# Date: 8 April 2016
# Time: 20:43
# Version Booster: F9 FT
# Launch site: Cape Canaveral
# Payload: SpaceX CRS-8
# Payload mass: 3,136 kg
# Orbit: LEO
# Customer: NASA
# Launch outcome: Success
# Booster landing: Success
# Extracted row: 23
# Length of Flight No. array: 1556
# Length of Date array: 1553
# Length of Time array: 1553
# Length of Version Booster array: 1553
# Length of Launch site array: 1553
# Length of Payload array: 1553
# Length of Payload mass array: 1553
# Length of Orbit array: 1553
# Length of Customer array: 1548
# Length of Launch outcome array: 1548
# Length of Booster landing array: 1548
# Flight No.: 24
# Date: 6 May 2016
# Time: 05:21
# Version Booster: F9 FT
# Launch site: Cape Canaveral
# Payload: JCSAT-14
# Payload mass: 4,696 kg
# Orbit: GTO
# Customer: SKY Perfect JSAT Group
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 24
# Length of Flight No. array: 1557
# Length of Date array: 1554
# Length of Time array: 1554
# Length of Version Booster array: 1554
# Length of Launch site array: 1554
# Length of Payload array: 1554
# Length of Payload mass array: 1554
# Length of Orbit array: 1554
# Length of Customer array: 1549
# Length of Launch outcome array: 1549
# Length of Booster landing array: 1549
# Flight No.: 25
# Date: 27 May 2016
# Time: 21:39
# Version Booster: F9 FT
# Launch site: Cape Canaveral
# Payload: Thaicom 8
# Payload mass: 3,100 kg
# Orbit: GTO
# Customer: Thaicom
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 25
# Length of Flight No. array: 1558
# Length of Date array: 1555
# Length of Time array: 1555
# Length of Version Booster array: 1555
# Length of Launch site array: 1555
# Length of Payload array: 1555
# Length of Payload mass array: 1555
# Length of Orbit array: 1555
# Length of Customer array: 1550
# Length of Launch outcome array: 1550
# Length of Booster landing array: 1550
# Flight No.: 26
# Date: 15 June 2016
# Time: 14:29
# Version Booster: F9 FT
# Launch site: Cape Canaveral
# Payload: ABS-2A
# Payload mass: 3,600 kg
# Orbit: GTO
# Customer: ABS
# Launch outcome: Success
#
# Booster landing: Failure
# Extracted row: 26
# Length of Flight No. array: 1559
# Length of Date array: 1556
# Length of Time array: 1556
# Length of Version Booster array: 1556
# Length of Launch site array: 1556
# Length of Payload array: 1556
# Length of Payload mass array: 1556
# Length of Orbit array: 1556
# Length of Customer array: 1551
# Length of Launch outcome array: 1551
# Length of Booster landing array: 1551
# Flight No.: 27
# Date: 18 July 2016
# Time: 04:45
# Version Booster: F9 FT
# Launch site: Cape Canaveral
# Payload: SpaceX CRS-9
# Payload mass: 2,257 kg
# Orbit: LEO
# Customer: NASA
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 27
# Length of Flight No. array: 1560
# Length of Date array: 1557
# Length of Time array: 1557
# Length of Version Booster array: 1557
# Length of Launch site array: 1557
# Length of Payload array: 1557
# Length of Payload mass array: 1557
# Length of Orbit array: 1557
# Length of Customer array: 1552
# Length of Launch outcome array: 1552
# Length of Booster landing array: 1552
# Flight No.: 28
# Date: 14 August 2016
# Time: 05:26
# Version Booster: F9 FT
# Launch site: Cape Canaveral
# Payload: JCSAT-16
# Payload mass: 4,600 kg
# Orbit: GTO
# Customer: SKY Perfect JSAT Group
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 28
# Length of Flight No. array: 1561
# Length of Date array: 1558
# Length of Time array: 1558
# Length of Version Booster array: 1558
# Length of Launch site array: 1558
# Length of Payload array: 1558
# Length of Payload mass array: 1558
# Length of Orbit array: 1558
# Length of Customer array: 1553
# Length of Launch outcome array: 1553
# Length of Booster landing array: 1553
# Flight No.: 29
# Date: 14 January 2017
# Time: 17:54
# Version Booster: F9 FT
# Launch site: VAFB
# Payload: Iridium NEXT
# Payload mass: 9,600 kg
# Orbit: Polar
# Customer: Iridium Communications
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 29
# Length of Flight No. array: 1562
# Length of Date array: 1559
# Length of Time array: 1559
# Length of Version Booster array: 1559
# Length of Launch site array: 1559
# Length of Payload array: 1559
# Length of Payload mass array: 1559
# Length of Orbit array: 1559
# Length of Customer array: 1554
# Length of Launch outcome array: 1554
# Length of Booster landing array: 1554
# Flight No.: 30
# Date: 19 February 2017
# Time: 14:39
# Version Booster: F9 FT
# Launch site: KSC
# Payload: SpaceX CRS-10
# Payload mass: 2,490 kg
# Orbit: LEO
# Customer: NASA
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 30
# Length of Flight No. array: 1563
# Length of Date array: 1560
# Length of Time array: 1560
# Length of Version Booster array: 1560
# Length of Launch site array: 1560
# Length of Payload array: 1560
# Length of Payload mass array: 1560
# Length of Orbit array: 1560
# Length of Customer array: 1555
# Length of Launch outcome array: 1555
# Length of Booster landing array: 1555
# Flight No.: 31
# Date: 16 March 2017
# Time: 06:00
# Version Booster: F9 FT
# Launch site: KSC
# Payload: EchoStar 23
# Payload mass: 5,600 kg
# Orbit: GTO
# Customer: EchoStar
# Launch outcome: Success
#
# Booster landing: No attempt
# Extracted row: 31
# Length of Flight No. array: 1564
# Length of Date array: 1561
# Length of Time array: 1561
# Length of Version Booster array: 1561
# Length of Launch site array: 1561
# Length of Payload array: 1561
# Length of Payload mass array: 1561
# Length of Orbit array: 1561
# Length of Customer array: 1556
# Length of Launch outcome array: 1556
# Length of Booster landing array: 1556
# Flight No.: 32
# Date: 30 March 2017
# Time: 22:27
# Version Booster: F9 FT♺
# Launch site: KSC
# Payload: SES-10
# Payload mass: 5,300 kg
# Orbit: GTO
# Customer: SES
# Launch outcome: Success
# Booster landing: Success
# Extracted row: 32
# Length of Flight No. array: 1565
# Length of Date array: 1562
# Length of Time array: 1562
# Length of Version Booster array: 1562
# Length of Launch site array: 1562
# Length of Payload array: 1562
# Length of Payload mass array: 1562
# Length of Orbit array: 1562
# Length of Customer array: 1557
# Length of Launch outcome array: 1557
# Length of Booster landing array: 1557
# Flight No.: 33
# Date: 1 May 2017
# Time: 11:15
# Version Booster: F9 FT
# Launch site: KSC
# Payload: NROL-76
# Payload mass: C
# Orbit: LEO
# Customer: NRO
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 33
# Length of Flight No. array: 1566
# Length of Date array: 1563
# Length of Time array: 1563
# Length of Version Booster array: 1563
# Length of Launch site array: 1563
# Length of Payload array: 1563
# Length of Payload mass array: 1563
# Length of Orbit array: 1563
# Length of Customer array: 1558
# Length of Launch outcome array: 1558
# Length of Booster landing array: 1558
# Flight No.: 34
# Date: 15 May 2017
# Time: 23:21
# Version Booster: F9 FT
# Launch site: KSC
# Payload: Inmarsat-5 F4
# Payload mass: 6,070 kg
# Orbit: GTO
# Customer: Inmarsat
# Launch outcome: Success
#
# Booster landing: No attempt
# Extracted row: 34
# Length of Flight No. array: 1567
# Length of Date array: 1564
# Length of Time array: 1564
# Length of Version Booster array: 1564
# Length of Launch site array: 1564
# Length of Payload array: 1564
# Length of Payload mass array: 1564
# Length of Orbit array: 1564
# Length of Customer array: 1559
# Length of Launch outcome array: 1559
# Length of Booster landing array: 1559
# Flight No.: 35
# Date: 3 June 2017
# Time: 21:07
# Version Booster: F9 FT
# Launch site: KSC
# Payload: SpaceX CRS-11
# Payload mass: 2,708 kg
# Orbit: LEO
# Customer: NASA
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 35
# Length of Flight No. array: 1568
# Length of Date array: 1565
# Length of Time array: 1565
# Length of Version Booster array: 1565
# Length of Launch site array: 1565
# Length of Payload array: 1565
# Length of Payload mass array: 1565
# Length of Orbit array: 1565
# Length of Customer array: 1560
# Length of Launch outcome array: 1560
# Length of Booster landing array: 1560
# Flight No.: 36
# Date: 23 June 2017
# Time: 19:10
# Version Booster: F9 FTB1029.2
# Launch site: KSC
# Payload: BulgariaSat-1
# Payload mass: 3,669 kg
# Orbit: GTO
# Customer: Bulsatcom
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 36
# Length of Flight No. array: 1569
# Length of Date array: 1566
# Length of Time array: 1566
# Length of Version Booster array: 1566
# Length of Launch site array: 1566
# Length of Payload array: 1566
# Length of Payload mass array: 1566
# Length of Orbit array: 1566
# Length of Customer array: 1561
# Length of Launch outcome array: 1561
# Length of Booster landing array: 1561
# Flight No.: 37
# Date: 25 June 2017
# Time: 20:25
# Version Booster: F9 FT
# Launch site: VAFB
# Payload: Iridium NEXT
# Payload mass: 9,600 kg
# Orbit: LEO
# Customer: Iridium Communications
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 37
# Length of Flight No. array: 1570
# Length of Date array: 1567
# Length of Time array: 1567
# Length of Version Booster array: 1567
# Length of Launch site array: 1567
# Length of Payload array: 1567
# Length of Payload mass array: 1567
# Length of Orbit array: 1567
# Length of Customer array: 1562
# Length of Launch outcome array: 1562
# Length of Booster landing array: 1562
# Flight No.: 38
# Date: 5 July 2017
# Time: 23:38
# Version Booster: F9 FT
# Launch site: KSC
# Payload: Intelsat 35e
# Payload mass: 6,761 kg
# Orbit: GTO
# Customer: Intelsat
# Launch outcome: Success
#
# Booster landing: No attempt
# Extracted row: 38
# Length of Flight No. array: 1571
# Length of Date array: 1568
# Length of Time array: 1568
# Length of Version Booster array: 1568
# Length of Launch site array: 1568
# Length of Payload array: 1568
# Length of Payload mass array: 1568
# Length of Orbit array: 1568
# Length of Customer array: 1563
# Length of Launch outcome array: 1563
# Length of Booster landing array: 1563
# Flight No.: 39
# Date: 14 August 2017
# Time: 16:31
# Version Booster: F9 B4
# Launch site: KSC
# Payload: SpaceX CRS-12
# Payload mass: 3,310 kg
# Orbit: LEO
# Customer: NASA
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 39
# Length of Flight No. array: 1572
# Length of Date array: 1569
# Length of Time array: 1569
# Length of Version Booster array: 1569
# Length of Launch site array: 1569
# Length of Payload array: 1569
# Length of Payload mass array: 1569
# Length of Orbit array: 1569
# Length of Customer array: 1564
# Length of Launch outcome array: 1564
# Length of Booster landing array: 1564
# Flight No.: 40
# Date: 24 August 2017
# Time: 18:51
# Version Booster: F9 FT
# Launch site: VAFB
# Payload: Formosat-5
# Payload mass: 475 kg
# Orbit: SSO
# Customer: NSPO
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 40
# Length of Flight No. array: 1573
# Length of Date array: 1570
# Length of Time array: 1570
# Length of Version Booster array: 1570
# Length of Launch site array: 1570
# Length of Payload array: 1570
# Length of Payload mass array: 1570
# Length of Orbit array: 1570
# Length of Customer array: 1565
# Length of Launch outcome array: 1565
# Length of Booster landing array: 1565
# Flight No.: 41
# Date: 7 September 2017
# Time: 14:00
# Version Booster: F9 B4
# Launch site: KSC
# Payload: Boeing X-37B
# Payload mass: 4,990 kg
# Orbit: LEO
# Customer: USAF
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 41
# Length of Flight No. array: 1574
# Length of Date array: 1571
# Length of Time array: 1571
# Length of Version Booster array: 1571
# Length of Launch site array: 1571
# Length of Payload array: 1571
# Length of Payload mass array: 1571
# Length of Orbit array: 1571
# Length of Customer array: 1566
# Length of Launch outcome array: 1566
# Length of Booster landing array: 1566
# Flight No.: 42
# Date: 9 October 2017
# Time: 12:37
# Version Booster: F9 B4
# Launch site: VAFB
# Payload: Iridium NEXT
# Payload mass: 9,600 kg
# Orbit: Polar
# Customer: Iridium Communications
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 42
# Length of Flight No. array: 1575
# Length of Date array: 1572
# Length of Time array: 1572
# Length of Version Booster array: 1572
# Length of Launch site array: 1572
# Length of Payload array: 1572
# Length of Payload mass array: 1572
# Length of Orbit array: 1572
# Length of Customer array: 1567
# Length of Launch outcome array: 1567
# Length of Booster landing array: 1567
# Flight No.: 43
# Date: 11 October 2017
# Time: 22:53:00
# Version Booster: F9 FTB1031.2
# Launch site: KSC
# Payload: SES-11
# Payload mass: 5,200 kg
# Orbit: GTO
# Customer: SES S.A.
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 43
# Length of Flight No. array: 1576
# Length of Date array: 1573
# Length of Time array: 1573
# Length of Version Booster array: 1573
# Length of Launch site array: 1573
# Length of Payload array: 1573
# Length of Payload mass array: 1573
# Length of Orbit array: 1573
# Length of Customer array: 1568
# Length of Launch outcome array: 1568
# Length of Booster landing array: 1568
# Flight No.: 44
# Date: 30 October 2017
# Time: 19:34
# Version Booster: F9 B4
# Launch site: KSC
# Payload: Koreasat 5A
# Payload mass: 3,500 kg
# Orbit: GTO
# Customer: KT Corporation
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 44
# Length of Flight No. array: 1577
# Length of Date array: 1574
# Length of Time array: 1574
# Length of Version Booster array: 1574
# Length of Launch site array: 1574
# Length of Payload array: 1574
# Length of Payload mass array: 1574
# Length of Orbit array: 1574
# Length of Customer array: 1569
# Length of Launch outcome array: 1569
# Length of Booster landing array: 1569
# Flight No.: 45
# Date: 15 December 2017
# Time: 15:36
# Version Booster: F9 FTB1035.2
# Launch site: Cape Canaveral
# Payload: SpaceX CRS-13
# Payload mass: 2,205 kg
# Orbit: LEO
# Customer: NASA
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 45
# Length of Flight No. array: 1578
# Length of Date array: 1575
# Length of Time array: 1575
# Length of Version Booster array: 1575
# Length of Launch site array: 1575
# Length of Payload array: 1575
# Length of Payload mass array: 1575
# Length of Orbit array: 1575
# Length of Customer array: 1570
# Length of Launch outcome array: 1570
# Length of Booster landing array: 1570
# Flight No.: 46
# Date: 23 December 2017
# Time: 01:27
# Version Booster: F9 FTB1036.2
# Launch site: VAFB
# Payload: Iridium NEXT
# Payload mass: 9,600 kg
# Orbit: Polar
# Customer: Iridium Communications
# Launch outcome: Success
# Booster landing: Controlled
# Extracted row: 46
# Length of Flight No. array: 1579
# Length of Date array: 1576
# Length of Time array: 1576
# Length of Version Booster array: 1576
# Length of Launch site array: 1576
# Length of Payload array: 1576
# Length of Payload mass array: 1576
# Length of Orbit array: 1576
# Length of Customer array: 1571
# Length of Launch outcome array: 1571
# Length of Booster landing array: 1571
# Flight No.: 47
# Date: 8 January 2018
# Time: 01:00
# Version Booster: F9 B4
# Launch site: CCAFS
# Payload: Zuma
# Payload mass: C
# Orbit: LEO
# Customer: Northrop Grumman
# Launch outcome: Success
# Booster landing: Success
# Extracted row: 47
# Length of Flight No. array: 1580
# Length of Date array: 1577
# Length of Time array: 1577
# Length of Version Booster array: 1577
# Length of Launch site array: 1577
# Length of Payload array: 1577
# Length of Payload mass array: 1577
# Length of Orbit array: 1577
# Length of Customer array: 1572
# Length of Launch outcome array: 1572
# Length of Booster landing array: 1572
# Flight No.: 48
# Date: 31 January 2018
# Time: 21:25
# Version Booster: F9 FTB1032.2
# Launch site: CCAFS
# Payload: GovSat-1
# Payload mass: 4,230 kg
# Orbit: GTO
# Customer: SES
# Launch outcome: Success
# Booster landing: Controlled
# Extracted row: 48
# Length of Flight No. array: 1581
# Length of Date array: 1578
# Length of Time array: 1578
# Length of Version Booster array: 1578
# Length of Launch site array: 1578
# Length of Payload array: 1578
# Length of Payload mass array: 1578
# Length of Orbit array: 1578
# Length of Customer array: 1573
# Length of Launch outcome array: 1573
# Length of Booster landing array: 1573
# Flight No.: 49
# Date: 22 February 2018
# Time: 14:17
# Version Booster: F9 FTB1038.2
# Launch site: VAFB
# Payload: Paz
# Payload mass: 2,150 kg
# Orbit: SSO
# Customer: Hisdesat
# Launch outcome: Success
# Booster landing: No attempt
# Extracted row: 49
# Length of Flight No. array: 1582
# Length of Date array: 1579
# Length of Time array: 1579
# Length of Version Booster array: 1579
# Length of Launch site array: 1579
# Length of Payload array: 1579
# Length of Payload mass array: 1579
# Length of Orbit array: 1579
# Length of Customer array: 1574
# Length of Launch outcome array: 1574
# Length of Booster landing array: 1574
# Flight No.: 50
# Date: 6 March 2018
# Time: 05:33
# Version Booster: F9 B4
# Launch site: CCAFS
# Payload: Hispasat 30W-6
# Payload mass: 6,092 kg
# Orbit: GTO
# Customer: Hispasat
# Launch outcome: Success
# Booster landing: No attempt
# Extracted row: 50
# Length of Flight No. array: 1583
# Length of Date array: 1580
# Length of Time array: 1580
# Length of Version Booster array: 1580
# Length of Launch site array: 1580
# Length of Payload array: 1580
# Length of Payload mass array: 1580
# Length of Orbit array: 1580
# Length of Customer array: 1575
# Length of Launch outcome array: 1575
# Length of Booster landing array: 1575
# Flight No.: 51
# Date: 30 March 2018
# Time: 14:14
# Version Booster: F9 B4B1041.2
# Launch site: VAFB
# Payload: Iridium NEXT
# Payload mass: 9,600 kg
# Orbit: Polar
# Customer: Iridium Communications
# Launch outcome: Success
# Booster landing: No attempt
# Extracted row: 51
# Length of Flight No. array: 1584
# Length of Date array: 1581
# Length of Time array: 1581
# Length of Version Booster array: 1581
# Length of Launch site array: 1581
# Length of Payload array: 1581
# Length of Payload mass array: 1581
# Length of Orbit array: 1581
# Length of Customer array: 1576
# Length of Launch outcome array: 1576
# Length of Booster landing array: 1576
# Flight No.: 52
# Date: 2 April 2018
# Time: 20:30
# Version Booster: F9 B4B1039.2
# Launch site: CCAFS
# Payload: SpaceX CRS-14
# Payload mass: 2,647 kg
# Orbit: LEO
# Customer: NASA
# Launch outcome: Success
# Booster landing: No attempt
# Extracted row: 52
# Length of Flight No. array: 1585
# Length of Date array: 1582
# Length of Time array: 1582
# Length of Version Booster array: 1582
# Length of Launch site array: 1582
# Length of Payload array: 1582
# Length of Payload mass array: 1582
# Length of Orbit array: 1582
# Length of Customer array: 1577
# Length of Launch outcome array: 1577
# Length of Booster landing array: 1577
# Flight No.: 53
# Date: 18 April 2018
# Time: 22:51
# Version Booster: F9 B4
# Launch site: CCAFS
# Payload: Transiting Exoplanet Survey Satellite
# Payload mass: 362 kg
# Orbit: HEO
# Customer: NASA
# Launch outcome: Success
# Booster landing: Success
# Extracted row: 53
# Length of Flight No. array: 1586
# Length of Date array: 1583
# Length of Time array: 1583
# Length of Version Booster array: 1583
# Length of Launch site array: 1583
# Length of Payload array: 1583
# Length of Payload mass array: 1583
# Length of Orbit array: 1583
# Length of Customer array: 1578
# Length of Launch outcome array: 1578
# Length of Booster landing array: 1578
# Flight No.: 54
# Date: 11 May 2018
# Time: 20:14
# Version Booster: F9 B5B1046.1
# Launch site: KSC
# Payload: Bangabandhu-1
# Payload mass: 3,600 kg
# Orbit: GTO
# Customer: Thales-Alenia
# Launch outcome: Success
# Booster landing: Success
# Extracted row: 54
# Length of Flight No. array: 1587
# Length of Date array: 1584
# Length of Time array: 1584
# Length of Version Booster array: 1584
# Length of Launch site array: 1584
# Length of Payload array: 1584
# Length of Payload mass array: 1584
# Length of Orbit array: 1584
# Length of Customer array: 1579
# Length of Launch outcome array: 1579
# Length of Booster landing array: 1579
# Flight No.: 55
# Date: 22 May 2018
# Time: 19:47
# Version Booster: F9 B4B1043.2
# Launch site: VAFB
# Payload: Iridium NEXT
# Payload mass: 6,460 kg
# Orbit: Polar
# Customer: Iridium Communications
# Launch outcome: Success
# Booster landing: No attempt
# Extracted row: 55
# Length of Flight No. array: 1588
# Length of Date array: 1585
# Length of Time array: 1585
# Length of Version Booster array: 1585
# Length of Launch site array: 1585
# Length of Payload array: 1585
# Length of Payload mass array: 1585
# Length of Orbit array: 1585
# Length of Customer array: 1580
# Length of Launch outcome array: 1580
# Length of Booster landing array: 1580
# Flight No.: 56
# Date: 4 June 2018
# Time: 04:45
# Version Booster: F9 B4B1040.2
# Launch site: CCAFS
# Payload: SES-12
# Payload mass: 5,384 kg
# Orbit: GTO
# Customer: SES
# Launch outcome: Success
# Booster landing: No attempt
# Extracted row: 56
# Length of Flight No. array: 1589
# Length of Date array: 1586
# Length of Time array: 1586
# Length of Version Booster array: 1586
# Length of Launch site array: 1586
# Length of Payload array: 1586
# Length of Payload mass array: 1586
# Length of Orbit array: 1586
# Length of Customer array: 1581
# Length of Launch outcome array: 1581
# Length of Booster landing array: 1581
# Flight No.: 57
# Date: 29 June 2018
# Time: 09:42
# Version Booster: F9 B4B1045.2
# Launch site: CCAFS
# Payload: SpaceX CRS-15
# Payload mass: 2,697 kg
# Orbit: LEO
# Customer: NASA
# Launch outcome: Success
# Booster landing: No attempt
# Extracted row: 57
# Length of Flight No. array: 1590
# Length of Date array: 1587
# Length of Time array: 1587
# Length of Version Booster array: 1587
# Length of Launch site array: 1587
# Length of Payload array: 1587
# Length of Payload mass array: 1587
# Length of Orbit array: 1587
# Length of Customer array: 1582
# Length of Launch outcome array: 1582
# Length of Booster landing array: 1582
# Flight No.: 58
# Date: 22 July 2018
# Time: 05:50
# Version Booster: F9 B5
# Launch site: CCAFS
# Payload: Telstar 19V
# Payload mass: 7,075 kg
# Orbit: GTO
# Customer: Telesat
# Launch outcome: Success
# Booster landing: Success
# Extracted row: 58
# Length of Flight No. array: 1591
# Length of Date array: 1588
# Length of Time array: 1588
# Length of Version Booster array: 1588
# Length of Launch site array: 1588
# Length of Payload array: 1588
# Length of Payload mass array: 1588
# Length of Orbit array: 1588
# Length of Customer array: 1583
# Length of Launch outcome array: 1583
# Length of Booster landing array: 1583
# Flight No.: 59
# Date: 25 July 2018
# Time: 11:39
# Version Booster: F9 B5B1048
# Launch site: VAFB
# Payload: Iridium NEXT
# Payload mass: 9,600 kg
# Orbit: Polar
# Customer: Iridium Communications
# Launch outcome: Success
# Booster landing: Success
# Extracted row: 59
# Length of Flight No. array: 1592
# Length of Date array: 1589
# Length of Time array: 1589
# Length of Version Booster array: 1589
# Length of Launch site array: 1589
# Length of Payload array: 1589
# Length of Payload mass array: 1589
# Length of Orbit array: 1589
# Length of Customer array: 1584
# Length of Launch outcome array: 1584
# Length of Booster landing array: 1584
# Flight No.: 60
# Date: 7 August 2018
# Time: 05:18
# Version Booster: F9 B5B1046.2
# Launch site: CCAFS
# Payload: Merah Putih
# Payload mass: 5,800 kg
# Orbit: GTO
# Customer: Telkom Indonesia
# Launch outcome: Success
# Booster landing: Success
# Extracted row: 60
# Length of Flight No. array: 1593
# Length of Date array: 1590
# Length of Time array: 1590
# Length of Version Booster array: 1590
# Length of Launch site array: 1590
# Length of Payload array: 1590
# Length of Payload mass array: 1590
# Length of Orbit array: 1590
# Length of Customer array: 1585
# Length of Launch outcome array: 1585
# Length of Booster landing array: 1585
# Flight No.: 61
# Date: 10 September 2018
# Time: 04:45
# Version Booster: F9 B5
# Launch site: CCAFS
# Payload: Telstar 18V
# Payload mass: 7,060 kg
# Orbit: GTO
# Customer: Telesat
# Launch outcome: Success
# Booster landing: Success
# Extracted row: 61
# Length of Flight No. array: 1594
# Length of Date array: 1591
# Length of Time array: 1591
# Length of Version Booster array: 1591
# Length of Launch site array: 1591
# Length of Payload array: 1591
# Length of Payload mass array: 1591
# Length of Orbit array: 1591
# Length of Customer array: 1586
# Length of Launch outcome array: 1586
# Length of Booster landing array: 1586
# Flight No.: 62
# Date: 8 October 2018
# Time: 02:22
# Version Booster: F9 B5B1048.2
# Launch site: VAFB
# Payload: SAOCOM 1A
# Payload mass: 3,000 kg
# Orbit: SSO
# Customer: CONAE
# Launch outcome: Success
# Booster landing: Success
# Extracted row: 62
# Length of Flight No. array: 1595
# Length of Date array: 1592
# Length of Time array: 1592
# Length of Version Booster array: 1592
# Length of Launch site array: 1592
# Length of Payload array: 1592
# Length of Payload mass array: 1592
# Length of Orbit array: 1592
# Length of Customer array: 1587
# Length of Launch outcome array: 1587
# Length of Booster landing array: 1587
# Flight No.: 63
# Date: 15 November 2018
# Time: 20:46
# Version Booster: F9 B5B1047.2
# Launch site: KSC
# Payload: Es'hail 2
# Payload mass: 5,300 kg
# Orbit: GTO
# Customer: Es'hailSat
# Launch outcome: Success
# Booster landing: Success
# Extracted row: 63
# Length of Flight No. array: 1596
# Length of Date array: 1593
# Length of Time array: 1593
# Length of Version Booster array: 1593
# Length of Launch site array: 1593
# Length of Payload array: 1593
# Length of Payload mass array: 1593
# Length of Orbit array: 1593
# Length of Customer array: 1588
# Length of Launch outcome array: 1588
# Length of Booster landing array: 1588
# Flight No.: 64
# Date: 3 December 2018
# Time: 18:34:05
# Version Booster: F9 B5B1046.3
# Launch site: VAFB
# Payload: SSO-A
# Payload mass: ~4,000 kg
# Orbit: SSO
# Customer: Spaceflight Industries
# Launch outcome: Success
# Booster landing: Success
# Extracted row: 64
# Length of Flight No. array: 1597
# Length of Date array: 1594
# Length of Time array: 1594
# Length of Version Booster array: 1594
# Length of Launch site array: 1594
# Length of Payload array: 1594
# Length of Payload mass array: 1594
# Length of Orbit array: 1594
# Length of Customer array: 1589
# Length of Launch outcome array: 1589
# Length of Booster landing array: 1589
# Flight No.: 65
# Date: 5 December 2018
# Time: 18:16
# Version Booster: F9 B5
# Launch site: CCAFS
# Payload: SpaceX CRS-16
# Payload mass: 2,500 kg
# Orbit: LEO
# Customer: NASA
# Launch outcome: Success
#
# Booster landing: Failure
# Extracted row: 65
# Length of Flight No. array: 1598
# Length of Date array: 1595
# Length of Time array: 1595
# Length of Version Booster array: 1595
# Length of Launch site array: 1595
# Length of Payload array: 1595
# Length of Payload mass array: 1595
# Length of Orbit array: 1595
# Length of Customer array: 1590
# Length of Launch outcome array: 1590
# Length of Booster landing array: 1590
# Flight No.: 66
# Date: 23 December 2018
# Time: 13:51
# Version Booster: F9 B5
# Launch site: CCAFS
# Payload: GPS III
# Payload mass: 4,400 kg
# Orbit: MEO
# Customer: USAF
# Launch outcome: Success
# Booster landing: No attempt
# Extracted row: 66
# Length of Flight No. array: 1599
# Length of Date array: 1596
# Length of Time array: 1596
# Length of Version Booster array: 1596
# Length of Launch site array: 1596
# Length of Payload array: 1596
# Length of Payload mass array: 1596
# Length of Orbit array: 1596
# Length of Customer array: 1591
# Length of Launch outcome array: 1591
# Length of Booster landing array: 1591
# Flight No.: 67
# Date: 11 January 2019
# Time: 15:31
# Version Booster: F9 B5B1049.2
# Launch site: VAFB
# Payload: Iridium NEXT
# Payload mass: 9,600 kg
# Orbit: Polar
# Customer: Iridium Communications
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 67
# Length of Flight No. array: 1600
# Length of Date array: 1597
# Length of Time array: 1597
# Length of Version Booster array: 1597
# Length of Launch site array: 1597
# Length of Payload array: 1597
# Length of Payload mass array: 1597
# Length of Orbit array: 1597
# Length of Customer array: 1592
# Length of Launch outcome array: 1592
# Length of Booster landing array: 1592
# Flight No.: 68
# Date: 22 February 2019
# Time: 01:45
# Version Booster: F9 B5B1048.3
# Launch site: CCAFS
# Payload: Nusantara Satu
# Payload mass: 4,850 kg
# Orbit: GTO
# Customer: PSN
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 68
# Length of Flight No. array: 1601
# Length of Date array: 1598
# Length of Time array: 1598
# Length of Version Booster array: 1598
# Length of Launch site array: 1598
# Length of Payload array: 1598
# Length of Payload mass array: 1598
# Length of Orbit array: 1598
# Length of Customer array: 1593
# Length of Launch outcome array: 1593
# Length of Booster landing array: 1593
# Flight No.: 69
# Date: 2 March 2019
# Time: 07:49
# Version Booster: F9 B5[268]
# Launch site: KSC
# Payload: Crew Dragon Demo-1
# Payload mass: 12,055 kg
# Orbit: LEO
# Customer: NASA
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 69
# Length of Flight No. array: 1602
# Length of Date array: 1599
# Length of Time array: 1599
# Length of Version Booster array: 1599
# Length of Launch site array: 1599
# Length of Payload array: 1599
# Length of Payload mass array: 1599
# Length of Orbit array: 1599
# Length of Customer array: 1594
# Length of Launch outcome array: 1594
# Length of Booster landing array: 1594
# Flight No.: 70
# Date: 4 May 2019
# Time: 06:48
# Version Booster: F9 B5
# Launch site: CCAFS
# Payload: SpaceX CRS-17
# Payload mass: 2,495 kg
# Orbit: LEO
# Customer: NASA
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 70
# Length of Flight No. array: 1603
# Length of Date array: 1600
# Length of Time array: 1600
# Length of Version Booster array: 1600
# Length of Launch site array: 1600
# Length of Payload array: 1600
# Length of Payload mass array: 1600
# Length of Orbit array: 1600
# Length of Customer array: 1595
# Length of Launch outcome array: 1595
# Length of Booster landing array: 1595
# Flight No.: 71
# Date: 24 May 2019
# Time: 02:30
# Version Booster: F9 B5B1049.3
# Launch site: CCAFS
# Payload: Starlink
# Payload mass: 13,620 kg
# Orbit: LEO
# Customer: SpaceX
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 71
# Length of Flight No. array: 1604
# Length of Date array: 1601
# Length of Time array: 1601
# Length of Version Booster array: 1601
# Length of Launch site array: 1601
# Length of Payload array: 1601
# Length of Payload mass array: 1601
# Length of Orbit array: 1601
# Length of Customer array: 1596
# Length of Launch outcome array: 1596
# Length of Booster landing array: 1596
# Flight No.: 72
# Date: 12 June 2019
# Time: 14:17
# Version Booster: F9 B5B1051.2
# Launch site: VAFB
# Payload: RADARSAT Constellation
# Payload mass: 4,200 kg
# Orbit: SSO
# Customer: Canadian Space Agency
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 72
# Length of Flight No. array: 1605
# Length of Date array: 1602
# Length of Time array: 1602
# Length of Version Booster array: 1602
# Length of Launch site array: 1602
# Length of Payload array: 1602
# Length of Payload mass array: 1602
# Length of Orbit array: 1602
# Length of Customer array: 1597
# Length of Launch outcome array: 1597
# Length of Booster landing array: 1597
# Flight No.: 73
# Date: 25 July 2019
# Time: 22:01
# Version Booster: F9 B5B1056.2
# Launch site: CCAFS
# Payload: SpaceX CRS-18
# Payload mass: 2,268 kg
# Orbit: LEO
# Customer: NASA
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 73
# Length of Flight No. array: 1606
# Length of Date array: 1603
# Length of Time array: 1603
# Length of Version Booster array: 1603
# Length of Launch site array: 1603
# Length of Payload array: 1603
# Length of Payload mass array: 1603
# Length of Orbit array: 1603
# Length of Customer array: 1598
# Length of Launch outcome array: 1598
# Length of Booster landing array: 1598
# Flight No.: 74
# Date: 6 August 2019
# Time: 23:23
# Version Booster: F9 B5B1047.3
# Launch site: CCAFS
# Payload: AMOS-17
# Payload mass: 6,500 kg
# Orbit: GTO
# Customer: Spacecom
# Launch outcome: Success
#
# Booster landing: No attempt
# Extracted row: 74
# Length of Flight No. array: 1607
# Length of Date array: 1604
# Length of Time array: 1604
# Length of Version Booster array: 1604
# Length of Launch site array: 1604
# Length of Payload array: 1604
# Length of Payload mass array: 1604
# Length of Orbit array: 1604
# Length of Customer array: 1599
# Length of Launch outcome array: 1599
# Length of Booster landing array: 1599
# Flight No.: 75
# Date: 11 November 2019
# Time: 14:56
# Version Booster: F9 B5
# Launch site: CCAFS
# Payload: Starlink
# Payload mass: 15,600 kg
# Orbit: LEO
# Customer: SpaceX
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 75
# Length of Flight No. array: 1608
# Length of Date array: 1605
# Length of Time array: 1605
# Length of Version Booster array: 1605
# Length of Launch site array: 1605
# Length of Payload array: 1605
# Length of Payload mass array: 1605
# Length of Orbit array: 1605
# Length of Customer array: 1600
# Length of Launch outcome array: 1600
# Length of Booster landing array: 1600
# Flight No.: 76
# Date: 5 December 2019
# Time: 17:29
# Version Booster: F9 B5
# Launch site: CCAFS
# Payload: SpaceX CRS-19
# Payload mass: 2,617 kg
# Orbit: LEO
# Customer: NASA
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 76
# Length of Flight No. array: 1609
# Length of Date array: 1606
# Length of Time array: 1606
# Length of Version Booster array: 1606
# Length of Launch site array: 1606
# Length of Payload array: 1606
# Length of Payload mass array: 1606
# Length of Orbit array: 1606
# Length of Customer array: 1601
# Length of Launch outcome array: 1601
# Length of Booster landing array: 1601
# Flight No.: 77
# Date: 17 December 2019
# Time: 00:10
# Version Booster: F9 B5B1056.3
# Launch site: CCAFS
# Payload: JCSat-18
# Payload mass: 6,956 kg
# Orbit: GTO
# Customer: Sky Perfect JSAT
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 77
# Length of Flight No. array: 1610
# Length of Date array: 1607
# Length of Time array: 1607
# Length of Version Booster array: 1607
# Length of Launch site array: 1607
# Length of Payload array: 1607
# Length of Payload mass array: 1607
# Length of Orbit array: 1607
# Length of Customer array: 1602
# Length of Launch outcome array: 1602
# Length of Booster landing array: 1602
# Flight No.: 78
# Date: 7 January 2020
# Time: 02:19:21
# Version Booster: F9 B5
# Launch site: CCAFS
# Payload: Starlink
# Payload mass: 15,600 kg
# Orbit: LEO
# Customer: SpaceX
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 78
# Length of Flight No. array: 1611
# Length of Date array: 1608
# Length of Time array: 1608
# Length of Version Booster array: 1608
# Length of Launch site array: 1608
# Length of Payload array: 1608
# Length of Payload mass array: 1608
# Length of Orbit array: 1608
# Length of Customer array: 1603
# Length of Launch outcome array: 1603
# Length of Booster landing array: 1603
# Flight No.: 79
# Date: 19 January 2020
# Time: 15:30
# Version Booster: F9 B5
# Launch site: KSC
# Payload: Crew Dragon in-flight abort test
# Payload mass: 12,050 kg
# Orbit: Sub-orbital
# Customer: NASA
# Launch outcome: Success
#
# Booster landing: No attempt
#
# Extracted row: 79
# Length of Flight No. array: 1612
# Length of Date array: 1609
# Length of Time array: 1609
# Length of Version Booster array: 1609
# Length of Launch site array: 1609
# Length of Payload array: 1609
# Length of Payload mass array: 1609
# Length of Orbit array: 1609
# Length of Customer array: 1604
# Length of Launch outcome array: 1604
# Length of Booster landing array: 1604
# Flight No.: 80
# Date: 29 January 2020
# Time: 14:07
# Version Booster: F9 B5
# Launch site: CCAFS
# Payload: Starlink
# Payload mass: 15,600 kg
# Orbit: LEO
# Customer: SpaceX
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 80
# Length of Flight No. array: 1613
# Length of Date array: 1610
# Length of Time array: 1610
# Length of Version Booster array: 1610
# Length of Launch site array: 1610
# Length of Payload array: 1610
# Length of Payload mass array: 1610
# Length of Orbit array: 1610
# Length of Customer array: 1605
# Length of Launch outcome array: 1605
# Length of Booster landing array: 1605
# Flight No.: 81
# ...
# Flight No.: 95
# Date: 18 October 2020
# Time: 12:25:57
# Version Booster: F9 B5B1051.6
# Launch site: KSC
# Payload: Starlink
# Payload mass: 15,600 kg
# Orbit: LEO
# Customer: SpaceX
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 95
# Length of Flight No. array: 1628
# Length of Date array: 1625
# Length of Time array: 1625
# Length of Version Booster array: 1625
# Length of Launch site array: 1625
# Length of Payload array: 1625
# Length of Payload mass array: 1625
# Length of Orbit array: 1625
# Length of Customer array: 1620
# Length of Launch outcome array: 1620
# Length of Booster landing array: 1620
# Flight No.: 96
# Date: 24 October 2020
# Time: 15:31:34
# Version Booster: F9 B5
# Launch site: CCAFS
# Payload: Starlink
# Payload mass: 15,600 kg
# Orbit: LEO
# Customer: SpaceX
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 96
# Length of Flight No. array: 1629
# Length of Date array: 1626
# Length of Time array: 1626
# Length of Version Booster array: 1626
# Length of Launch site array: 1626
# Length of Payload array: 1626
# Length of Payload mass array: 1626
# Length of Orbit array: 1626
# Length of Customer array: 1621
# Length of Launch outcome array: 1621
# Length of Booster landing array: 1621
# Flight No.: 97
# Date: 5 November 2020
# Time: 23:24:23
# Version Booster: F9 B5
# Launch site: CCAFS
# Payload: GPS III
# Payload mass: 4,311 kg
# Orbit: MEO
# Customer: USSF
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 97
# Length of Flight No. array: 1630
# Length of Date array: 1627
# Length of Time array: 1627
# Length of Version Booster array: 1627
# Length of Launch site array: 1627
# Length of Payload array: 1627
# Length of Payload mass array: 1627
# Length of Orbit array: 1627
# Length of Customer array: 1622
# Length of Launch outcome array: 1622
# Length of Booster landing array: 1622
# Flight No.: 98
# Date: 16 November 2020
# Time: 00:27
# Version Booster: F9 B5
# Launch site: KSC
# Payload: Crew-1
# Payload mass: ~12,500 kg
# Orbit: LEO
# Customer: NASA
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 98
# Length of Flight No. array: 1631
# Length of Date array: 1628
# Length of Time array: 1628
# Length of Version Booster array: 1628
# Length of Launch site array: 1628
# Length of Payload array: 1628
# Length of Payload mass array: 1628
# Length of Orbit array: 1628
# Length of Customer array: 1623
# Length of Launch outcome array: 1623
# Length of Booster landing array: 1623
# Flight No.: 99
# Date: 21 November 2020
# Time: 17:17:08
# Version Booster: F9 B5
# Launch site: VAFB
# Payload: Sentinel-6 Michael Freilich (Jason-CS A)
# Payload mass: 1,192 kg
# Orbit: LEO
# Customer: NASA
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 99
# Length of Flight No. array: 1632
# Length of Date array: 1629
# Length of Time array: 1629
# Length of Version Booster array: 1629
# Length of Launch site array: 1629
# Length of Payload array: 1629
# Length of Payload mass array: 1629
# Length of Orbit array: 1629
# Length of Customer array: 1624
# Length of Launch outcome array: 1624
# Length of Booster landing array: 1624
# Flight No.: 100
# Date: 25 November 2020
# Time: 02:13
# Version Booster: F9 B5 ♺
# Launch site: CCAFS
# Payload: Starlink
# Payload mass: 15,600 kg
# Orbit: LEO
# Customer: SpaceX
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 100
# Length of Flight No. array: 1633
# Length of Date array: 1630
# Length of Time array: 1630
# Length of Version Booster array: 1630
# Length of Launch site array: 1630
# Length of Payload array: 1630
# Length of Payload mass array: 1630
# Length of Orbit array: 1630
# Length of Customer array: 1625
# Length of Launch outcome array: 1625
# Length of Booster landing array: 1625
# Flight No.: 101
# Date: 6 December 2020
# Time: 16:17:08
# Version Booster: F9 B5 ♺
# Launch site: KSC
# Payload: SpaceX CRS-21
# Payload mass: 2,972 kg
# Orbit: LEO
# Customer: NASA
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 101
# Length of Flight No. array: 1634
# Length of Date array: 1631
# Length of Time array: 1631
# Length of Version Booster array: 1631
# Length of Launch site array: 1631
# Length of Payload array: 1631
# Length of Payload mass array: 1631
# Length of Orbit array: 1631
# Length of Customer array: 1626
# Length of Launch outcome array: 1626
# Length of Booster landing array: 1626
# Flight No.: 102
# Date: 13 December 2020
# Time: 17:30:00
# Version Booster: F9 B5 ♺
# Launch site: CCSFSSLC-40
# Payload: SXM-7
# Payload mass: 7,000 kg
# Orbit: GTO
# Customer: Sirius XM
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 102
# Length of Flight No. array: 1635
# Length of Date array: 1632
# Length of Time array: 1632
# Length of Version Booster array: 1632
# Length of Launch site array: 1632
# Length of Payload array: 1632
# Length of Payload mass array: 1632
# Length of Orbit array: 1632
# Length of Customer array: 1627
# Length of Launch outcome array: 1627
# Length of Booster landing array: 1627
# Flight No.: 103
# Date: 19 December 2020
# Time: 14:00:00
# Version Booster: F9 B5 ♺
# Launch site: KSC
# Payload: NROL-108
# Payload mass: C
# Orbit: LEO
# Customer: NRO
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 103
# Length of Flight No. array: 1636
# Length of Date array: 1633
# Length of Time array: 1633
# Length of Version Booster array: 1633
# Length of Launch site array: 1633
# Length of Payload array: 1633
# Length of Payload mass array: 1633
# Length of Orbit array: 1633
# Length of Customer array: 1628
# Length of Launch outcome array: 1628
# Length of Booster landing array: 1628
# Flight No.: 104
# Date: 8 January 2021
# Time: 02:15
# Version Booster: F9 B5
# Launch site: CCSFS
# Payload: Türksat 5A
# Payload mass: 3,500 kg
# Orbit: GTO
# Customer: Türksat
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 104
# Length of Flight No. array: 1637
# Length of Date array: 1634
# Length of Time array: 1634
# Length of Version Booster array: 1634
# Length of Launch site array: 1634
# Length of Payload array: 1634
# Length of Payload mass array: 1634
# Length of Orbit array: 1634
# Length of Customer array: 1629
# Length of Launch outcome array: 1629
# Length of Booster landing array: 1629
# Flight No.: 105
# Date: 20 January 2021
# Time: 13:02
# Version Booster: F9 B5B1051.8
# Launch site: KSC
# Payload: Starlink
# Payload mass: 15,600 kg
# Orbit: LEO
# Customer: SpaceX
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 105
# Length of Flight No. array: 1638
# Length of Date array: 1635
# Length of Time array: 1635
# Length of Version Booster array: 1635
# Length of Launch site array: 1635
# Length of Payload array: 1635
# Length of Payload mass array: 1635
# Length of Orbit array: 1635
# Length of Customer array: 1630
# Length of Launch outcome array: 1630
# Length of Booster landing array: 1630
# Flight No.: 106
# Date: 24 January 2021
# Time: 15:00
# Version Booster: F9 B5B1058.5
# Launch site: CCSFS
# Payload: Transporter-1
# Payload mass: ~5,000 kg
# Orbit: SSO
# Customer: Various
#
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 106
# Length of Flight No. array: 1639
# Length of Date array: 1636
# Length of Time array: 1636
# Length of Version Booster array: 1636
# Length of Launch site array: 1636
# Length of Payload array: 1636
# Length of Payload mass array: 1636
# Length of Orbit array: 1636
# Length of Customer array: 1631
# Length of Launch outcome array: 1631
# Length of Booster landing array: 1631
# Flight No.: 107
# Date: 4 February 2021
# Time: 06:19
# Version Booster: F9 B5 ♺
# Launch site: CCSFS
# Payload: Starlink
# Payload mass: 15,600 kg
# Orbit: LEO
# Customer: SpaceX
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 107
# Length of Flight No. array: 1640
# Length of Date array: 1637
# Length of Time array: 1637
# Length of Version Booster array: 1637
# Length of Launch site array: 1637
# Length of Payload array: 1637
# Length of Payload mass array: 1637
# Length of Orbit array: 1637
# Length of Customer array: 1632
# Length of Launch outcome array: 1632
# Length of Booster landing array: 1632
# Flight No.: 108
# Date: 16 February 2021
# Time: 03:59:37
# Version Booster: F9 B5 ♺
# Launch site: CCSFS
# Payload: Starlink
# Payload mass: 15,600 kg
# Orbit: LEO
# Customer: SpaceX
# Launch outcome: Success
#
# Booster landing: Failure
# Extracted row: 108
# Length of Flight No. array: 1641
# Length of Date array: 1638
# Length of Time array: 1638
# Length of Version Booster array: 1638
# Length of Launch site array: 1638
# Length of Payload array: 1638
# Length of Payload mass array: 1638
# Length of Orbit array: 1638
# Length of Customer array: 1633
# Length of Launch outcome array: 1633
# Length of Booster landing array: 1633
# Flight No.: 109
# Date: 4 March 2021
# Time: 08:24
# Version Booster: F9 B5 ♺
# Launch site: KSC
# Payload: Starlink
# Payload mass: 15,600 kg
# Orbit: LEO
# Customer: SpaceX
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 109
# Length of Flight No. array: 1642
# Length of Date array: 1639
# Length of Time array: 1639
# Length of Version Booster array: 1639
# Length of Launch site array: 1639
# Length of Payload array: 1639
# Length of Payload mass array: 1639
# Length of Orbit array: 1639
# Length of Customer array: 1634
# Length of Launch outcome array: 1634
# Length of Booster landing array: 1634
# Flight No.: 110
# Date: 11 March 2021
# Time: 08:13:29
# Version Booster: F9 B5 ♺
# Launch site: CCSFS
# Payload: Starlink
# Payload mass: 15,600 kg
# Orbit: LEO
# Customer: SpaceX
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 110
# Length of Flight No. array: 1643
# Length of Date array: 1640
# Length of Time array: 1640
# Length of Version Booster array: 1640
# Length of Launch site array: 1640
# Length of Payload array: 1640
# Length of Payload mass array: 1640
# Length of Orbit array: 1640
# Length of Customer array: 1635
# Length of Launch outcome array: 1635
# Length of Booster landing array: 1635
# Flight No.: 111
# Date: 14 March 2021
# Time: 10:01
# Version Booster: F9 B5 ♺
# Launch site: KSC
# Payload: Starlink
# Payload mass: 15,600 kg
# Orbit: LEO
# Customer: SpaceX
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 111
# Length of Flight No. array: 1644
# Length of Date array: 1641
# Length of Time array: 1641
# Length of Version Booster array: 1641
# Length of Launch site array: 1641
# Length of Payload array: 1641
# Length of Payload mass array: 1641
# Length of Orbit array: 1641
# Length of Customer array: 1636
# Length of Launch outcome array: 1636
# Length of Booster landing array: 1636
# Flight No.: 112
# Date: 24 March 2021
# Time: 08:28
# Version Booster: F9 B5B1060.6
# Launch site: CCSFS
# Payload: Starlink
# Payload mass: 15,600 kg
# Orbit: LEO
# Customer: SpaceX
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 112
# Length of Flight No. array: 1645
# Length of Date array: 1642
# Length of Time array: 1642
# Length of Version Booster array: 1642
# Length of Launch site array: 1642
# Length of Payload array: 1642
# Length of Payload mass array: 1642
# Length of Orbit array: 1642
# Length of Customer array: 1637
# Length of Launch outcome array: 1637
# Length of Booster landing array: 1637
# Flight No.: 113
# Date: 7 April 2021
# Time: 16:34
# Version Booster: F9 B5 ♺
# Launch site: CCSFS
# Payload: Starlink
# Payload mass: 15,600 kg
# Orbit: LEO
# Customer: SpaceX
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 113
# Length of Flight No. array: 1646
# Length of Date array: 1643
# Length of Time array: 1643
# Length of Version Booster array: 1643
# Length of Launch site array: 1643
# Length of Payload array: 1643
# Length of Payload mass array: 1643
# Length of Orbit array: 1643
# Length of Customer array: 1638
# Length of Launch outcome array: 1638
# Length of Booster landing array: 1638
# Flight No.: 114
# Date: 23 April 2021
# Time: 9:49
# Version Booster: F9 B5B1061.2
# Launch site: KSC
# Payload: Crew-2
# Payload mass: ~13,000 kg
# Orbit: LEO
# Customer: NASA
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 114
# Length of Flight No. array: 1647
# Length of Date array: 1644
# Length of Time array: 1644
# Length of Version Booster array: 1644
# Length of Launch site array: 1644
# Length of Payload array: 1644
# Length of Payload mass array: 1644
# Length of Orbit array: 1644
# Length of Customer array: 1639
# Length of Launch outcome array: 1639
# Length of Booster landing array: 1639
# Flight No.: 115
# Date: 29 April 2021
# Time: 03:44
# Version Booster: F9 B5B1060.7
# Launch site: CCSFS
# Payload: Starlink
# Payload mass: 15,600 kg
# Orbit: LEO
# Customer: SpaceX
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 115
# Length of Flight No. array: 1648
# Length of Date array: 1645
# Length of Time array: 1645
# Length of Version Booster array: 1645
# Length of Launch site array: 1645
# Length of Payload array: 1645
# Length of Payload mass array: 1645
# Length of Orbit array: 1645
# Length of Customer array: 1640
# Length of Launch outcome array: 1640
# Length of Booster landing array: 1640
# Flight No.: 116
# Date: 4 May 2021
# Time: 19:01
# Version Booster: F9 B5B1049.9
# Launch site: KSC
# Payload: Starlink
# Payload mass: 15,600 kg
# Orbit: LEO
# Customer: SpaceX
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 116
# Length of Flight No. array: 1649
# Length of Date array: 1646
# Length of Time array: 1646
# Length of Version Booster array: 1646
# Length of Launch site array: 1646
# Length of Payload array: 1646
# Length of Payload mass array: 1646
# Length of Orbit array: 1646
# Length of Customer array: 1641
# Length of Launch outcome array: 1641
# Length of Booster landing array: 1641
# Flight No.: 117
# Date: 9 May 2021
# Time: 06:42
# Version Booster: F9 B5B1051.10
# Launch site: CCSFS
# Payload: Starlink
# Payload mass: 15,600 kg
# Orbit: LEO
# Customer: SpaceX
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 117
# Length of Flight No. array: 1650
# Length of Date array: 1647
# Length of Time array: 1647
# Length of Version Booster array: 1647
# Length of Launch site array: 1647
# Length of Payload array: 1647
# Length of Payload mass array: 1647
# Length of Orbit array: 1647
# Length of Customer array: 1642
# Length of Launch outcome array: 1642
# Length of Booster landing array: 1642
# Flight No.: 118
# Date: 15 May 2021
# Time: 22:56
# Version Booster: F9 B5B1058.8
# Launch site: KSCLC-39A
# Payload: Starlink
# Payload mass: ~14,000 kg
# Orbit: LEO
# Customer: SpaceX
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 118
# Length of Flight No. array: 1651
# Length of Date array: 1648
# Length of Time array: 1648
# Length of Version Booster array: 1648
# Length of Launch site array: 1648
# Length of Payload array: 1648
# Length of Payload mass array: 1648
# Length of Orbit array: 1648
# Length of Customer array: 1643
# Length of Launch outcome array: 1643
# Length of Booster landing array: 1643
# Flight No.: 119
# Date: 26 May 2021
# Time: 18:59
# Version Booster: F9 B5B1063.2
# Launch site: CCSFSSLC-40
# Payload: Starlink
# Payload mass: 15,600 kg
# Orbit: LEO
# Customer: SpaceX
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 119
# Length of Flight No. array: 1652
# Length of Date array: 1649
# Length of Time array: 1649
# Length of Version Booster array: 1649
# Length of Launch site array: 1649
# Length of Payload array: 1649
# Length of Payload mass array: 1649
# Length of Orbit array: 1649
# Length of Customer array: 1644
# Length of Launch outcome array: 1644
# Length of Booster landing array: 1644
# Flight No.: 120
# Date: 3 June 2021
# Time: 17:29
# Version Booster: F9 B5B1067.1
# Launch site: KSC
# Payload: SpaceX CRS-22
# Payload mass: 3,328 kg
# Orbit: LEO
# Customer: NASA
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 120
# Length of Flight No. array: 1653
# Length of Date array: 1650
# Length of Time array: 1650
# Length of Version Booster array: 1650
# Length of Launch site array: 1650
# Length of Payload array: 1650
# Length of Payload mass array: 1650
# Length of Orbit array: 1650
# Length of Customer array: 1645
# Length of Launch outcome array: 1645
# Length of Booster landing array: 1645
# Flight No.: 121
# Date: 6 June 2021
# Time: 04:26
# Version Booster: F9 B5
# Launch site: CCSFS
# Payload: SXM-8
# Payload mass: 7,000 kg
# Orbit: GTO
# Customer: Sirius XM
# Launch outcome: Success
#
# Booster landing: Success
# Extracted row: 121
# Length of Flight No. array: 1654
# Length of Date array: 1651
# Length of Time array: 1651
# Length of Version Booster array: 1651
# Length of Launch site array: 1651
# Length of Payload array: 1651
# Length of Payload mass array: 1651
# Length of Orbit array: 1651
# Length of Customer array: 1646
# Length of Launch outcome array: 1646
# Length of Booster landing array: 1646

# %% [markdown]
# After you have fill in the parsed launch record values into `launch_dict`, you can create a dataframe from it.

# %%
df = pd.DataFrame({ key:pd.Series(value) for key, value in launch_dict.items()})
df.head()

#in the launch outcome column, there are some values that have \n in them. We need to remove them
df['Launch outcome'] = df['Launch outcome'].str.replace('\n', '')
df['Booster landing'] = df['Booster landing'].str.replace('\n', '')
df.head()

#remove the extra customer column
#df.drop('customer', axis=1, inplace=True)
# Out:
#   Flight No. Launch site                               Payload Payload mass  \
# 0          1       CCAFS  Dragon Spacecraft Qualification Unit            0
# 1          1       CCAFS                                Dragon            0
# 2          1       CCAFS                                Dragon       525 kg
# 3          1       CCAFS                          SpaceX CRS-1     4,700 kg
# 4          2       CCAFS                          SpaceX CRS-2     4,877 kg
#
#   Orbit                                           Customer Launch outcome  \
# 0   LEO                                     [[SpaceX], \n]        Success
# 1   LEO  [[.mw-parser-output .plainlist ol,.mw-parser-o...        Success
# 2   LEO                          [[NASA],  (, [COTS], )\n]        Success
# 3   LEO                           [[NASA],  (, [CRS], )\n]        Success
# 4   LEO                           [[NASA],  (, [CRS], )\n]        Success
#
#               Date   Time Version Booster Booster landing
# 0      4 June 2010  18:45  F9 v1.0B0003.1         Success
# 1  8 December 2010  15:43  F9 v1.0B0004.1         Success
# 2      22 May 2012  07:44  F9 v1.0B0005.1         Success
# 3   8 October 2012  00:35  F9 v1.0B0006.1         Success
# 4     1 March 2013  15:10  F9 v1.0B0007.1         Success

# %%
df.to_csv('spacex_web_scraped_1.csv', index=False)

# %% [markdown]
# <code>df.to_csv('spacex_web_scraped1.csv', index=False)</code>
